# %%
#Importando pacotes
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import time
import os
import pandas_gbq
from google.cloud import bigquery
import glob
import openpyxl
import csv

# %%
#Chamando diretório
os.chdir('G:\\Drives compartilhados\\República.org\\4. Equipes\\Dados e Comunicação\\DADOS\\415 - Repositório de Dados\\Dados para subir\\Dados Brutos\\INEP\\Esforço docente')

# %%
df1 = pd.read_csv('IED_ESCOLAS_2013.csv', sep=';', encoding='UTF8')
df1
# Out:
#          Ano        Região  UF  Código do Município      Nome do Município  \
# 0       2013         Norte  RO              1100015  ALTA FLORESTA D OESTE
# 1       2013         Norte  RO              1100015  ALTA FLORESTA D OESTE
# 2       2013         Norte  RO              1100015  ALTA FLORESTA D OESTE
# 3       2013         Norte  RO              1100015  ALTA FLORESTA D OESTE
# 4       2013         Norte  RO              1100015  ALTA FLORESTA D OESTE
# ...      ...           ...  ..                  ...                    ...
# 149136  2013  Centro_Oeste  DF              5300108               BRASILIA
# 149137  2013  Centro_Oeste  DF              5300108               BRASILIA
# 149138  2013  Centro_Oeste  DF              5300108               BRASILIA
# 149139  2013  Centro_Oeste  DF              5300108               BRASILIA
# 149140  2013  Centro_Oeste  DF              5300108               BRASILIA
#
# ...

# %%
df1.columns
# Out:
# Index(['Ano', 'Região', 'UF', 'Código do Município', 'Nome do Município',
#        'Código da Escola', 'Nome da Escola', 'Localização',
#        'Dependência Administrativa', 'EF_total_grupo1', 'EF_total_grupo2',
#        'EF_total_grupo3', 'EF_total_grupo4', 'EF_total_grupo5',
#        'EF_total_grupo6', 'EF_iniciais_grupo1', 'EF_iniciais_grupo2',
#        'EF_iniciais_grupo3', 'EF_iniciais_grupo4', 'EF_iniciais_grupo5',
#        'EF_iniciais_grupo6', 'EF_finais_grupo1', 'EF_finais_grupo2',
#        'EF_finais_grupo3', 'EF_finais_grupo4', 'EF_finais_grupo5',
#        'EF_finais_grupo6', 'EM_grupo1', 'EM_grupo2', 'EM_grupo3', 'EM_grupo4',
#        'EM_grupo5', 'EM_grupo6'],
#       dtype='object')

# %%
df2 = pd.read_csv('IED_ESCOLAS_2014.csv', sep=';', encoding='UTF8')
df2
# Out:
#          Ano        Região  UF  Código do Município      Nome do Município  \
# 0       2014         Norte  RO              1100015  ALTA FLORESTA D OESTE
# 1       2014         Norte  RO              1100015  ALTA FLORESTA D OESTE
# 2       2014         Norte  RO              1100015  ALTA FLORESTA D OESTE
# 3       2014         Norte  RO              1100015  ALTA FLORESTA D OESTE
# 4       2014         Norte  RO              1100015  ALTA FLORESTA D OESTE
# ...      ...           ...  ..                  ...                    ...
# 145805  2014  Centro_Oeste  DF              5300108               BRASILIA
# 145806  2014  Centro_Oeste  DF              5300108               BRASILIA
# 145807  2014  Centro_Oeste  DF              5300108               BRASILIA
# 145808  2014  Centro_Oeste  DF              5300108               BRASILIA
# 145809  2014  Centro_Oeste  DF              5300108               BRASILIA
#
#         Código da Escola             Nome da Escola Localização  \
# ...

# %%
df2.columns
# Out:
# Index(['Ano', 'Região', 'UF', 'Código do Município', 'Nome do Município',
#        'Código da Escola', 'Nome da Escola', 'Localização',
#        'Dependência Administrativa', 'EF_total_grupo1', 'EF_total_grupo2',
#        'EF_total_grupo3', 'EF_total_grupo4', 'EF_total_grupo5',
#        'EF_total_grupo6', 'EF_iniciais_grupo1', 'EF_iniciais_grupo2',
#        'EF_iniciais_grupo3', 'EF_iniciais_grupo4', 'EF_iniciais_grupo5',
#        'EF_iniciais_grupo6', 'EF_finais_grupo1', 'EF_finais_grupo2',
#        'EF_finais_grupo3', 'EF_finais_grupo4', 'EF_finais_grupo5',
#        'EF_finais_grupo6', 'EM_grupo1', 'EM_grupo2', 'EM_grupo3', 'EM_grupo4',
#        'EM_grupo5', 'EM_grupo6'],
#       dtype='object')

# %%
df3 = pd.read_csv('IED_ESCOLAS_2015.csv', sep=';', encoding='UTF8')
df3
# Out:
#          Ano        Região  UF  Código do Município      Nome do Município  \
# 0       2015         Norte  RO              1100015  ALTA FLORESTA D OESTE
# 1       2015         Norte  RO              1100015  ALTA FLORESTA D OESTE
# 2       2015         Norte  RO              1100015  ALTA FLORESTA D OESTE
# 3       2015         Norte  RO              1100015  ALTA FLORESTA D OESTE
# 4       2015         Norte  RO              1100015  ALTA FLORESTA D OESTE
# ...      ...           ...  ..                  ...                    ...
# 142690  2015  Centro-Oeste  DF              5300108               BRASILIA
# 142691  2015  Centro-Oeste  DF              5300108               BRASILIA
# 142692  2015  Centro-Oeste  DF              5300108               BRASILIA
# 142693  2015  Centro-Oeste  DF              5300108               BRASILIA
# 142694  2015  Centro-Oeste  DF              5300108               BRASILIA
#
# ...

# %%
df3.columns
# Out:
# Index(['Ano', 'Região', 'UF', 'Código do Município', 'Nome do Município',
#        'Código da Escola', 'Nome da Escola', 'Localização',
#        'Dependência Administrativa', 'EF_total_grupo1', 'EF_total_grupo2',
#        'EF_total_grupo3', 'EF_total_grupo4', 'EF_total_grupo5',
#        'EF_total_grupo6', 'EF_iniciais_grupo1', 'EF_iniciais_grupo2',
#        'EF_iniciais_grupo3', 'EF_iniciais_grupo4', 'EF_iniciais_grupo5',
#        'EF_iniciais_grupo6', 'EF_finais_grupo1', 'EF_finais_grupo2',
#        'EF_finais_grupo3', 'EF_finais_grupo4', 'EF_finais_grupo5',
#        'EF_finais_grupo6', 'EM_grupo1', 'EM_grupo2', 'EM_grupo3', 'EM_grupo4',
#        'EM_grupo5', 'EM_grupo6'],
#       dtype='object')

# %%
df4 = pd.read_csv('IED_ESCOLAS_2016.csv', sep=';', encoding='latin-1')
df4
# Out:
#          Ano        Região  UF  Código do Município      Nome do Município  \
# 0       2016         Norte  RO              1100015  Alta Floresta D'Oeste
# 1       2016         Norte  RO              1100015  Alta Floresta D'Oeste
# 2       2016         Norte  RO              1100015  Alta Floresta D'Oeste
# 3       2016         Norte  RO              1100015  Alta Floresta D'Oeste
# 4       2016         Norte  RO              1100015  Alta Floresta D'Oeste
# ...      ...           ...  ..                  ...                    ...
# 141589  2016  Centro-Oeste  DF              5300108               Brasília
# 141590  2016  Centro-Oeste  DF              5300108               Brasília
# 141591  2016  Centro-Oeste  DF              5300108               Brasília
# 141592  2016  Centro-Oeste  DF              5300108               Brasília
# 141593  2016  Centro-Oeste  DF              5300108               Brasília
#
#         Código da Escola         Nome da Escola Localização  \
# ...

# %%
df4.columns
# Out:
# Index(['Ano', 'Região', 'UF', 'Código do Município', 'Nome do Município',
#        'Código da Escola', 'Nome da Escola', 'Localização',
#        'Dependência Administrativa', 'EF_total_grupo1', 'EF_total_grupo2',
#        'EF_total_grupo3', 'EF_total_grupo4', 'EF_total_grupo5',
#        'EF_total_grupo6', 'EF_iniciais_grupo1', 'EF_iniciais_grupo2',
#        'EF_iniciais_grupo3', 'EF_iniciais_grupo4', 'EF_iniciais_grupo5',
#        'EF_iniciais_grupo6', 'EF_finais_grupo1', 'EF_finais_grupo2',
#        'EF_finais_grupo3', 'EF_finais_grupo4', 'EF_finais_grupo5',
#        'EF_finais_grupo6', 'EM_grupo1', 'EM_grupo2', 'EM_grupo3', 'EM_grupo4',
#        'EM_grupo5', 'EM_grupo6'],
#       dtype='object')

# %%
df5 = pd.read_csv('IED_ESCOLAS_2017.csv', sep=';', encoding='UTF8')
df5
# Out:
#          Ano        Região  UF  Código do Município      Nome do Município  \
# 0       2017         Norte  RO              1100015  Alta Floresta D'Oeste
# 1       2017         Norte  RO              1100015  Alta Floresta D'Oeste
# 2       2017         Norte  RO              1100015  Alta Floresta D'Oeste
# 3       2017         Norte  RO              1100015  Alta Floresta D'Oeste
# 4       2017         Norte  RO              1100015  Alta Floresta D'Oeste
# ...      ...           ...  ..                  ...                    ...
# 139090  2017  Centro-Oeste  DF              5300108               Brasília
# 139091  2017  Centro-Oeste  DF              5300108               Brasília
# 139092  2017  Centro-Oeste  DF              5300108               Brasília
# 139093  2017  Centro-Oeste  DF              5300108               Brasília
# 139094  2017  Centro-Oeste  DF              5300108               Brasília
#
#         Código da Escola               Nome da Escola Localização  \
# ...

# %%
df5.columns
# Out:
# Index(['Ano', 'Região', 'UF', 'Código do Município', 'Nome do Município',
#        'Código da Escola', 'Nome da Escola', 'Localização',
#        'Dependência Administrativa', 'EF_total_grupo1', 'EF_total_grupo2',
#        'EF_total_grupo3', 'EF_total_grupo4', 'EF_total_grupo5',
#        'EF_total_grupo6', 'EF_iniciais_grupo1', 'EF_iniciais_grupo2',
#        'EF_iniciais_grupo3', 'EF_iniciais_grupo4', 'EF_iniciais_grupo5',
#        'EF_iniciais_grupo6', 'EF_finais_grupo1', 'EF_finais_grupo2',
#        'EF_finais_grupo3', 'EF_finais_grupo4', 'EF_finais_grupo5',
#        'EF_finais_grupo6', 'EM_grupo1', 'EM_grupo2', 'EM_grupo3', 'EM_grupo4',
#        'EM_grupo5', 'EM_grupo6'],
#       dtype='object')

# %%
df6 = pd.read_csv('IED_ESCOLAS_2018.csv', sep=';', encoding='UTF8')
df6
# Out:
#          Ano        Região  UF  Código do Município      Nome do Município  \
# 0       2018         Norte  RO              1100015  Alta Floresta D'Oeste
# 1       2018         Norte  RO              1100015  Alta Floresta D'Oeste
# 2       2018         Norte  RO              1100015  Alta Floresta D'Oeste
# 3       2018         Norte  RO              1100015  Alta Floresta D'Oeste
# 4       2018         Norte  RO              1100015  Alta Floresta D'Oeste
# ...      ...           ...  ..                  ...                    ...
# 136172  2018  Centro-Oeste  DF              5300108               Brasília
# 136173  2018  Centro-Oeste  DF              5300108               Brasília
# 136174  2018  Centro-Oeste  DF              5300108               Brasília
# 136175  2018  Centro-Oeste  DF              5300108               Brasília
# 136176  2018  Centro-Oeste  DF              5300108               Brasília
#
#         Código da Escola               Nome da Escola Localização  \
# ...

# %%
df6.columns
# Out:
# Index(['Ano', 'Região', 'UF', 'Código do Município', 'Nome do Município',
#        'Código da Escola', 'Nome da Escola', 'Localização',
#        'Dependência Administrativa', 'EF_total_grupo1', 'EF_total_grupo2',
#        'EF_total_grupo3', 'EF_total_grupo4', 'EF_total_grupo5',
#        'EF_total_grupo6', 'EF_iniciais_grupo1', 'EF_iniciais_grupo2',
#        'EF_iniciais_grupo3', 'EF_iniciais_grupo4', 'EF_iniciais_grupo5',
#        'EF_iniciais_grupo6', 'EF_finais_grupo1', 'EF_finais_grupo2',
#        'EF_finais_grupo3', 'EF_finais_grupo4', 'EF_finais_grupo5',
#        'EF_finais_grupo6', 'EM_grupo1', 'EM_grupo2', 'EM_grupo3', 'EM_grupo4',
#        'EM_grupo5', 'EM_grupo6'],
#       dtype='object')

# %%
df7 = pd.read_csv('IED_ESCOLAS_2019.csv', sep=';', encoding='latin-1')
df7
# Out:
#          Ano        Região  UF  Código do Município      Nome do Município  \
# 0       2019         Norte  RO              1100015  Alta Floresta D'Oeste
# 1       2019         Norte  RO              1100015  Alta Floresta D'Oeste
# 2       2019         Norte  RO              1100015  Alta Floresta D'Oeste
# 3       2019         Norte  RO              1100015  Alta Floresta D'Oeste
# 4       2019         Norte  RO              1100015  Alta Floresta D'Oeste
# ...      ...           ...  ..                  ...                    ...
# 134147  2019  Centro-Oeste  DF              5300108               Brasília
# 134148  2019  Centro-Oeste  DF              5300108               Brasília
# 134149  2019  Centro-Oeste  DF              5300108               Brasília
# 134150  2019  Centro-Oeste  DF              5300108               Brasília
# 134151  2019  Centro-Oeste  DF              5300108               Brasília
#
#         Código da Escola               Nome da Escola Localização  \
# ...

# %%
df7.columns
# Out:
# Index(['Ano', 'Região', 'UF', 'Código do Município', 'Nome do Município',
#        'Código da Escola', 'Nome da Escola', 'Localização',
#        'Dependência Administrativa', 'EF_total_grupo1', 'EF_total_grupo2',
#        'EF_total_grupo3', 'EF_total_grupo4', 'EF_total_grupo5',
#        'EF_total_grupo6', 'EF_iniciais_grupo1', 'EF_iniciais_grupo2',
#        'EF_iniciais_grupo3', 'EF_iniciais_grupo4', 'EF_iniciais_grupo5',
#        'EF_iniciais_grupo6', 'EF_finais_grupo1', 'EF_finais_grupo2',
#        'EF_finais_grupo3', 'EF_finais_grupo4', 'EF_finais_grupo5',
#        'EF_finais_grupo6', 'EM_grupo1', 'EM_grupo2', 'EM_grupo3', 'EM_grupo4',
#        'EM_grupo5', 'EM_grupo6'],
#       dtype='object')

# %%
df8 = pd.read_csv('IED_ESCOLAS_2020.csv', sep=';', encoding='latin-1')
df8
# Out:
#          Ano        Região  UF  Código do Município      Nome do Município  \
# 0       2020         Norte  RO              1100015  Alta Floresta D'Oeste
# 1       2020         Norte  RO              1100015  Alta Floresta D'Oeste
# 2       2020         Norte  RO              1100015  Alta Floresta D'Oeste
# 3       2020         Norte  RO              1100015  Alta Floresta D'Oeste
# 4       2020         Norte  RO              1100015  Alta Floresta D'Oeste
# ...      ...           ...  ..                  ...                    ...
# 132897  2020  Centro-Oeste  DF              5300108               Brasília
# 132898  2020  Centro-Oeste  DF              5300108               Brasília
# 132899  2020  Centro-Oeste  DF              5300108               Brasília
# 132900  2020  Centro-Oeste  DF              5300108               Brasília
# 132901  2020  Centro-Oeste  DF              5300108               Brasília
#
#         Código da Escola               Nome da Escola Localização  \
# ...

# %%
df8.columns
# Out:
# Index(['Ano', 'Região', 'UF', 'Código do Município', 'Nome do Município',
#        'Código da Escola', 'Nome da Escola', 'Localização',
#        'Dependência Administrativa', 'EF_total_grupo1', 'EF_total_grupo2',
#        'EF_total_grupo3', 'EF_total_grupo4', 'EF_total_grupo5',
#        'EF_total_grupo6', 'EF_iniciais_grupo1', 'EF_iniciais_grupo2',
#        'EF_iniciais_grupo3', 'EF_iniciais_grupo4', 'EF_iniciais_grupo5',
#        'EF_iniciais_grupo6', 'EF_finais_grupo1', 'EF_finais_grupo2',
#        'EF_finais_grupo3', 'EF_finais_grupo4', 'EF_finais_grupo5',
#        'EF_finais_grupo6', 'EM_grupo1', 'EM_grupo2', 'EM_grupo3', 'EM_grupo4',
#        'EM_grupo5', 'EM_grupo6'],
#       dtype='object')

# %%
df9 = pd.read_csv('IED_ESCOLAS_2021.csv', sep=';', encoding="latin-1")
df9
# Out:
#          Ano        Região  UF  Código do Município      Nome do Município  \
# 0       2021         Norte  RO              1100015  Alta Floresta D'Oeste
# 1       2021         Norte  RO              1100015  Alta Floresta D'Oeste
# 2       2021         Norte  RO              1100015  Alta Floresta D'Oeste
# 3       2021         Norte  RO              1100015  Alta Floresta D'Oeste
# 4       2021         Norte  RO              1100015  Alta Floresta D'Oeste
# ...      ...           ...  ..                  ...                    ...
# 131799  2021  Centro-Oeste  DF              5300108               Brasília
# 131800  2021  Centro-Oeste  DF              5300108               Brasília
# 131801  2021  Centro-Oeste  DF              5300108               Brasília
# 131802  2021  Centro-Oeste  DF              5300108               Brasília
# 131803  2021  Centro-Oeste  DF              5300108               Brasília
#
# ...

# %%
df9.columns
# Out:
# Index(['Ano', 'Região', 'UF', 'Código do Município', 'Nome do Município',
#        'Código da Escola', 'Nome da Escola', 'Localização',
#        'Dependência Administrativa', 'EF_total_grupo1', 'EF_total_grupo2',
#        'EF_total_grupo3', 'EF_total_grupo4', 'EF_total_grupo5',
#        'EF_total_grupo6', 'EF_iniciais_grupo1', 'EF_iniciais_grupo2',
#        'EF_iniciais_grupo3', 'EF_iniciais_grupo4', 'EF_iniciais_grupo5',
#        'EF_iniciais_grupo6', 'EF_finais_grupo1', 'EF_finais_grupo2',
#        'EF_finais_grupo3', 'EF_finais_grupo4', 'EF_finais_grupo5',
#        'EF_finais_grupo6', 'EM_grupo1', 'EM_grupo2', 'EM_grupo3', 'EM_grupo4',
#        'EM_grupo5', 'EM_grupo6'],
#       dtype='object')

# %%
df10 = pd.read_csv('IED_ESCOLAS_2022.csv', sep=';', encoding='latin-1')
df10
# Out:
#          Ano        Região  UF  Código do Município      Nome do Município  \
# 0       2022         Norte  RO              1100015  Alta Floresta D'Oeste
# 1       2022         Norte  RO              1100015  Alta Floresta D'Oeste
# 2       2022         Norte  RO              1100015  Alta Floresta D'Oeste
# 3       2022         Norte  RO              1100015  Alta Floresta D'Oeste
# 4       2022         Norte  RO              1100015  Alta Floresta D'Oeste
# ...      ...           ...  ..                  ...                    ...
# 130902  2022  Centro-Oeste  DF              5300108               Brasília
# 130903  2022  Centro-Oeste  DF              5300108               Brasília
# 130904  2022  Centro-Oeste  DF              5300108               Brasília
# 130905  2022  Centro-Oeste  DF              5300108               Brasília
# 130906  2022  Centro-Oeste  DF              5300108               Brasília
#
# ...

# %%
df10.columns
# Out:
# Index(['Ano', 'Região', 'UF', 'Código do Município', 'Nome do Município',
#        'Código da Escola', 'Nome da Escola', 'Localização',
#        'Dependência Administrativa', 'EF_total_grupo1', 'EF_total_grupo2',
#        'EF_total_grupo3', 'EF_total_grupo4', 'EF_total_grupo5',
#        'EF_total_grupo6', 'EF_iniciais_grupo1', 'EF_iniciais_grupo2',
#        'EF_iniciais_grupo3', 'EF_iniciais_grupo4', 'EF_iniciais_grupo5',
#        'EF_iniciais_grupo6', 'EF_finais_grupo1', 'EF_finais_grupo2',
#        'EF_finais_grupo3', 'EF_finais_grupo4', 'EF_finais_grupo5',
#        'EF_finais_grupo6', 'EM_grupo1', 'EM_grupo2', 'EM_grupo3', 'EM_grupo4',
#        'EM_grupo5', 'EM_grupo6'],
#       dtype='object')

# %%
df = pd.concat([df1,df2,df3,df4,df5,df6,df7,df8,df9,df10])
df
# Out:
#          Ano        Região  UF  Código do Município      Nome do Município  \
# 0       2013         Norte  RO              1100015  ALTA FLORESTA D OESTE
# 1       2013         Norte  RO              1100015  ALTA FLORESTA D OESTE
# 2       2013         Norte  RO              1100015  ALTA FLORESTA D OESTE
# 3       2013         Norte  RO              1100015  ALTA FLORESTA D OESTE
# 4       2013         Norte  RO              1100015  ALTA FLORESTA D OESTE
# ...      ...           ...  ..                  ...                    ...
# 130902  2022  Centro-Oeste  DF              5300108               Brasília
# 130903  2022  Centro-Oeste  DF              5300108               Brasília
# 130904  2022  Centro-Oeste  DF              5300108               Brasília
# 130905  2022  Centro-Oeste  DF              5300108               Brasília
# 130906  2022  Centro-Oeste  DF              5300108               Brasília
#
# ...

# %%
df.columns
# Out:
# Index(['Ano', 'Região', 'UF', 'Código do Município', 'Nome do Município',
#        'Código da Escola', 'Nome da Escola', 'Localização',
#        'Dependência Administrativa', 'EF_total_grupo1', 'EF_total_grupo2',
#        'EF_total_grupo3', 'EF_total_grupo4', 'EF_total_grupo5',
#        'EF_total_grupo6', 'EF_iniciais_grupo1', 'EF_iniciais_grupo2',
#        'EF_iniciais_grupo3', 'EF_iniciais_grupo4', 'EF_iniciais_grupo5',
#        'EF_iniciais_grupo6', 'EF_finais_grupo1', 'EF_finais_grupo2',
#        'EF_finais_grupo3', 'EF_finais_grupo4', 'EF_finais_grupo5',
#        'EF_finais_grupo6', 'EM_grupo1', 'EM_grupo2', 'EM_grupo3', 'EM_grupo4',
#        'EM_grupo5', 'EM_grupo6'],
#       dtype='object')

# %%
df['Ano'].unique()
# Out:
# array([2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022],
#       dtype=int64)

# %%
#Padronizando todos os nomes das colunas para o Big Query
df = df.rename(columns= {'Ano':'ano', 
                        'Região':'nome_regiao', 
                        'UF': 'sigla_uf', 
                        'Código do Município':'id_municipio',
                        'Nome do Município':'nome_municipio',
                        'Código da Escola':'id_escola',
                        'Nome da Escola':'nome_escola',
                        'Localização':'localizacao',
                        'Dependência Administrativa':'dependencia_adm',
                        'EF_total_grupo1':'ef_total_grupo1', 
                        'EF_total_grupo2':'ef_total_grupo2',
                        'EF_total_grupo3':'ef_total_grupo3', 
                        'EF_total_grupo4':'ef_total_grupo4', 
                        'EF_total_grupo5':'ef_total_grupo5',
                        'EF_total_grupo6':'ef_total_grupo6', 
                        'EF_iniciais_grupo1':'ef_iniciais_grupo1', 
                        'EF_iniciais_grupo2':'ef_iniciais_grupo2',
                        'EF_iniciais_grupo3':'ef_iniciais_grupo3', 
                        'EF_iniciais_grupo4':'ef_iniciais_grupo4',  
                        'EF_iniciais_grupo5':'ef_iniciais_grupo5',
                        'EF_iniciais_grupo6':'ef_iniciais_grupo6', 
                        'EF_finais_grupo1':'ef_finais_grupo1', 
                        'EF_finais_grupo2':'ef_finais_grupo2',
                        'EF_finais_grupo3':'ef_finais_grupo3', 
                        'EF_finais_grupo4':'ef_finais_grupo4', 
                        'EF_finais_grupo5':'ef_finais_grupo5',
                        'EF_finais_grupo6':'ef_finais_grupo6', 
                        'EM_grupo1':'em_grupo1', 
                        'EM_grupo2':'em_grupo2', 
                        'EM_grupo3':'em_grupo3', 
                        'EM_grupo4':'em_grupo4',
                        'EM_grupo5':'em_grupo5', 
                        'EM_grupo6':'em_grupo6'})
df
# Out:
#          ano   nome_regiao sigla_uf  id_municipio         nome_municipio  \
# 0       2013         Norte       RO       1100015  ALTA FLORESTA D OESTE
# 1       2013         Norte       RO       1100015  ALTA FLORESTA D OESTE
# 2       2013         Norte       RO       1100015  ALTA FLORESTA D OESTE
# 3       2013         Norte       RO       1100015  ALTA FLORESTA D OESTE
# 4       2013         Norte       RO       1100015  ALTA FLORESTA D OESTE
# ...      ...           ...      ...           ...                    ...
# 130902  2022  Centro-Oeste       DF       5300108               Brasília
# 130903  2022  Centro-Oeste       DF       5300108               Brasília
# 130904  2022  Centro-Oeste       DF       5300108               Brasília
# 130905  2022  Centro-Oeste       DF       5300108               Brasília
# 130906  2022  Centro-Oeste       DF       5300108               Brasília
#
#         id_escola                     nome_escola localizacao dependencia_adm  \
# ...

# %%
df.columns
# Out:
# Index(['ano', 'nome_regiao', 'sigla_uf', 'id_municipio', 'nome_municipio',
#        'id_escola', 'nome_escola', 'localizacao', 'dependencia_adm',
#        'ef_total_grupo1', 'ef_total_grupo2', 'ef_total_grupo3',
#        'ef_total_grupo4', 'ef_total_grupo5', 'ef_total_grupo6',
#        'ef_iniciais_grupo1', 'ef_iniciais_grupo2', 'ef_iniciais_grupo3',
#        'ef_iniciais_grupo4', 'ef_iniciais_grupo5', 'ef_iniciais_grupo6',
#        'ef_finais_grupo1', 'ef_finais_grupo2', 'ef_finais_grupo3',
#        'ef_finais_grupo4', 'ef_finais_grupo5', 'ef_finais_grupo6', 'em_grupo1',
#        'em_grupo2', 'em_grupo3', 'em_grupo4', 'em_grupo5', 'em_grupo6'],
#       dtype='object')

# %%
df = df.replace('--', np.nan) #transformando os valores '--' como  NaN

# %%
transformar_float = ['ef_total_grupo1', 'ef_total_grupo2', 'ef_total_grupo3',
       'ef_total_grupo4', 'ef_total_grupo5', 'ef_total_grupo6',
       'ef_iniciais_grupo1', 'ef_iniciais_grupo2', 'ef_iniciais_grupo3',
       'ef_iniciais_grupo4', 'ef_iniciais_grupo5', 'ef_iniciais_grupo6',
       'ef_finais_grupo1', 'ef_finais_grupo2', 'ef_finais_grupo3',
       'ef_finais_grupo4', 'ef_finais_grupo5', 'ef_finais_grupo6', 'em_grupo1',
       'em_grupo2', 'em_grupo3', 'em_grupo4', 'em_grupo5', 'em_grupo6'] #definindo uma variável para todas as colunas

# %%
for coluna in transformar_float:
    df[coluna] = df[coluna].str.replace(',', '.').astype(float)

# %%
df.dtypes #conferindo
# Out:
# ano                     int64
# nome_regiao            object
# sigla_uf               object
# id_municipio            int64
# nome_municipio         object
# id_escola               int64
# nome_escola            object
# localizacao            object
# dependencia_adm        object
# ef_total_grupo1       float64
# ef_total_grupo2       float64
# ef_total_grupo3       float64
# ef_total_grupo4       float64
# ef_total_grupo5       float64
# ef_total_grupo6       float64
# ef_iniciais_grupo1    float64
# ef_iniciais_grupo2    float64
# ef_iniciais_grupo3    float64
# ef_iniciais_grupo4    float64
# ef_iniciais_grupo5    float64
# ef_iniciais_grupo6    float64
# ef_finais_grupo1      float64
# ef_finais_grupo2      float64
# ef_finais_grupo3      float64
# ef_finais_grupo4      float64
# ef_finais_grupo5      float64
# ef_finais_grupo6      float64
# em_grupo1             float64
# em_grupo2             float64
# em_grupo3             float64
# em_grupo4             float64
# ...

# %%
df.to_csv('INEP_esforco_docente.csv',index=False, encoding="latin-1", sep=';', decimal=',')

# %% [markdown]
# Subindo para o GBQ

# %%
client = bigquery.Client()
dataset_ref = client.dataset('Datalake')

# %%
schema = [bigquery.SchemaField('ano', 'INTEGER', description= 'Ano de referência da observação'),
          bigquery.SchemaField('nome_regiao', 'STRING', description= 'Região do Brasil abrangente a observação'),
          bigquery.SchemaField('sigla_uf', 'STRING', description= 'Sigla da Unidade da Federação referente aquela observação'),
          bigquery.SchemaField('id_municipio', 'INTEGER', description= 'Identificador do município pelo IBGE'),
          bigquery.SchemaField('nome_municipio', 'STRING', description= 'Nome do município da observação'),                    
          bigquery.SchemaField('id_escola', 'INTEGER', description= 'Identificação da escola'),                    
          bigquery.SchemaField('nome_escola', 'STRING', description= 'Nome da escola observada'),                    
          bigquery.SchemaField('localizacao', 'STRING', description= 'Se a área da observação é urbana ou rural'),                    
          bigquery.SchemaField('dependencia_adm', 'STRING', description= 'Dependência admnistrativa da observação (privada ou pública)'),                   
          bigquery.SchemaField('ef_total_grupo1', 'FLOAT', description= 'Docentes de todos os anos do Ensino Fundamental que, em geral, tem até 25 alunos e atua em um único turno, escola e etapa'),                   
          bigquery.SchemaField('ef_total_grupo2', 'FLOAT', description= 'Docentes de todos os anos do Ensino Fundamental que, em geral, tem entre 25 e 150 alunos e atua em um único turno, escola e etapa'),                   
          bigquery.SchemaField('ef_total_grupo3', 'FLOAT', description= 'Docentes de todos os anos do Ensino Fundamental que, em geral, tem entre 25 e 300 alunos e atua em um ou dois turnos em uma única escola e etapa'),                   
          bigquery.SchemaField('ef_total_grupo4', 'FLOAT', description= 'Docentes de todos os anos do Ensino Fundamental que, em geral, tem entre 50 e 400 alunos e atua em dois turnos, em uma ou duas escolas e em duas etapas'),                   
          bigquery.SchemaField('ef_total_grupo5', 'FLOAT', description= 'Docentes de todos os anos do Ensino Fundamental que, em geral, tem mais de 300 alunos e atua nos três turnos, em duas ou três escolas e em duas etapas ou três etapas'),                   
          bigquery.SchemaField('ef_total_grupo6', 'FLOAT', description= 'Docentes de todos os anos do Ensino Fundamental que, em geral, tem mais de 400 alunos e atua nos três turnos, em duas ou três escolas e em duas etapas ou três etapas'),                   
          bigquery.SchemaField('ef_iniciais_grupo1', 'FLOAT', description= 'Docentes dos anos iniciais do Ensino Fundamental que, em geral, tem até 25 alunos e atua em um único turno, escola e etapa'),                   
          bigquery.SchemaField('ef_iniciais_grupo2', 'FLOAT', description= 'Docentes dos anos iniciais do Ensino Fundamental que, em geral, tem entre 25 e 150 alunos e atua em um único turno, escola e etapa'),                   
          bigquery.SchemaField('ef_iniciais_grupo3', 'FLOAT', description= 'Docentes dos anos iniciais do Ensino Fundamental que, em geral, tem entre 25 e 300 alunos e atua em um ou dois turnos em uma única escola e etapa'),                   
          bigquery.SchemaField('ef_iniciais_grupo4', 'FLOAT', description= 'Docentes dos anos iniciais do Ensino Fundamental que, em geral, tem entre 50 e 400 alunos e atua em dois turnos, em uma ou duas escolas e em duas etapas'),                   
          bigquery.SchemaField('ef_iniciais_grupo5', 'FLOAT', description= 'Docentes dos anos iniciais do Ensino Fundamental que, em geral, tem mais de 300 alunos e atua nos três turnos, em duas ou três escolas e em duas etapas ou três etapas'),                   
          bigquery.SchemaField('ef_iniciais_grupo6', 'FLOAT', description= 'Docentes dos anos iniciais do Ensino Fundamental que, em geral, tem mais de 400 alunos e atua nos três turnos, em duas ou três escolas e em duas etapas ou três etapas'),                   
          bigquery.SchemaField('ef_finais_grupo1', 'FLOAT', description= 'Docentes dos anos finais do Ensino Fundamental que, em geral, tem até 25 alunos e atua em um único turno, escola e etapa'),                   
          bigquery.SchemaField('ef_finais_grupo2', 'FLOAT', description= 'Docentes dos anos finais do Ensino Fundamental que, em geral, tem entre 25 e 150 alunos e atua em um único turno, escola e etapa'),                   
          bigquery.SchemaField('ef_finais_grupo3', 'FLOAT', description= 'Docentes dos anos finais do Ensino Fundamental que, em geral, tem entre 25 e 300 alunos e atua em um ou dois turnos em uma única escola e etapa'),                   
          bigquery.SchemaField('ef_finais_grupo4', 'FLOAT', description= 'Docentes dos anos finais do Ensino Fundamental que, em geral, tem entre 50 e 400 alunos e atua em dois turnos, em uma ou duas escolas e em duas etapas'),                   
          bigquery.SchemaField('ef_finais_grupo5', 'FLOAT', description= 'Docentes dos anos finais do Ensino Fundamental que, em geral, tem mais de 300 alunos e atua nos três turnos, em duas ou três escolas e em duas etapas ou três etapas'),                   
          bigquery.SchemaField('ef_finais_grupo6', 'FLOAT', description= 'Docentes dos anos finais do Ensino Fundamental que, em geral, tem mais de 400 alunos e atua nos três turnos, em duas ou três escolas e em duas etapas ou três etapas'),                   
          bigquery.SchemaField('em_grupo1', 'FLOAT', description= 'Docentes do Ensino Médio que, em geral, tem até 25 alunos e atua em um único turno, escola e etapa'),                   
          bigquery.SchemaField('em_grupo2', 'FLOAT', description= 'Docentes do Ensino Médio que, em geral, tem entre 25 e 150 alunos e atua em um único turno, escola e etapa'),                   
          bigquery.SchemaField('em_grupo3', 'FLOAT', description= 'Docentes do Ensino Médio que, em geral, tem entre 25 e 300 alunos e atua em um ou dois turnos em uma única escola e etapa. '),                   
          bigquery.SchemaField('em_grupo4', 'FLOAT', description= 'Docentes do Ensino Médio que, em geral, tem entre 50 e 400 alunos e atua em dois turnos, em uma ou duas escolas e em duas etapas'),                   
          bigquery.SchemaField('em_grupo5', 'FLOAT', description= 'Docentes do Ensino Médio que, em geral, tem mais de 300 alunos e atua nos três turnos, em duas ou três escolas e em duas etapas ou três etapas'),                   
          bigquery.SchemaField('em_grupo6', 'FLOAT', description= 'Docentes do Ensino Médio que, em geral, tem mais de 400 alunos e atua nos três turnos, em duas ou três escolas e em duas etapas ou três etapas'),                         
          ]

# %%
table_ref = dataset_ref.table('INEP_esforco_docente')
job_config = bigquery.LoadJobConfig(schema=schema)
job = client.load_table_from_dataframe(df, table_ref, job_config=job_config)
job.result()
# Out:
# LoadJob<project=repositoriodedadosgpsp, location=US, id=a0062a56-d31f-4020-946d-432ead6dd344>
