# %%
##importando pacotes
import pandas as pd
#import matplotlib.pyplot as plt
import numpy as np
import time
import os
import pandas_gbq
from google.cloud import bigquery
import glob
import openpyxl
import csv

# %%
os.chdir('G:\\\\Drives compartilhados\\\\República.org\\\\4. Equipes\\\\Dados e Comunicação\\\\DADOS\\\\415 - Repositório de Dados\\\\Dados para subir\\\\Dados Brutos\\\\INEP\\\\Adequação Formação Docente')

# %%
df1 = pd.read_csv('AFD_ESCOLAS_2013.csv', delimiter=',')
df1
# Out:
#          Ano        Região  UF  Código do Município      Nome do Município  \
# 0       2013         Norte  RO              1100015  ALTA FLORESTA D OESTE
# 1       2013         Norte  RO              1100015  ALTA FLORESTA D OESTE
# 2       2013         Norte  RO              1100015  ALTA FLORESTA D OESTE
# 3       2013         Norte  RO              1100015  ALTA FLORESTA D OESTE
# 4       2013         Norte  RO              1100015  ALTA FLORESTA D OESTE
# ...      ...           ...  ..                  ...                    ...
# 187482  2013  Centro_Oeste  DF              5300108               BRASILIA
# 187483  2013  Centro_Oeste  DF              5300108               BRASILIA
# 187484  2013  Centro_Oeste  DF              5300108               BRASILIA
# 187485  2013  Centro_Oeste  DF              5300108               BRASILIA
# 187486  2013  Centro_Oeste  DF              5300108               BRASILIA
#
# ...

# %%
df1.columns
# Out:
# Index(['Ano', 'Região', 'UF', 'Código do Município', 'Nome do Município',
#        'Código da Escola', 'Nome da Escola', 'Localização',
#        'Dependência Administrativa', 'EI_grupo1', 'EI_grupo2', 'EI_grupo3',
#        'EI_grupo4', 'EI_grupo5', 'EF_total_grupo1', 'EF_total_grupo2',
#        'EF_total_grupo3', 'EF_total_grupo4', 'EF_total_grupo5',
#        'EF_iniciais_grupo1', 'EF_iniciais_grupo2', 'EF_iniciais_grupo3',
#        'EF_iniciais_grupo4', 'EF_iniciais_grupo5', 'EF_finais_grupo1',
#        'EF_finais_grupo2', 'EF_finais_grupo3', 'EF_finais_grupo4',
#        'EF_finais_grupo5', 'EM_grupo1', 'EM_grupo2', 'EM_grupo3', 'EM_grupo4',
#        'EM_grupo5', 'EJA_EF_grupo1', 'EJA_EF_grupo2', 'EJA_EF_grupo3',
#        'EJA_EF_grupo4', 'EJA_EF_grupo5', 'EJA_EM_grupo1', 'EJA_EM_grupo2',
#        'EJA_EM_grupo3', 'EJA_EM_grupo4', 'EJA_EM_grupo5'],
#       dtype='object')

# %%
df2= pd.read_csv('AFD_ESCOLAS_2014.csv',sep=',')
df2
# Out:
#          Ano        Região  UF  Código do Município      Nome do Município  \
# 0       2014         Norte  RO              1100015  ALTA FLORESTA D OESTE
# 1       2014         Norte  RO              1100015  ALTA FLORESTA D OESTE
# 2       2014         Norte  RO              1100015  ALTA FLORESTA D OESTE
# 3       2014         Norte  RO              1100015  ALTA FLORESTA D OESTE
# 4       2014         Norte  RO              1100015  ALTA FLORESTA D OESTE
# ...      ...           ...  ..                  ...                    ...
# 184896  2014  Centro_Oeste  DF              5300108               BRASILIA
# 184897  2014  Centro_Oeste  DF              5300108               BRASILIA
# 184898  2014  Centro_Oeste  DF              5300108               BRASILIA
# 184899  2014  Centro_Oeste  DF              5300108               BRASILIA
# 184900  2014  Centro_Oeste  DF              5300108               BRASILIA
#
# ...

# %%
df2.columns
# Out:
# Index(['Ano', 'Região', 'UF', 'Código do Município', 'Nome do Município',
#        'Código da Escola', 'Nome da Escola', 'Localização',
#        'Dependência Administrativa', 'EI_grupo1', 'EI_grupo2', 'EI_grupo3',
#        'EI_grupo4', 'EI_grupo5', 'EF_total_grupo1', 'EF_total_grupo2',
#        'EF_total_grupo3', 'EF_total_grupo4', 'EF_total_grupo5',
#        'EF_iniciais_grupo1', 'EF_iniciais_grupo2', 'EF_iniciais_grupo3',
#        'EF_iniciais_grupo4', 'EF_iniciais_grupo5', 'EF_finais_grupo1',
#        'EF_finais_grupo2', 'EF_finais_grupo3', 'EF_finais_grupo4',
#        'EF_finais_grupo5', 'EM_grupo1', 'EM_grupo2', 'EM_grupo3', 'EM_grupo4',
#        'EM_grupo5', 'EJA_EF_grupo1', 'EJA_EF_grupo2', 'EJA_EF_grupo3',
#        'EJA_EF_grupo4', 'EJA_EF_grupo5', 'EJA_EM_grupo1', 'EJA_EM_grupo2',
#        'EJA_EM_grupo3', 'EJA_EM_grupo4', 'EJA_EM_grupo5'],
#       dtype='object')

# %%
df3 = pd.read_csv('AFD_ESCOLAS_2015.csv', sep=',')
df3
# Out:
#          Ano        Região  UF  Código do Município      Nome do Município  \
# 0       2015         Norte  RO              1100015  ALTA FLORESTA D OESTE
# 1       2015         Norte  RO              1100015  ALTA FLORESTA D OESTE
# 2       2015         Norte  RO              1100015  ALTA FLORESTA D OESTE
# 3       2015         Norte  RO              1100015  ALTA FLORESTA D OESTE
# 4       2015         Norte  RO              1100015  ALTA FLORESTA D OESTE
# ...      ...           ...  ..                  ...                    ...
# 182601  2015  Centro-Oeste  DF              5300108               BRASILIA
# 182602  2015  Centro-Oeste  DF              5300108               BRASILIA
# 182603  2015  Centro-Oeste  DF              5300108               BRASILIA
# 182604  2015  Centro-Oeste  DF              5300108               BRASILIA
# 182605  2015  Centro-Oeste  DF              5300108               BRASILIA
#
# ...

# %%
df3.columns
# Out:
# Index(['Ano', 'Região', 'UF', 'Código do Município', 'Nome do Município',
#        'Código da Escola', 'Nome da Escola', 'Localização',
#        'Dependência Administrativa', 'EI_grupo1', 'EI_grupo2', 'EI_grupo3',
#        'EI_grupo4', 'EI_grupo5', 'EF_total_grupo1', 'EF_total_grupo2',
#        'EF_total_grupo3', 'EF_total_grupo4', 'EF_total_grupo5',
#        'EF_iniciais_grupo1', 'EF_iniciais_grupo2', 'EF_iniciais_grupo3',
#        'EF_iniciais_grupo4', 'EF_iniciais_grupo5', 'EF_finais_grupo1',
#        'EF_finais_grupo2', 'EF_finais_grupo3', 'EF_finais_grupo4',
#        'EF_finais_grupo5', 'EM_grupo1', 'EM_grupo2', 'EM_grupo3', 'EM_grupo4',
#        'EM_grupo5', 'EJA_EF_grupo1', 'EJA_EF_grupo2', 'EJA_EF_grupo3',
#        'EJA_EF_grupo4', 'EJA_EF_grupo5', 'EJA_EM_grupo1', 'EJA_EM_grupo2',
#        'EJA_EM_grupo3', 'EJA_EM_grupo4', 'EJA_EM_grupo5'],
#       dtype='object')

# %%
df4=pd.read_csv('AFD_ESCOLAS_2016.csv', sep=',')
df4
# Out:
#          Ano        Região  UF  Código do Município      Nome do Município  \
# 0       2016         Norte  RO              1100015  Alta Floresta D'Oeste
# 1       2016         Norte  RO              1100015  Alta Floresta D'Oeste
# 2       2016         Norte  RO              1100015  Alta Floresta D'Oeste
# 3       2016         Norte  RO              1100015  Alta Floresta D'Oeste
# 4       2016         Norte  RO              1100015  Alta Floresta D'Oeste
# ...      ...           ...  ..                  ...                    ...
# 182629  2016  Centro-Oeste  DF              5300108               Brasília
# 182630  2016  Centro-Oeste  DF              5300108               Brasília
# 182631  2016  Centro-Oeste  DF              5300108               Brasília
# 182632  2016  Centro-Oeste  DF              5300108               Brasília
# 182633  2016  Centro-Oeste  DF              5300108               Brasília
#
#         Código da Escola            Nome da Escola Localização  \
# ...

# %%
df4.columns
# Out:
# Index(['Ano', 'Região', 'UF', 'Código do Município', 'Nome do Município',
#        'Código da Escola', 'Nome da Escola', 'Localização',
#        'Dependência Administrativa', 'EI_grupo1', 'EI_grupo2', 'EI_grupo3',
#        'EI_grupo4', 'EI_grupo5', 'EF_total_grupo1', 'EF_total_grupo2',
#        'EF_total_grupo3', 'EF_total_grupo4', 'EF_total_grupo5',
#        'EF_iniciais_grupo1', 'EF_iniciais_grupo2', 'EF_iniciais_grupo3',
#        'EF_iniciais_grupo4', 'EF_iniciais_grupo5', 'EF_finais_grupo1',
#        'EF_finais_grupo2', 'EF_finais_grupo3', 'EF_finais_grupo4',
#        'EF_finais_grupo5', 'EM_grupo1', 'EM_grupo2', 'EM_grupo3', 'EM_grupo4',
#        'EM_grupo5', 'EJA_EF_grupo1', 'EJA_EF_grupo2', 'EJA_EF_grupo3',
#        'EJA_EF_grupo4', 'EJA_EF_grupo5', 'EJA_EM_grupo1', 'EJA_EM_grupo2',
#        'EJA_EM_grupo3', 'EJA_EM_grupo4', 'EJA_EM_grupo5'],
#       dtype='object')

# %%
df5 = pd.read_csv('AFD_ESCOLAS_2017.csv', sep=';')
df5
# Out:
#          Ano        Região  UF  Código do Município      Nome do Município  \
# 0       2017         Norte  RO              1100015  Alta Floresta D'Oeste
# 1       2017         Norte  RO              1100015  Alta Floresta D'Oeste
# 2       2017         Norte  RO              1100015  Alta Floresta D'Oeste
# 3       2017         Norte  RO              1100015  Alta Floresta D'Oeste
# 4       2017         Norte  RO              1100015  Alta Floresta D'Oeste
# ...      ...           ...  ..                  ...                    ...
# 180951  2017  Centro-Oeste  DF              5300108               Brasília
# 180952  2017  Centro-Oeste  DF              5300108               Brasília
# 180953  2017  Centro-Oeste  DF              5300108               Brasília
# 180954  2017  Centro-Oeste  DF              5300108               Brasília
# 180955  2017  Centro-Oeste  DF              5300108               Brasília
#
#         Código da Escola            Nome da Escola Localização  \
# ...

# %%
df5.columns
# Out:
# Index(['Ano', 'Região', 'UF', 'Código do Município', 'Nome do Município',
#        'Código da Escola', 'Nome da Escola', 'Localização',
#        'Dependência Administrativa', 'EI_grupo1', 'EI_grupo2', 'EI_grupo3',
#        'EI_grupo4', 'EI_grupo5', 'EF_total_grupo1', 'EF_total_grupo2',
#        'EF_total_grupo3', 'EF_total_grupo4', 'EF_total_grupo5',
#        'EF_iniciais_grupo1', 'EF_iniciais_grupo2', 'EF_iniciais_grupo3',
#        'EF_iniciais_grupo4', 'EF_iniciais_grupo5', 'EF_finais_grupo1',
#        'EF_finais_grupo2', 'EF_finais_grupo3', 'EF_finais_grupo4',
#        'EF_finais_grupo5', 'EM_grupo1', 'EM_grupo2', 'EM_grupo3', 'EM_grupo4',
#        'EM_grupo5', 'EJA_EF_grupo1', 'EJA_EF_grupo2', 'EJA_EF_grupo3',
#        'EJA_EF_grupo4', 'EJA_EF_grupo5', 'EJA_EM_grupo1', 'EJA_EM_grupo2',
#        'EJA_EM_grupo3', 'EJA_EM_grupo4', 'EJA_EM_grupo5'],
#       dtype='object')

# %%
df6 = pd.read_csv('AFD_ESCOLAS_2018.csv', sep=';')
df6
# Out:
#          Ano        Região  UF  Código do Município      Nome do Município  \
# 0       2018         Norte  RO              1100015  Alta Floresta D'Oeste
# 1       2018         Norte  RO              1100015  Alta Floresta D'Oeste
# 2       2018         Norte  RO              1100015  Alta Floresta D'Oeste
# 3       2018         Norte  RO              1100015  Alta Floresta D'Oeste
# 4       2018         Norte  RO              1100015  Alta Floresta D'Oeste
# ...      ...           ...  ..                  ...                    ...
# 178892  2018  Centro-Oeste  DF              5300108               Brasília
# 178893  2018  Centro-Oeste  DF              5300108               Brasília
# 178894  2018  Centro-Oeste  DF              5300108               Brasília
# 178895  2018  Centro-Oeste  DF              5300108               Brasília
# 178896  2018  Centro-Oeste  DF              5300108               Brasília
#
#         Código da Escola            Nome da Escola Localização  \
# ...

# %%
df6.columns
# Out:
# Index(['Ano', 'Região', 'UF', 'Código do Município', 'Nome do Município',
#        'Código da Escola', 'Nome da Escola', 'Localização',
#        'Dependência Administrativa', 'EI_grupo1', 'EI_grupo2', 'EI_grupo3',
#        'EI_grupo4', 'EI_grupo5', 'EF_total_grupo1', 'EF_total_grupo2',
#        'EF_total_grupo3', 'EF_total_grupo4', 'EF_total_grupo5',
#        'EF_iniciais_grupo1', 'EF_iniciais_grupo2', 'EF_iniciais_grupo3',
#        'EF_iniciais_grupo4', 'EF_iniciais_grupo5', 'EF_finais_grupo1',
#        'EF_finais_grupo2', 'EF_finais_grupo3', 'EF_finais_grupo4',
#        'EF_finais_grupo5', 'EM_grupo1', 'EM_grupo2', 'EM_grupo3', 'EM_grupo4',
#        'EM_grupo5', 'EJA_EF_grupo1', 'EJA_EF_grupo2', 'EJA_EF_grupo3',
#        'EJA_EF_grupo4', 'EJA_EF_grupo5', 'EJA_EM_grupo1', 'EJA_EM_grupo2',
#        'EJA_EM_grupo3', 'EJA_EM_grupo4', 'EJA_EM_grupo5'],
#       dtype='object')

# %%
df7 = pd.read_csv('AFD_ESCOLAS_2019.csv', sep=';')
df7
# Out:
#          Ano        Região  UF  Código do Município      Nome do Município  \
# 0       2019         Norte  RO              1100015  Alta Floresta D'Oeste
# 1       2019         Norte  RO              1100015  Alta Floresta D'Oeste
# 2       2019         Norte  RO              1100015  Alta Floresta D'Oeste
# 3       2019         Norte  RO              1100015  Alta Floresta D'Oeste
# 4       2019         Norte  RO              1100015  Alta Floresta D'Oeste
# ...      ...           ...  ..                  ...                    ...
# 177709  2019  Centro-Oeste  DF              5300108               Brasília
# 177710  2019  Centro-Oeste  DF              5300108               Brasília
# 177711  2019  Centro-Oeste  DF              5300108               Brasília
# 177712  2019  Centro-Oeste  DF              5300108               Brasília
# 177713  2019  Centro-Oeste  DF              5300108               Brasília
#
#         Código da Escola            Nome da Escola Localização  \
# ...

# %%
df7.columns
# Out:
# Index(['Ano', 'Região', 'UF', 'Código do Município', 'Nome do Município',
#        'Código da Escola', 'Nome da Escola', 'Localização',
#        'Dependência Administrativa', 'EI_grupo1', 'EI_grupo2', 'EI_grupo3',
#        'EI_grupo4', 'EI_grupo5', 'EF_total_grupo1', 'EF_total_grupo2',
#        'EF_total_grupo3', 'EF_total_grupo4', 'EF_total_grupo5',
#        'EF_iniciais_grupo1', 'EF_iniciais_grupo2', 'EF_iniciais_grupo3',
#        'EF_iniciais_grupo4', 'EF_iniciais_grupo5', 'EF_finais_grupo1',
#        'EF_finais_grupo2', 'EF_finais_grupo3', 'EF_finais_grupo4',
#        'EF_finais_grupo5', 'EM_grupo1', 'EM_grupo2', 'EM_grupo3', 'EM_grupo4',
#        'EM_grupo5', 'EJA_EF_grupo1', 'EJA_EF_grupo2', 'EJA_EF_grupo3',
#        'EJA_EF_grupo4', 'EJA_EF_grupo5', 'EJA_EM_grupo1', 'EJA_EM_grupo2',
#        'EJA_EM_grupo3', 'EJA_EM_grupo4', 'EJA_EM_grupo5'],
#       dtype='object')

# %%
df8 = pd.read_csv('AFD_ESCOLAS_2020.csv', sep=';')
df8
# Out:
#          Ano        Região  UF  Código do Município      Nome do Município  \
# 0       2020         Norte  RO              1100015  Alta Floresta D'Oeste
# 1       2020         Norte  RO              1100015  Alta Floresta D'Oeste
# 2       2020         Norte  RO              1100015  Alta Floresta D'Oeste
# 3       2020         Norte  RO              1100015  Alta Floresta D'Oeste
# 4       2020         Norte  RO              1100015  Alta Floresta D'Oeste
# ...      ...           ...  ..                  ...                    ...
# 176552  2020  Centro-Oeste  DF              5300108               Brasília
# 176553  2020  Centro-Oeste  DF              5300108               Brasília
# 176554  2020  Centro-Oeste  DF              5300108               Brasília
# 176555  2020  Centro-Oeste  DF              5300108               Brasília
# 176556  2020  Centro-Oeste  DF              5300108               Brasília
#
#         Código da Escola            Nome da Escola Localização  \
# ...

# %%
df8.columns
# Out:
# Index(['Ano', 'Região', 'UF', 'Código do Município', 'Nome do Município',
#        'Código da Escola', 'Nome da Escola', 'Localização',
#        'Dependência Administrativa', 'EI_grupo1', 'EI_grupo2', 'EI_grupo3',
#        'EI_grupo4', 'EI_grupo5', 'EF_total_grupo1', 'EF_total_grupo2',
#        'EF_total_grupo3', 'EF_total_grupo4', 'EF_total_grupo5',
#        'EF_iniciais_grupo1', 'EF_iniciais_grupo2', 'EF_iniciais_grupo3',
#        'EF_iniciais_grupo4', 'EF_iniciais_grupo5', 'EF_finais_grupo1',
#        'EF_finais_grupo2', 'EF_finais_grupo3', 'EF_finais_grupo4',
#        'EF_finais_grupo5', 'EM_grupo1', 'EM_grupo2', 'EM_grupo3', 'EM_grupo4',
#        'EM_grupo5', 'EJA_EF_grupo1', 'EJA_EF_grupo2', 'EJA_EF_grupo3',
#        'EJA_EF_grupo4', 'EJA_EF_grupo5', 'EJA_EM_grupo1', 'EJA_EM_grupo2',
#        'EJA_EM_grupo3', 'EJA_EM_grupo4', 'EJA_EM_grupo5'],
#       dtype='object')

# %%
df9 = pd.read_csv('AFD_ESCOLAS_2021.csv', sep=',')
df9
# Out:
#          Ano        Região  UF  Código do Município      Nome do Município  \
# 0       2021         Norte  RO              1100015  Alta Floresta D'Oeste
# 1       2021         Norte  RO              1100015  Alta Floresta D'Oeste
# 2       2021         Norte  RO              1100015  Alta Floresta D'Oeste
# 3       2021         Norte  RO              1100015  Alta Floresta D'Oeste
# 4       2021         Norte  RO              1100015  Alta Floresta D'Oeste
# ...      ...           ...  ..                  ...                    ...
# 175588  2021  Centro-Oeste  DF              5300108               Brasília
# 175589  2021  Centro-Oeste  DF              5300108               Brasília
# 175590  2021  Centro-Oeste  DF              5300108               Brasília
# 175591  2021  Centro-Oeste  DF              5300108               Brasília
# 175592  2021  Centro-Oeste  DF              5300108               Brasília
#
#         Código da Escola            Nome da Escola Localização  \
# ...

# %%
df9.columns
# Out:
# Index(['Ano', 'Região', 'UF', 'Código do Município', 'Nome do Município',
#        'Código da Escola', 'Nome da Escola', 'Localização',
#        'Dependência Administrativa', 'EI_grupo1', 'EI_grupo2', 'EI_grupo3',
#        'EI_grupo4', 'EI_grupo5', 'EF_total_grupo1', 'EF_total_grupo2',
#        'EF_total_grupo3', 'EF_total_grupo4', 'EF_total_grupo5',
#        'EF_iniciais_grupo1', 'EF_iniciais_grupo2', 'EF_iniciais_grupo3',
#        'EF_iniciais_grupo4', 'EF_iniciais_grupo5', 'EF_finais_grupo1',
#        'EF_finais_grupo2', 'EF_finais_grupo3', 'EF_finais_grupo4',
#        'EF_finais_grupo5', 'EM_grupo1', 'EM_grupo2', 'EM_grupo3', 'EM_grupo4',
#        'EM_grupo5', 'EJA_EF_grupo1', 'EJA_EF_grupo2', 'EJA_EF_grupo3',
#        'EJA_EF_grupo4', 'EJA_EF_grupo5', 'EJA_EM_grupo1', 'EJA_EM_grupo2',
#        'EJA_EM_grupo3', 'EJA_EM_grupo4', 'EJA_EM_grupo5'],
#       dtype='object')

# %%
df10 = pd.read_csv('AFD_ESCOLAS_2022.csv', sep=';')
df10
# Out:
#          Ano        Região  UF  Código do Município      Nome do Município  \
# 0       2022         Norte  RO              1100015  Alta Floresta D'Oeste
# 1       2022         Norte  RO              1100015  Alta Floresta D'Oeste
# 2       2022         Norte  RO              1100015  Alta Floresta D'Oeste
# 3       2022         Norte  RO              1100015  Alta Floresta D'Oeste
# 4       2022         Norte  RO              1100015  Alta Floresta D'Oeste
# ...      ...           ...  ..                  ...                    ...
# 175517  2022  Centro-Oeste  DF              5300108               Brasília
# 175518  2022  Centro-Oeste  DF              5300108               Brasília
# 175519  2022  Centro-Oeste  DF              5300108               Brasília
# 175520  2022  Centro-Oeste  DF              5300108               Brasília
# 175521  2022  Centro-Oeste  DF              5300108               Brasília
#
#         Código da Escola            Nome da Escola Localização  \
# ...

# %%
df10.columns
# Out:
# Index(['Ano', 'Região', 'UF', 'Código do Município', 'Nome do Município',
#        'Código da Escola', 'Nome da Escola', 'Localização',
#        'Dependência Administrativa', 'EI_grupo1', 'EI_grupo2', 'EI_grupo3',
#        'EI_grupo4', 'EI_grupo5', 'EF_total_grupo1', 'EF_total_grupo2',
#        'EF_total_grupo3', 'EF_total_grupo4', 'EF_total_grupo5',
#        'EF_iniciais_grupo1', 'EF_iniciais_grupo2', 'EF_iniciais_grupo3',
#        'EF_iniciais_grupo4', 'EF_iniciais_grupo5', 'EF_finais_grupo1',
#        'EF_finais_grupo2', 'EF_finais_grupo3', 'EF_finais_grupo4',
#        'EF_finais_grupo5', 'EM_grupo1', 'EM_grupo2', 'EM_grupo3', 'EM_grupo4',
#        'EM_grupo5', 'EJA_EF_grupo1', 'EJA_EF_grupo2', 'EJA_EF_grupo3',
#        'EJA_EF_grupo4', 'EJA_EF_grupo5', 'EJA_EM_grupo1', 'EJA_EM_grupo2',
#        'EJA_EM_grupo3', 'EJA_EM_grupo4', 'EJA_EM_grupo5'],
#       dtype='object')

# %%
tabela_final = pd.concat([df1,df2,df3,df4,df5,df6,df7,df8,df9,df10])
tabela_final
# Out:
#          Ano        Região  UF  Código do Município      Nome do Município  \
# 0       2013         Norte  RO              1100015  ALTA FLORESTA D OESTE
# 1       2013         Norte  RO              1100015  ALTA FLORESTA D OESTE
# 2       2013         Norte  RO              1100015  ALTA FLORESTA D OESTE
# 3       2013         Norte  RO              1100015  ALTA FLORESTA D OESTE
# 4       2013         Norte  RO              1100015  ALTA FLORESTA D OESTE
# ...      ...           ...  ..                  ...                    ...
# 175517  2022  Centro-Oeste  DF              5300108               Brasília
# 175518  2022  Centro-Oeste  DF              5300108               Brasília
# 175519  2022  Centro-Oeste  DF              5300108               Brasília
# 175520  2022  Centro-Oeste  DF              5300108               Brasília
# 175521  2022  Centro-Oeste  DF              5300108               Brasília
#
#         Código da Escola              Nome da Escola Localização  \
# ...

# %%
tabela_final['Ano'].unique()
# Out:
# array([2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022],
#       dtype=int64)

# %%
#Padronizando todos os nomes das colunas para o Big Query
tabela_final = tabela_final.rename(columns= {'Ano':'ano', 
                        'Região':'nome_regiao', 
                        'UF': 'sigla_uf', 
                        'Código do Município':'id_municipio',
                        'Nome do Município':'nome_municipio',
                        'Código da Escola':'id_escola',
                        'Nome da Escola':'nome_escola',
                        'Localização':'localizacao',
                        'Dependência Administrativa':'dependencia_adm',
                        'EI_grupo1': 'ei_grupo1',
                        'EI_grupo2': 'ei_grupo2', 
                        'EI_grupo3': 'ei_grupo3',
                        'EI_grupo4': 'ei_grupo4', 
                        'EI_grupo5': 'ei_grupo5', 
                        'EF_total_grupo1': 'ef_total_grupo1', 
                        'EF_total_grupo2': 'ef_total_grupo2', 
                        'EF_total_grupo3': 'ef_total_grupo3', 
                        'EF_total_grupo4': 'ef_total_grupo4', 
                        'EF_total_grupo5': 'ef_total_grupo5',
                        'EF_finais_grupo1' : 'ef_finais_grupo1',
                        'EF_finais_grupo2' : 'ef_finais_grupo2', 
                        'EF_finais_grupo3' : 'ef_finais_grupo3', 
                        'EF_finais_grupo4' : 'ef_finais_grupo4',
                        'EF_finais_grupo5' : 'ef_finais_grupo5', 
                        'EM_grupo1' : 'em_grupo1', 
                        'EM_grupo2' : 'em_grupo2', 
                        'EM_grupo3' : 'em_grupo3', 
                        'EM_grupo4' : 'em_grupo4',
                        'EM_grupo5' : 'em_grupo5', 
                        'EJA_EF_grupo1' : 'eja_ef_grupo1',
                        'EJA_EF_grupo2' : 'eja_ef_grupo2', 
                        'EJA_EF_grupo3' : 'eja_ef_grupo3',
                        'EJA_EF_grupo4' : 'eja_ef_grupo4', 
                        'EJA_EF_grupo5' : 'eja_ef_grupo5', 
                        'EJA_EM_grupo1' : 'eja_em_grupo1', 
                        'EJA_EM_grupo2' : 'eja_em_grupo2',
                        'EJA_EM_grupo3' : 'eja_em_grupo3', 
                        'EJA_EM_grupo4' : 'eja_em_grupo4', 
                        'EJA_EM_grupo5' : 'eja_em_grupo5', 
                        'EF_iniciais_grupo1' : 'ef_iniciais_grupo1',
                        'EF_iniciais_grupo2' : 'ef_iniciais_grupo2', 
                        'EF_iniciais_grupo3' : 'ef_iniciais_grupo3',
                        'EF_iniciais_grupo4' : 'ef_iniciais_grupo4',
                        'EF_iniciais_grupo5' : 'ef_iniciais_grupo5' })
tabela_final
# Out:
#          ano   nome_regiao sigla_uf  id_municipio         nome_municipio  \
# 0       2013         Norte       RO       1100015  ALTA FLORESTA D OESTE
# 1       2013         Norte       RO       1100015  ALTA FLORESTA D OESTE
# 2       2013         Norte       RO       1100015  ALTA FLORESTA D OESTE
# 3       2013         Norte       RO       1100015  ALTA FLORESTA D OESTE
# 4       2013         Norte       RO       1100015  ALTA FLORESTA D OESTE
# ...      ...           ...      ...           ...                    ...
# 175517  2022  Centro-Oeste       DF       5300108               Brasília
# 175518  2022  Centro-Oeste       DF       5300108               Brasília
# 175519  2022  Centro-Oeste       DF       5300108               Brasília
# 175520  2022  Centro-Oeste       DF       5300108               Brasília
# 175521  2022  Centro-Oeste       DF       5300108               Brasília
#
#         id_escola                 nome_escola localizacao dependencia_adm  \
# ...

# %%
tabela_final.columns
# Out:
# Index(['ano', 'nome_regiao', 'sigla_uf', 'id_municipio', 'nome_municipio',
#        'id_escola', 'nome_escola', 'localizacao', 'dependencia_adm',
#        'ei_grupo1', 'ei_grupo2', 'ei_grupo3', 'ei_grupo4', 'ei_grupo5',
#        'ef_total_grupo1', 'ef_total_grupo2', 'ef_total_grupo3',
#        'ef_total_grupo4', 'ef_total_grupo5', 'ef_iniciais_grupo1',
#        'ef_iniciais_grupo2', 'ef_iniciais_grupo3', 'ef_iniciais_grupo4',
#        'ef_iniciais_grupo5', 'ef_finais_grupo1', 'ef_finais_grupo2',
#        'ef_finais_grupo3', 'ef_finais_grupo4', 'ef_finais_grupo5', 'em_grupo1',
#        'em_grupo2', 'em_grupo3', 'em_grupo4', 'em_grupo5', 'eja_ef_grupo1',
#        'eja_ef_grupo2', 'eja_ef_grupo3', 'eja_ef_grupo4', 'eja_ef_grupo5',
#        'eja_em_grupo1', 'eja_em_grupo2', 'eja_em_grupo3', 'eja_em_grupo4',
#        'eja_em_grupo5'],
#       dtype='object')

# %%
tabela_final = tabela_final.replace('--', np.nan) #transformando os valores '--' como  NaN

# %%
transformar_float = ['ei_grupo1', 'ei_grupo2', 'ei_grupo3', 'ei_grupo4', 'ei_grupo5',
       'ef_total_grupo1', 'ef_total_grupo2', 'ef_total_grupo3',
       'ef_total_grupo4', 'ef_total_grupo5', 'ef_iniciais_grupo1',
       'ef_iniciais_grupo2', 'ef_iniciais_grupo3', 'ef_iniciais_grupo4',
       'ef_iniciais_grupo5', 'ef_finais_grupo1', 'ef_finais_grupo2',
       'ef_finais_grupo3', 'ef_finais_grupo4', 'ef_finais_grupo5', 'em_grupo1',
       'em_grupo2', 'em_grupo3', 'em_grupo4', 'em_grupo5', 'eja_ef_grupo1',
       'eja_ef_grupo2', 'eja_ef_grupo3', 'eja_ef_grupo4', 'eja_ef_grupo5',
       'eja_em_grupo1', 'eja_em_grupo2', 'eja_em_grupo3', 'eja_em_grupo4',
       'eja_em_grupo5'] #definindo uma variável para todas as colunas

# %%
tabela_final[transformar_float] = tabela_final[transformar_float].astype(float) #transformando as colunas dos grupos dos docentes em float

# %%
tabela_final.dtypes #conferindo
# Out:
# ano                     int64
# nome_regiao            object
# sigla_uf               object
# id_municipio            int64
# nome_municipio         object
# id_escola               int64
# nome_escola            object
# localizacao            object
# dependencia_adm        object
# ei_grupo1             float64
# ei_grupo2             float64
# ei_grupo3             float64
# ei_grupo4             float64
# ei_grupo5             float64
# ef_total_grupo1       float64
# ef_total_grupo2       float64
# ef_total_grupo3       float64
# ef_total_grupo4       float64
# ef_total_grupo5       float64
# ef_iniciais_grupo1    float64
# ef_iniciais_grupo2    float64
# ef_iniciais_grupo3    float64
# ef_iniciais_grupo4    float64
# ef_iniciais_grupo5    float64
# ef_finais_grupo1      float64
# ef_finais_grupo2      float64
# ef_finais_grupo3      float64
# ef_finais_grupo4      float64
# ef_finais_grupo5      float64
# em_grupo1             float64
# em_grupo2             float64
# ...

# %%
tabela_final.to_csv('INEP_adequacao_formacao_docente.csv',index=False, encoding="latin-1", sep=';', decimal=',')

# %%
client = bigquery.Client()
dataset_ref = client.dataset('Datalake')

# %%
schema = [bigquery.SchemaField('ano', 'INTEGER', description= 'Ano de referência da observação'),
          bigquery.SchemaField('nome_regiao', 'STRING', description= 'Região do Brasil abrangente a observação'),
          bigquery.SchemaField('sigla_uf', 'STRING', description= 'Sigla da Unidade da Federação referente aquela observação'),
          bigquery.SchemaField('id_municipio', 'INTEGER', description= 'Identificador do município pelo IBGE'),
          bigquery.SchemaField('nome_municipio', 'STRING', description= 'Nome do município da observação'),                    
          bigquery.SchemaField('id_escola', 'INTEGER', description= 'Identificação da escola'),                    
          bigquery.SchemaField('nome_escola', 'STRING', description= 'Nome da escola observada'),                    
          bigquery.SchemaField('localizacao', 'STRING', description= 'Se a área da observação é urbana ou rural'),                    
          bigquery.SchemaField('dependencia_adm', 'STRING', description= 'Dependência admnistrativa da observação (privada ou pública)'),                    
          bigquery.SchemaField('ei_grupo1', 'FLOAT', description= 'Docentes do Ensino Infantil com formação superior de licenciatura (ou bacharelado com complementação pedagógica) na mesma área da disciplina que leciona'),                    
          bigquery.SchemaField('ei_grupo2', 'FLOAT', description= 'Docentes do Ensino Infantil com formação superior de bacharelado (sem complementação pedagógica) na mesma área da disciplina que leciona'),                    
          bigquery.SchemaField('ei_grupo3', 'FLOAT', description= 'Docentes do Ensino Infantil com formação superior de licenciatura (ou bacharelado com complementação pedagógica) em área diferente daquela que leciona'),                    
          bigquery.SchemaField('ei_grupo4', 'FLOAT', description= 'Docentes do Ensino Infantil com formação superior não considerada nas categorias anteriores'),                    
          bigquery.SchemaField('ei_grupo5', 'FLOAT', description= 'Docentes do Ensino Infantil sem formação superior'),                    
          bigquery.SchemaField('ef_total_grupo1', 'FLOAT', description= 'Docentes de todos os anos do Ensino Fundamental com formação superior de licenciatura (ou bacharelado com complementação pedagógica) na mesma área da disciplina que leciona'),                    
          bigquery.SchemaField('ef_total_grupo2', 'FLOAT', description= 'Docentes de todos os anos do Ensino Fundamental com formação superior de bacharelado (sem complementação pedagógica) na mesma área da disciplina que leciona'),                    
          bigquery.SchemaField('ef_total_grupo3', 'FLOAT', description= 'Docentes de todos os anos do Ensino Fundamental com formação superior de licenciatura (ou bacharelado com complementação pedagógica) em área diferente daquela que leciona'),                    
          bigquery.SchemaField('ef_total_grupo4', 'FLOAT', description= 'Docentes de todos os anos do Ensino Fundamental com formação superior não considerada nas categorias anteriores'),                    
          bigquery.SchemaField('ef_total_grupo5', 'FLOAT', description= 'Docentes de todos os anos do Ensino Fundamental sem formação superior'),                    
          bigquery.SchemaField('ef_iniciais_grupo1', 'FLOAT', description= 'Docentes dos anos iniciais do Ensino Fundamental com formação superior de licenciatura (ou bacharelado com complementação pedagógica) na mesma área da disciplina que leciona'),                    
          bigquery.SchemaField('ef_iniciais_grupo2', 'FLOAT', description= 'Docentes dos anos iniciais do Ensino Fundamental com formação superior de bacharelado (sem complementação pedagógica) na mesma área da disciplina que leciona'),                    
          bigquery.SchemaField('ef_iniciais_grupo3', 'FLOAT', description= 'Docentes dos anos iniciais do Ensino Fundamental com formação superior de licenciatura (ou bacharelado com complementação pedagógica) em área diferente daquela que leciona'),                    
          bigquery.SchemaField('ef_iniciais_grupo4', 'FLOAT', description= 'Docentes dos anos iniciais do Ensino Fundamental com formação superior não considerada nas categorias anteriores'),                    
          bigquery.SchemaField('ef_iniciais_grupo5', 'FLOAT', description= 'Docentes dos anos iniciais do Ensino Fundamental sem formação superior'),                    
          bigquery.SchemaField('ef_finais_grupo1', 'FLOAT', description= 'Docentes dos anos finais do Ensino Fundamental com formação superior de licenciatura (ou bacharelado com complementação pedagógica) na mesma área da disciplina que leciona'),                    
          bigquery.SchemaField('ef_finais_grupo2', 'FLOAT', description= 'Docentes dos anos finais do Ensino Fundamental com formação superior de bacharelado (sem complementação pedagógica) na mesma área da disciplina que leciona'),                    
          bigquery.SchemaField('ef_finais_grupo3', 'FLOAT', description= 'Docentes dos anos finais do Ensino Fundamental com formação superior de licenciatura (ou bacharelado com complementação pedagógica) em área diferente daquela que leciona'),                    
          bigquery.SchemaField('ef_finais_grupo4', 'FLOAT', description= 'Docentes dos anos finais do Ensino Fundamental com formação superior não considerada nas categorias anteriores'),                    
          bigquery.SchemaField('ef_finais_grupo5', 'FLOAT', description= 'Docentes dos anos finais do Ensino Fundamental sem formação superior'),                    
          bigquery.SchemaField('em_grupo1', 'FLOAT', description= 'Docentes do Ensino Médio com formação superior de licenciatura (ou bacharelado com complementação pedagógica) na mesma área da disciplina que leciona'),                    
          bigquery.SchemaField('em_grupo2', 'FLOAT', description= 'Docentes do Ensino Médio com formação superior de bacharelado (sem complementação pedagógica) na mesma área da disciplina que leciona'),                    
          bigquery.SchemaField('em_grupo3', 'FLOAT', description= 'Docentes do Ensino Médio com formação superior de licenciatura (ou bacharelado com complementação pedagógica) em área diferente daquela que leciona'),                    
          bigquery.SchemaField('em_grupo4', 'FLOAT', description= 'Docentes do Ensino Médio com formação superior não considerada nas categorias anteriores'),                    
          bigquery.SchemaField('em_grupo5', 'FLOAT', description= 'Docentes do Ensino Médio sem formação superior'),                    
          bigquery.SchemaField('eja_ef_grupo1', 'FLOAT', description= 'Docentes do Ensino Fundamental do EJA com formação superior de licenciatura (ou bacharelado com complementação pedagógica) na mesma área da disciplina que leciona'),                    
          bigquery.SchemaField('eja_ef_grupo2', 'FLOAT', description= 'Docentes do Ensino Fundamental do EJA com formação superior de bacharelado (sem complementação pedagógica) na mesma área da disciplina que leciona'),                    
          bigquery.SchemaField('eja_ef_grupo3', 'FLOAT', description= 'Docentes do Ensino Fundamental do EJA com formação superior de licenciatura (ou bacharelado com complementação pedagógica) em área diferente daquela que leciona.'),                    
          bigquery.SchemaField('eja_ef_grupo4', 'FLOAT', description= 'Docentes do Ensino Fundamental do EJA com formação superior não considerada nas categorias anteriores'),                    
          bigquery.SchemaField('eja_ef_grupo5', 'FLOAT', description= 'Docentes do Ensino Fundamental do EJA sem formação superior'),                    
          bigquery.SchemaField('eja_em_grupo1', 'FLOAT', description= 'Docentes do Ensino Médio do EJA com formação superior de licenciatura (ou bacharelado com complementação pedagógica) na mesma área da disciplina que leciona'),                    
          bigquery.SchemaField('eja_em_grupo2', 'FLOAT', description= 'Docentes do Ensino Médio do EJA com formação superior de bacharelado (sem complementação pedagógica) na mesma área da disciplina que leciona'),                    
          bigquery.SchemaField('eja_em_grupo3', 'FLOAT', description= 'Docentes do Ensino Médio do EJA com formação superior de licenciatura (ou bacharelado com complementação pedagógica) em área diferente daquela que leciona.'),                    
          bigquery.SchemaField('eja_em_grupo4', 'FLOAT', description= 'Docentes do Ensino Médio do EJA com formação superior não considerada nas categorias anteriores'),                    
          bigquery.SchemaField('eja_em_grupo5', 'FLOAT', description= 'Docentes do Ensino Médio do EJA sem formação superior'),
          ]

# %%
table_ref = dataset_ref.table('INEP_adequacao_formacao_docente')
job_config = bigquery.LoadJobConfig(schema=schema)
job = client.load_table_from_dataframe(tabela_final, table_ref, job_config=job_config)
job.result()
# Out:
# LoadJob<project=repositoriodedadosgpsp, location=US, id=dfed1e4c-62b2-44e8-90e1-3f5c9c56c9e7>
