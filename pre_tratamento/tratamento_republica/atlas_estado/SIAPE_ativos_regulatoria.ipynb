# %%
import numpy as np
import pandas as pd
import os

# %%
os.chdir('G:\\Drives compartilhados\\República.org\\4. Equipes\\Dados e Comunicação\\DADOS\\415 - Repositório de Dados\\Dados para subir\\Dados Brutos\\Atlas do Estado')

# %%
df = pd.read_csv("SIAPE_ativos_regulatoria.csv", sep= ";")
df
# Out:
#      ano                                        ministerios  \
# 0   1999                              ministerio da fazenda
# 1   1999                              ministerio da justica
# 2   1999  ministerio do planejamento desenvolvimento e g...
# 3   2000                              ministerio da fazenda
# 4   2000                              ministerio da justica
# ..   ...                                                ...
# 57  2017  ministerio do planejamento desenvolvimento e g...
# 58  2018                              ministerio da fazenda
# 59  2018                              ministerio da justica
# 60  2018                  ministerio da transparencia e cgu
# 61  2018  ministerio do planejamento desenvolvimento e g...
#
#     servidores_ativos_ministerios  total_servidores_ativos  perc_servidores
# 0                           27990                   482854             5.80
# 1                           23450                   482854             4.86
# 2                           36797                   482854             7.62
# 3                           26184                   478435             5.47
# 4                           22644                   478435             4.73
# ..                            ...                      ...              ...
# 57                          32567                   614925             5.30
# 58                          30967                   611916             5.06
# 59                          31642                   611916             5.17
# 60                           2308                   611916             0.38
# 61                          33485                   611916             5.47
#
# [62 rows x 5 columns]

# %%
df = df.to_csv("SIAPE_ativos_regulatoria.csv", index = False)
