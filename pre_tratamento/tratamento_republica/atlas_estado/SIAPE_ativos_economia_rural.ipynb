# %%
import numpy as np
import pandas as pd
import os

# %%
os.chdir('G:\\Drives compartilhados\\República.org\\4. Equipes\\Dados e Comunicação\\DADOS\\415 - Repositório de Dados\\Dados para subir\\Dados Brutos\\Atlas do Estado')

# %%
df = pd.read_csv("SIAPE_ativos_economia_rural.csv", sep=';')
df
# Out:
#       ano                                        ministerios  \
# 0    1999  ministerio da agricultura, pecuaria e abasteci...
# 1    1999                               ministerio da defesa
# 2    1999                 ministerio das relacoes exteriores
# 3    1999                              ministerio do esporte
# 4    1999                              ministerio do turismo
# ..    ...                                                ...
# 118  2018  ministerio da agricultura, pecuaria e abasteci...
# 119  2018                               ministerio da defesa
# 120  2018                 ministerio das relacoes exteriores
# 121  2018                              ministerio do esporte
# 122  2018                              ministerio do turismo
#
#      servidores_ativos_ministerios  total_servidores_ativos  perc_servidores
# 0                            11036                   482854             2.29
# 1                            32124                   482854             6.65
# 2                             3193                   482854             0.66
# 3                              208                   482854             0.04
# 4                              224                   482854             0.05
# ..                             ...                      ...              ...
# 118                           9893                   611916             1.62
# 119                          17771                   611916             2.90
# 120                           3337                   611916             0.55
# 121                            330                   611916             0.05
# 122                            433                   611916             0.07
#
# [123 rows x 5 columns]

# %%
df = df.to_csv('SIAPE_ativos_economia_rural.csv', index = False)
