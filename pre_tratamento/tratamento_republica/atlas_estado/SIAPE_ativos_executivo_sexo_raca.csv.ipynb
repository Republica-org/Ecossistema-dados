# %%
import pandas as pd
import numpy as np
import os

# %%
import pandas as pd
import numpy as np
df_wide = pd.read_csv('SIAPE_ativos_executivo_sexo_raca.csv', sep=';')
df_wide
# Out:
#       ano           raça     Fem     Mas   total  total_ano  fem_ano  mas_ano
# 0    1999        AMARELA    7319    8566   15885     477416   210314   267102
# 1    1999         BRANCA  105793  124198  229991     477416   210314   267102
# 2    1999       INDIGENA     530    1054    1584     477416   210314   267102
# 3    1999  NAO INFORMADO   32792   50004   82796     477416   210314   267102
# 4    1999          PARDA   54612   74169  128781     477416   210314   267102
# ..    ...            ...     ...     ...     ...        ...      ...      ...
# 127  2020         BRANCA  128464  154111  282575     499306   219861   279445
# 128  2020       INDIGENA     416     882    1298     499306   219861   279445
# 129  2020  NAO INFORMADO   11872   16372   28244     499306   219861   279445
# 130  2020          PARDA   61637   87518  149155     499306   219861   279445
# 131  2020          PRETA   12214   13822   26036     499306   219861   279445
#
# [132 rows x 8 columns]

# %%
df_long = df_wide.melt(id_vars =['ano', 'raça'], 
        value_vars =['Fem', 'Mas'],
        var_name ='Gênero', 
        value_name ='Total de vinculos')
df_long
# Out:
#       ano           raça Gênero  Total de vinculos
# 0    1999        AMARELA    Fem               7319
# 1    1999         BRANCA    Fem             105793
# 2    1999       INDIGENA    Fem                530
# 3    1999  NAO INFORMADO    Fem              32792
# 4    1999          PARDA    Fem              54612
# ..    ...            ...    ...                ...
# 259  2020         BRANCA    Mas             154111
# 260  2020       INDIGENA    Mas                882
# 261  2020  NAO INFORMADO    Mas              16372
# 262  2020          PARDA    Mas              87518
# 263  2020          PRETA    Mas              13822
#
# [264 rows x 4 columns]

# %%
df_long.to_csv('SIAPE_ativos_executivo_sexo_raca.csv')

# %% [markdown]
# Renomeação de coluna

# %%
os.chdir('G:\\Drives compartilhados\\República.org\\4. Equipes\\Dados e Comunicação\\DADOS\\415 - Repositório de Dados\\Dados para subir\\Tabelas finais')

# %%
df = pd.read_csv("SIAPE_ativos_executivo_sexo_raca.csv")
df
# Out:
#       ano           raça genero  total_de_vinculos
# 0    1999        AMARELA    Fem               7319
# 1    1999         BRANCA    Fem             105793
# 2    1999       INDIGENA    Fem                530
# 3    1999  NAO INFORMADO    Fem              32792
# 4    1999          PARDA    Fem              54612
# ..    ...            ...    ...                ...
# 259  2020         BRANCA    Mas             154111
# 260  2020       INDIGENA    Mas                882
# 261  2020  NAO INFORMADO    Mas              16372
# 262  2020          PARDA    Mas              87518
# 263  2020          PRETA    Mas              13822
#
# [264 rows x 4 columns]

# %%
df
# Out:
#       ano           raça genero  total_de_vinculos
# 0    1999        AMARELA    Fem               7319
# 1    1999         BRANCA    Fem             105793
# 2    1999       INDIGENA    Fem                530
# 3    1999  NAO INFORMADO    Fem              32792
# 4    1999          PARDA    Fem              54612
# ..    ...            ...    ...                ...
# 259  2020         BRANCA    Mas             154111
# 260  2020       INDIGENA    Mas                882
# 261  2020  NAO INFORMADO    Mas              16372
# 262  2020          PARDA    Mas              87518
# 263  2020          PRETA    Mas              13822
#
# [264 rows x 4 columns]

# %%
df.rename(columns={"raça":"raca", "Gênero" : "genero", "total de vinculos": "total_de_vinculos"}, inplace = True)
df
# Out:
#       ano           raca genero  total_de_vinculos
# 0    1999        AMARELA    Fem               7319
# 1    1999         BRANCA    Fem             105793
# 2    1999       INDIGENA    Fem                530
# 3    1999  NAO INFORMADO    Fem              32792
# 4    1999          PARDA    Fem              54612
# ..    ...            ...    ...                ...
# 259  2020         BRANCA    Mas             154111
# 260  2020       INDIGENA    Mas                882
# 261  2020  NAO INFORMADO    Mas              16372
# 262  2020          PARDA    Mas              87518
# 263  2020          PRETA    Mas              13822
#
# [264 rows x 4 columns]

# %% [markdown]
# Eliminação de coluna

# %%
df = df.drop('Unnamed: 0', axis=1)
df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 df = df.drop('Unnamed: 0', axis=1)
#       2 df
#
# File c:\Users\ana.sales_republica\Anaconda\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File c:\Users\ana.sales_republica\Anaconda\lib\site-packages\pandas\core\frame.py:5399, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5251 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
# ...

# %%
df = df.to_csv('SIAPE_ativos_executivo_sexo_raca.csv', index = False)
df
