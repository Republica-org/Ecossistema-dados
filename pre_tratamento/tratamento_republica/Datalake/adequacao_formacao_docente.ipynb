# %%
import pandas as pd
import time
import os
import pandas_gbq
from google.cloud import bigquery
import basedosdados as bd
import numpy as np

# %%
os.chdir("G:\\Drives compartilhados\\República.org\\4. Equipes\\Dados e Comunicação\\DADOS\\415 - Repositório de Dados\\Dados para subir\\Dados Brutos\\INEP\\Adequação Formação Docente")

# %%
df = pd.read_csv("Tabela final.csv",  sep=';', engine="python", error_bad_lines=False, encoding='utf-8')
df
# Out:
#           Ano        Região  UF  Código do Município      Nome do Município  \
# 0        2013         Norte  RO              1100015  ALTA FLORESTA D OESTE
# 1        2013         Norte  RO              1100015  ALTA FLORESTA D OESTE
# 2        2013         Norte  RO              1100015  ALTA FLORESTA D OESTE
# 3        2013         Norte  RO              1100015  ALTA FLORESTA D OESTE
# 4        2013         Norte  RO              1100015  ALTA FLORESTA D OESTE
# ...       ...           ...  ..                  ...                    ...
# 1802862  2022  Centro-Oeste  DF              5300108               Brasília
# 1802863  2022  Centro-Oeste  DF              5300108               Brasília
# 1802864  2022  Centro-Oeste  DF              5300108               Brasília
# 1802865  2022  Centro-Oeste  DF              5300108               Brasília
# 1802866  2022  Centro-Oeste  DF              5300108               Brasília
#
#          Código da Escola              Nome da Escola Localização  \
# 0                11022558       EIEEF HAP BITT TUPARI       Rural
# 1                11024275    CEEJA LUIZ VAZ DE CAMOES      Urbana
# 2                11024291        EMMEF 07 DE SETEMBRO       Rural
# 3                11024313  EMMEF AFONSO AURELIO PORTO       Rural
# 4                11024372             EMEIEF ANA NERY       Rural
# ...                   ...                         ...         ...
# 1802862          53084020         ESC PEQUENO ENCANTO      Urbana
# 1802863          53084039                COL ANCHIETA      Urbana
# 1802864          53084055                    COL MAPA      Urbana
# 1802865          53085000       COBIAN - COL BIANGULO      Urbana
# 1802866          53086007           CED VITORIA REGIA      Urbana
#
#         Dependência Administrativa EI_grupo1  ... EF_iniciais_grupo2  \
# 0                         Estadual        --  ...                NaN
# 1                         Estadual        --  ...                NaN
# 2                        Municipal        --  ...                NaN
# 3                        Municipal        --  ...                NaN
# 4                        Municipal       100  ...                NaN
# ...                            ...       ...  ...                ...
# 1802862                    Privada       100  ...               14.3
# 1802863                    Privada      26.8  ...                  0
# 1802864                    Privada       100  ...                  0
# 1802865                    Privada      75.5  ...                  0
# 1802866                    Privada        --  ...                 --
#
#         EF_iniciais_grupo3 EF_iniciais_grupo4 EF_iniciais_grupo5  \
# 0                      NaN                NaN                NaN
# 1                      NaN                NaN                NaN
# 2                      NaN                NaN                NaN
# 3                      NaN                NaN                NaN
# 4                      NaN                NaN                NaN
# ...                    ...                ...                ...
# 1802862                  0                  0                  0
# 1802863                  0                  0                6.7
# 1802864                  0                  0                  0
# 1802865                4.2                  0                  0
# 1802866                 --                 --                 --
#
#         EJA_EF_grupo1\n EJA_EF_grupo2\n EJA_EF_grupo3\n EJA_EF_grupo4\n  \
# 0                   NaN             NaN             NaN             NaN
# 1                   NaN             NaN             NaN             NaN
# 2                   NaN             NaN             NaN             NaN
# 3                   NaN             NaN             NaN             NaN
# 4                   NaN             NaN             NaN             NaN
# ...                 ...             ...             ...             ...
# 1802862             NaN             NaN             NaN             NaN
# 1802863             NaN             NaN             NaN             NaN
# 1802864             NaN             NaN             NaN             NaN
# 1802865             NaN             NaN             NaN             NaN
# 1802866             NaN             NaN             NaN             NaN
#
#         EJA_EF_grupo5\n EI_grupo1\n
# 0                   NaN         NaN
# 1                   NaN         NaN
# 2                   NaN         NaN
# 3                   NaN         NaN
# 4                   NaN         NaN
# ...                 ...         ...
# 1802862             NaN         NaN
# 1802863             NaN         NaN
# 1802864             NaN         NaN
# 1802865             NaN         NaN
# 1802866             NaN         NaN
#
# [1802867 rows x 55 columns]

# %%
df = df.replace('--', np.nan) #transformando os valores '--' como  NaN

# %%
transformar_float = ['EI_grupo1', 'EI_grupo2', 'EI_grupo3',
       'EI_grupo4', 'EI_grupo5', 'EF_total_grupo1', 'EF_total_grupo2',
       'EF_total_grupo3', 'EF_total_grupo4', 'EF_total_grupo5',
       'EF_iniciais_grupo1\n', 'EF_iniciais_grupo2\n', 'EF_iniciais_grupo3\n',
       'EF_iniciais_grupo4\n', 'EF_iniciais_grupo5\n', 'EF_finais_grupo1',
       'EF_finais_grupo2', 'EF_finais_grupo3', 'EF_finais_grupo4',
       'EF_finais_grupo5', 'EM_grupo1', 'EM_grupo2', 'EM_grupo3', 'EM_grupo4',
       'EM_grupo5', 'EJA_EF_grupo1', 'EJA_EF_grupo2', 'EJA_EF_grupo3',
       'EJA_EF_grupo4', 'EJA_EF_grupo5', 'EJA_EM_grupo1', 'EJA_EM_grupo2',
       'EJA_EM_grupo3', 'EJA_EM_grupo4', 'EJA_EM_grupo5', 'EF_iniciais_grupo1',
       'EF_iniciais_grupo2', 'EF_iniciais_grupo3', 'EF_iniciais_grupo4',
       'EF_iniciais_grupo5', 'EJA_EF_grupo1\n', 'EJA_EF_grupo2\n',
       'EJA_EF_grupo3\n', 'EJA_EF_grupo4\n', 'EJA_EF_grupo5\n', 'EI_grupo1\n'] #definindo uma variável para todas as colunas

# %%
df[transformar_float] = df[transformar_float].astype(float) #transformando todas as colunas em float

# %%
df
# Out:
#           Ano        Região  UF  Código do Município      Nome do Município  \
# 0        2013         Norte  RO              1100015  ALTA FLORESTA D OESTE
# 1        2013         Norte  RO              1100015  ALTA FLORESTA D OESTE
# 2        2013         Norte  RO              1100015  ALTA FLORESTA D OESTE
# 3        2013         Norte  RO              1100015  ALTA FLORESTA D OESTE
# 4        2013         Norte  RO              1100015  ALTA FLORESTA D OESTE
# ...       ...           ...  ..                  ...                    ...
# 1802862  2022  Centro-Oeste  DF              5300108               Brasília
# 1802863  2022  Centro-Oeste  DF              5300108               Brasília
# 1802864  2022  Centro-Oeste  DF              5300108               Brasília
# 1802865  2022  Centro-Oeste  DF              5300108               Brasília
# 1802866  2022  Centro-Oeste  DF              5300108               Brasília
#
#          Código da Escola              Nome da Escola Localização  \
# 0                11022558       EIEEF HAP BITT TUPARI       Rural
# 1                11024275    CEEJA LUIZ VAZ DE CAMOES      Urbana
# 2                11024291        EMMEF 07 DE SETEMBRO       Rural
# 3                11024313  EMMEF AFONSO AURELIO PORTO       Rural
# 4                11024372             EMEIEF ANA NERY       Rural
# ...                   ...                         ...         ...
# 1802862          53084020         ESC PEQUENO ENCANTO      Urbana
# 1802863          53084039                COL ANCHIETA      Urbana
# 1802864          53084055                    COL MAPA      Urbana
# 1802865          53085000       COBIAN - COL BIANGULO      Urbana
# 1802866          53086007           CED VITORIA REGIA      Urbana
#
#         Dependência Administrativa  EI_grupo1  ...  EF_iniciais_grupo2  \
# 0                         Estadual        NaN  ...                 NaN
# 1                         Estadual        NaN  ...                 NaN
# 2                        Municipal        NaN  ...                 NaN
# 3                        Municipal        NaN  ...                 NaN
# 4                        Municipal      100.0  ...                 NaN
# ...                            ...        ...  ...                 ...
# 1802862                    Privada      100.0  ...                14.3
# 1802863                    Privada       26.8  ...                 0.0
# 1802864                    Privada      100.0  ...                 0.0
# 1802865                    Privada       75.5  ...                 0.0
# 1802866                    Privada        NaN  ...                 NaN
#
#          EF_iniciais_grupo3  EF_iniciais_grupo4  EF_iniciais_grupo5  \
# 0                       NaN                 NaN                 NaN
# 1                       NaN                 NaN                 NaN
# 2                       NaN                 NaN                 NaN
# 3                       NaN                 NaN                 NaN
# 4                       NaN                 NaN                 NaN
# ...                     ...                 ...                 ...
# 1802862                 0.0                 0.0                 0.0
# 1802863                 0.0                 0.0                 6.7
# 1802864                 0.0                 0.0                 0.0
# 1802865                 4.2                 0.0                 0.0
# 1802866                 NaN                 NaN                 NaN
#
#          EJA_EF_grupo1\n  EJA_EF_grupo2\n  EJA_EF_grupo3\n  EJA_EF_grupo4\n  \
# 0                    NaN              NaN              NaN              NaN
# 1                    NaN              NaN              NaN              NaN
# 2                    NaN              NaN              NaN              NaN
# 3                    NaN              NaN              NaN              NaN
# 4                    NaN              NaN              NaN              NaN
# ...                  ...              ...              ...              ...
# 1802862              NaN              NaN              NaN              NaN
# 1802863              NaN              NaN              NaN              NaN
# 1802864              NaN              NaN              NaN              NaN
# 1802865              NaN              NaN              NaN              NaN
# 1802866              NaN              NaN              NaN              NaN
#
#          EJA_EF_grupo5\n  EI_grupo1\n
# 0                    NaN          NaN
# 1                    NaN          NaN
# 2                    NaN          NaN
# 3                    NaN          NaN
# 4                    NaN          NaN
# ...                  ...          ...
# 1802862              NaN          NaN
# 1802863              NaN          NaN
# 1802864              NaN          NaN
# 1802865              NaN          NaN
# 1802866              NaN          NaN
#
# [1802867 rows x 55 columns]

# %%
df.dtypes #verificando
# Out:
# Ano                             int64
# Região                         object
# UF                             object
# Código do Município             int64
# Nome do Município              object
# Código da Escola                int64
# Nome da Escola                 object
# Localização                    object
# Dependência Administrativa     object
# EI_grupo1                     float64
# EI_grupo2                     float64
# EI_grupo3                     float64
# EI_grupo4                     float64
# EI_grupo5                     float64
# EF_total_grupo1               float64
# EF_total_grupo2               float64
# EF_total_grupo3               float64
# EF_total_grupo4               float64
# EF_total_grupo5               float64
# EF_iniciais_grupo1\n          float64
# EF_iniciais_grupo2\n          float64
# EF_iniciais_grupo3\n          float64
# EF_iniciais_grupo4\n          float64
# EF_iniciais_grupo5\n          float64
# EF_finais_grupo1              float64
# EF_finais_grupo2              float64
# EF_finais_grupo3              float64
# EF_finais_grupo4              float64
# EF_finais_grupo5              float64
# EM_grupo1                     float64
# EM_grupo2                     float64
# EM_grupo3                     float64
# EM_grupo4                     float64
# EM_grupo5                     float64
# EJA_EF_grupo1                 float64
# EJA_EF_grupo2                 float64
# EJA_EF_grupo3                 float64
# EJA_EF_grupo4                 float64
# EJA_EF_grupo5                 float64
# EJA_EM_grupo1                 float64
# EJA_EM_grupo2                 float64
# EJA_EM_grupo3                 float64
# EJA_EM_grupo4                 float64
# EJA_EM_grupo5                 float64
# EF_iniciais_grupo1            float64
# EF_iniciais_grupo2            float64
# EF_iniciais_grupo3            float64
# EF_iniciais_grupo4            float64
# EF_iniciais_grupo5            float64
# EJA_EF_grupo1\n               float64
# EJA_EF_grupo2\n               float64
# EJA_EF_grupo3\n               float64
# EJA_EF_grupo4\n               float64
# EJA_EF_grupo5\n               float64
# EI_grupo1\n                   float64
# dtype: object

# %%
df
# Out:
#           Ano        Região  UF  Código do Município      Nome do Município  \
# 0        2013         Norte  RO              1100015  ALTA FLORESTA D OESTE
# 1        2013         Norte  RO              1100015  ALTA FLORESTA D OESTE
# 2        2013         Norte  RO              1100015  ALTA FLORESTA D OESTE
# 3        2013         Norte  RO              1100015  ALTA FLORESTA D OESTE
# 4        2013         Norte  RO              1100015  ALTA FLORESTA D OESTE
# ...       ...           ...  ..                  ...                    ...
# 1802862  2022  Centro-Oeste  DF              5300108               Brasília
# 1802863  2022  Centro-Oeste  DF              5300108               Brasília
# 1802864  2022  Centro-Oeste  DF              5300108               Brasília
# 1802865  2022  Centro-Oeste  DF              5300108               Brasília
# 1802866  2022  Centro-Oeste  DF              5300108               Brasília
#
#          Código da Escola              Nome da Escola Localização  \
# 0                11022558       EIEEF HAP BITT TUPARI       Rural
# 1                11024275    CEEJA LUIZ VAZ DE CAMOES      Urbana
# 2                11024291        EMMEF 07 DE SETEMBRO       Rural
# 3                11024313  EMMEF AFONSO AURELIO PORTO       Rural
# 4                11024372             EMEIEF ANA NERY       Rural
# ...                   ...                         ...         ...
# 1802862          53084020         ESC PEQUENO ENCANTO      Urbana
# 1802863          53084039                COL ANCHIETA      Urbana
# 1802864          53084055                    COL MAPA      Urbana
# 1802865          53085000       COBIAN - COL BIANGULO      Urbana
# 1802866          53086007           CED VITORIA REGIA      Urbana
#
#         Dependência Administrativa  EI_grupo1  ...  EF_iniciais_grupo2  \
# 0                         Estadual        NaN  ...                 NaN
# 1                         Estadual        NaN  ...                 NaN
# 2                        Municipal        NaN  ...                 NaN
# 3                        Municipal        NaN  ...                 NaN
# 4                        Municipal      100.0  ...                 NaN
# ...                            ...        ...  ...                 ...
# 1802862                    Privada      100.0  ...                14.3
# 1802863                    Privada       26.8  ...                 0.0
# 1802864                    Privada      100.0  ...                 0.0
# 1802865                    Privada       75.5  ...                 0.0
# 1802866                    Privada        NaN  ...                 NaN
#
#          EF_iniciais_grupo3  EF_iniciais_grupo4  EF_iniciais_grupo5  \
# 0                       NaN                 NaN                 NaN
# 1                       NaN                 NaN                 NaN
# 2                       NaN                 NaN                 NaN
# 3                       NaN                 NaN                 NaN
# 4                       NaN                 NaN                 NaN
# ...                     ...                 ...                 ...
# 1802862                 0.0                 0.0                 0.0
# 1802863                 0.0                 0.0                 6.7
# 1802864                 0.0                 0.0                 0.0
# 1802865                 4.2                 0.0                 0.0
# 1802866                 NaN                 NaN                 NaN
#
#          EJA_EF_grupo1\n  EJA_EF_grupo2\n  EJA_EF_grupo3\n  EJA_EF_grupo4\n  \
# 0                    NaN              NaN              NaN              NaN
# 1                    NaN              NaN              NaN              NaN
# 2                    NaN              NaN              NaN              NaN
# 3                    NaN              NaN              NaN              NaN
# 4                    NaN              NaN              NaN              NaN
# ...                  ...              ...              ...              ...
# 1802862              NaN              NaN              NaN              NaN
# 1802863              NaN              NaN              NaN              NaN
# 1802864              NaN              NaN              NaN              NaN
# 1802865              NaN              NaN              NaN              NaN
# 1802866              NaN              NaN              NaN              NaN
#
#          EJA_EF_grupo5\n  EI_grupo1\n
# 0                    NaN          NaN
# 1                    NaN          NaN
# 2                    NaN          NaN
# 3                    NaN          NaN
# 4                    NaN          NaN
# ...                  ...          ...
# 1802862              NaN          NaN
# 1802863              NaN          NaN
# 1802864              NaN          NaN
# 1802865              NaN          NaN
# 1802866              NaN          NaN
#
# [1802867 rows x 55 columns]

# %%
if df['EI_grupo1'].equals(df['EI_grupo1\n']):
    print("As colunas são iguais")
else:
    print("As colunas não são iguais")
# Out:
# As colunas não são iguais

# %%
#Padronizando todos os nomes das colunas
df = df.rename(columns= {'Ano':'ano', 
                        'Região':'nome_regiao', 
                        'UF': 'sigla_uf', 
                        'Código do Município':'id_municipio',
                        'Nome do Município':'nome_municipio',
                        'Código da Escola':'id_escola',
                        'Nome da Escola':'nome_escola',
                        'Localização':'localizacao',
                        'Dependência Administrativa':'dependencia_adm'
                        'EI_grupo1': 'ei_grupo1',
                        'EI_grupo2': 'ei_grupo2', 
                        'EI_grupo3': 'ei_grupo3',
                        'EI_grupo4': 'ei_grupo4', 
                        'EI_grupo5': 'ei_grupo5', 
                        'EF_total_grupo1': 'ef_total_grupo1', 
                        'EF_total_grupo2': 'ef_total_grupo2', 
                        'EF_total_grupo3': 'ef_total_grupo3', 
                        'EF_total_grupo4': 'ef_total_grupo4', 
                        'EF_total_grupo5': 'ef_total_grupo5',
                        'EF_iniciais_grupo1\n' : 'ef_iniciais_grupo1', 
                        'EF_iniciais_grupo2\n' : 'ef_iniciais_grupo2', 
                        'EF_iniciais_grupo3\n' : 'ef_iniciais_grupo3',
                        'EF_iniciais_grupo4\n' : 'ef_iniciais_grupo4', 
                        'EF_iniciais_grupo5\n' : 'ef_iniciais_grupo5', 
                        'EF_finais_grupo1' : 'ef_finais_grupo1',
                        'EF_finais_grupo2' : 'ef_finais_grupo2', 
                        'EF_finais_grupo3' : 'ef_finais_grupo3', 
                        'EF_finais_grupo4' : 'ef_finais_grupo4',
                        'EF_finais_grupo5' : 'ef_finais_grupo5', 
                        'EM_grupo1' : 'em_grupo1', 
                        'EM_grupo2' : 'em_grupo2', 
                        'EM_grupo3' : 'em_grupo3', 
                        'EM_grupo4' : 'em_grupo4',
                        'EM_grupo5' : 'em_grupo5', 
                        'EJA_EF_grupo1' : 'eja_ef_grupo1',
                        'EJA_EF_grupo2' : 'eja_ef_grupo2', 
                        'EJA_EF_grupo3' : 'eja_ef_grupo3',
                        'EJA_EF_grupo4' : 'eja_ef_grupo4', 
                        'EJA_EF_grupo5' : 'eja_ef_grupo5', 
                        'EJA_EM_grupo1' : 'eja_em_grupo1', 
                        'EJA_EM_grupo2' : 'eja_em_grupo2',
                        'EJA_EM_grupo3' : 'eja_em_grupo3', 
                        'EJA_EM_grupo4' : 'eja_em_grupo4', 
                        'EJA_EM_grupo5' : 'eja_em_grupo5', 
                        'EF_iniciais_grupo1' : 'ef_iniciais_grupo1',
                        'EF_iniciais_grupo2' : 'ef_iniciais_grupo2', 
                        'EF_iniciais_grupo3' : 'ef_iniciais_grupo3',
                        'EF_iniciais_grupo4' : 'ef_iniciais_grupo4',
                        'EF_iniciais_grupo5' : 'ef_iniciais_grupo5', 
                        'EJA_EF_grupo1\n' : 'EJA_EF_grupo1\n', 
                        'EJA_EF_grupo2\n' : 'EJA_EF_grupo2\n', 
                        'EJA_EF_grupo3\n' : 'EJA_EF_grupo3\n', 
                        'EJA_EF_grupo4\n' : 'EJA_EF_grupo4\n' , 
                        'EJA_EF_grupo5\n' : 'EJA_EF_grupo5\n', 
                        'EI_grupo1\n' : 'ei_grupo1'})
df
# Out:
#           ano   nome_regiao sigla_uf  id_municipio         nome_municipio  \
# 0        2013         Norte       RO       1100015  ALTA FLORESTA D OESTE
# 1        2013         Norte       RO       1100015  ALTA FLORESTA D OESTE
# 2        2013         Norte       RO       1100015  ALTA FLORESTA D OESTE
# 3        2013         Norte       RO       1100015  ALTA FLORESTA D OESTE
# 4        2013         Norte       RO       1100015  ALTA FLORESTA D OESTE
# ...       ...           ...      ...           ...                    ...
# 1802862  2022  Centro-Oeste       DF       5300108               Brasília
# 1802863  2022  Centro-Oeste       DF       5300108               Brasília
# 1802864  2022  Centro-Oeste       DF       5300108               Brasília
# 1802865  2022  Centro-Oeste       DF       5300108               Brasília
# 1802866  2022  Centro-Oeste       DF       5300108               Brasília
#
#          id_escola                 nome_escola localizacao dependencia_adm  \
# 0         11022558       EIEEF HAP BITT TUPARI       Rural        Estadual
# 1         11024275    CEEJA LUIZ VAZ DE CAMOES      Urbana        Estadual
# 2         11024291        EMMEF 07 DE SETEMBRO       Rural       Municipal
# 3         11024313  EMMEF AFONSO AURELIO PORTO       Rural       Municipal
# 4         11024372             EMEIEF ANA NERY       Rural       Municipal
# ...            ...                         ...         ...             ...
# 1802862   53084020         ESC PEQUENO ENCANTO      Urbana         Privada
# 1802863   53084039                COL ANCHIETA      Urbana         Privada
# 1802864   53084055                    COL MAPA      Urbana         Privada
# 1802865   53085000       COBIAN - COL BIANGULO      Urbana         Privada
# 1802866   53086007           CED VITORIA REGIA      Urbana         Privada
#
#         EI_grupo1  ... EF_iniciais_grupo2 EF_iniciais_grupo3  \
# 0             NaN  ...                NaN                NaN
# 1             NaN  ...                NaN                NaN
# 2             NaN  ...                NaN                NaN
# 3             NaN  ...                NaN                NaN
# 4             100  ...                NaN                NaN
# ...           ...  ...                ...                ...
# 1802862       100  ...               14.3                  0
# 1802863      26.8  ...                  0                  0
# 1802864       100  ...                  0                  0
# 1802865      75.5  ...                  0                4.2
# 1802866       NaN  ...                NaN                NaN
#
#         EF_iniciais_grupo4 EF_iniciais_grupo5 EJA_EF_grupo1 EJA_EF_grupo2  \
# 0                      NaN                NaN           NaN           NaN
# 1                      NaN                NaN           NaN           NaN
# 2                      NaN                NaN           NaN           NaN
# 3                      NaN                NaN           NaN           NaN
# 4                      NaN                NaN           NaN           NaN
# ...                    ...                ...           ...           ...
# 1802862                  0                  0           NaN           NaN
# 1802863                  0                6.7           NaN           NaN
# 1802864                  0                  0           NaN           NaN
# 1802865                  0                  0           NaN           NaN
# 1802866                NaN                NaN           NaN           NaN
#
#         EJA_EF_grupo3 EJA_EF_grupo4 EJA_EF_grupo5 EI_grupo1
# 0                 NaN           NaN           NaN       NaN
# 1                 NaN           NaN           NaN       NaN
# 2                 NaN           NaN           NaN       NaN
# 3                 NaN           NaN           NaN       NaN
# 4                 NaN           NaN           NaN       NaN
# ...               ...           ...           ...       ...
# 1802862           NaN           NaN           NaN       NaN
# 1802863           NaN           NaN           NaN       NaN
# 1802864           NaN           NaN           NaN       NaN
# 1802865           NaN           NaN           NaN       NaN
# 1802866           NaN           NaN           NaN       NaN
#
# [1802867 rows x 55 columns]

# %% [markdown]
# ome do Município;Código da Escola;Nome da Escola;Localização;Dependência Administrativa;
# EI_grupo1;EI_grupo2;
# EI_grupo3;EI_grupo4;EI_grupo5;EF_total_grupo1;EF_total_grupo2;EF_total_grupo3;EF_total_grupo4;EF_total_grupo5;"EF_iniciais_grupo1
# ";"EF_iniciais_grupo2
# ";"EF_iniciais_grupo3
# ";"EF_iniciais_grupo4
# ";"EF_iniciais_grupo5
# ";EF_finais_grupo1;
# EF_finais_grupo2;
# EF_finais_grupo3;EF_finais_grupo4;
# EF_finais_grupo5;EM_grupo1;EM_grupo2;EM_grupo3;EM_grupo4;EM_grupo5;EJA_EF_grupo1;EJA_EF_grupo2;EJA_EF_grupo3;EJA_EF_grupo4;EJA_EF_grupo5;EJA_EM_grupo1;EJA_EM_grupo2;EJA_EM_grupo3;EJA_EM_grupo4;EJA_EM_grupo5;EF_iniciais_grupo1;EF_iniciais_grupo2;EF_iniciais_grupo3;EF_iniciais_grupo4;EF_iniciais_grupo5;"EJA_EF_grupo1
# ";"EJA_EF_grupo2
# ";"EJA_EF_grupo3
# ";"EJA_EF_grupo4
# ";"EJA_EF_grupo5
# ";"EI_grupo1
