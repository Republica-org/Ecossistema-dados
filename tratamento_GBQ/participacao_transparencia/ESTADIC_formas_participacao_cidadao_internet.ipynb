# %%
import pandas as pd
import numpy as np
import os
import pandas_gbq
from google.cloud import bigquery
import glob
import openpyxl

# %%
os.chdir('G:\\\\Drives compartilhados\\\\República.org\\\\4. Equipes\\\\Dados e Comunicação\\\\DADOS\\\\415 - Repositório de Dados\\\\Repositório Local')

# %%
df = pd.read_excel('ESTADIC//Base_ESTADIC_2019.xlsx', sheet_name='Comunicação e informática')
df
# Out:
#     CodUF ETIC011 ETIC012 ETIC013 ETIC014 ETIC015 ETIC016 ETIC017 ETIC02  \
# 0      11     Sim     Não     Sim     Sim     Sim     Sim     Não    Sim
# 1      12     Não     Não     Não     Sim     Sim     Sim     Não    Sim
# 2      13     Não     Não     Não     Sim     Sim     Sim     Não    Sim
# 3      14     Não     Não     Sim     Sim     Sim     Não     Não    Sim
# 4      15     Não     Não     Não     Sim     Sim     Não     Não    Sim
# 5      16     Sim     Sim     Sim     Sim     Sim     Não     Sim    Sim
# 6      17     Sim     Sim     Sim     Sim     Sim     Não     Sim    Sim
# 7      21     Sim     Não     Sim     Sim     Sim     Sim     Não    Sim
# 8      22     Não     Não     Sim     Sim     Não     Não     Não    Sim
# 9      23     Sim     Não     Não     Sim     Sim     Sim     Não    Sim
# 10     24     Sim     Não     Não     Sim     Sim     Não     Sim    Sim
# 11     25     Não     Não     Não     Sim     Sim     Não     Sim    Sim
# ...

# %%
df = df[['CodUF','ETIC231', 'ETIC232', 'ETIC234', 'ETIC233']]

# %%
cod_uf = pd.read_csv('MUNIC//MUNIC_educacao_2021.csv', sep=';')[['UF','Cod UF']]

# %%
x= cod_uf.pivot_table(columns=('UF','Cod UF'), aggfunc='size')

# %%
cod_uf = pd.DataFrame(x).reset_index()[['UF','Cod UF']]

# %%
df = df.merge(cod_uf, right_on='Cod UF',left_on='CodUF')
df
# Out:
#     CodUF ETIC231 ETIC232 ETIC234 ETIC233  UF  Cod UF
# 0      11     Sim     Não     Sim     Não  RO      11
# 1      12     Não     Não     Não     Não  AC      12
# 2      13     Não     Não     Não     Não  AM      13
# 3      14     Não     Não     Não     Não  RR      14
# 4      15     Sim     Não     Não     Não  PA      15
# 5      16     Não     Não     Não     Sim  AP      16
# 6      17     Sim     Sim     Sim     Sim  TO      17
# 7      21     Sim     Não     Sim     Sim  MA      21
# 8      22     Não     Não     Não     Não  PI      22
# 9      23     Não     Não     Não     Não  CE      23
# 10     24     Sim     Não     Não     Sim  RN      24
# 11     25     Sim     Sim     Sim     Sim  PB      25
# 12     26     Sim     Não     Sim     Não  PE      26
# 13     27     Sim     Sim     Sim     Sim  AL      27
# 14     28     Não     Sim     Sim     Sim  SE      28
# 15     29     Não     Sim     Não     Sim  BA      29
# ...

# %%
df = df.drop(['CodUF'], axis=1)
df
# Out:
#    ETIC231 ETIC232 ETIC234 ETIC233  UF  Cod UF
# 0      Sim     Não     Sim     Não  RO      11
# 1      Não     Não     Não     Não  AC      12
# 2      Não     Não     Não     Não  AM      13
# 3      Não     Não     Não     Não  RR      14
# 4      Sim     Não     Não     Não  PA      15
# 5      Não     Não     Não     Sim  AP      16
# 6      Sim     Sim     Sim     Sim  TO      17
# 7      Sim     Não     Sim     Sim  MA      21
# 8      Não     Não     Não     Não  PI      22
# 9      Não     Não     Não     Não  CE      23
# 10     Sim     Não     Não     Sim  RN      24
# 11     Sim     Sim     Sim     Sim  PB      25
# 12     Sim     Não     Sim     Não  PE      26
# 13     Sim     Sim     Sim     Sim  AL      27
# 14     Não     Sim     Sim     Sim  SE      28
# 15     Não     Sim     Não     Sim  BA      29
# 16     Sim     Sim     Não     Sim  MG      31
# 17     Sim     Não     Não     Não  ES      32
# 18     Não     Não     Não     Não  RJ      33
# ...

# %%
df.columns
# Out:
# Index(['ETIC231', 'ETIC232', 'ETIC234', 'ETIC233', 'UF', 'Cod UF'], dtype='object')

# %%
df['ano']=2019

# %%
df = df.rename(columns={'Cod UF': 'cod_uf',
                        'UF':'sigla_uf',
                        'ETIC231':'consulta_publica_cidadaos',
                        'ETIC232':'grupos_discussao_foruns',
                        'ETIC234':'votacao_orientar_decisoes',
                        'ETIC233':'enquete_interesse_governo_estadual'})

# %%
df = df[['ano','cod_uf','sigla_uf', 'consulta_publica_cidadaos', 'grupos_discussao_foruns','votacao_orientar_decisoes', 'enquete_interesse_governo_estadual']]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 27 entries, 0 to 26
# Data columns (total 7 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   ano                                 27 non-null     int64
#  1   cod_uf                              27 non-null     int64
#  2   sigla_uf                            27 non-null     object
#  3   consulta_publica_cidadaos           27 non-null     object
#  4   grupos_discussao_foruns             27 non-null     object
#  5   votacao_orientar_decisoes           27 non-null     object
#  6   enquete_interesse_governo_estadual  27 non-null     object
# dtypes: int64(2), object(5)
# memory usage: 1.7+ KB

# %%
df['ano'].unique()
# Out:
# array([2019], dtype=int64)

# %% [markdown]
# Subindo para o GBQ

# %%
client = bigquery.Client()
dataset_ref = client.dataset('participacao_transparencia')

# %%
schema=[bigquery.SchemaField('ano','INTEGER',description='Ano de referência da observação'),
    bigquery.SchemaField('cod_uf','INTEGER',description='Código do IBGE da UF'),
    bigquery.SchemaField('sigla_uf','STRING',description='Sigla da Unidade da Federação'),
    bigquery.SchemaField('consulta_publica_cidadaos','STRING',description='Consulta pública on line para que cidadãos possam enviar'),
    bigquery.SchemaField('grupos_discussao_foruns','STRING',description='Grupos de discussão como fóruns ou comunidades pela internet'),
    bigquery.SchemaField('votacao_orientar_decisoes','STRING',description='Votação on line para orientar a tomada de decisão sobre  políticas públicas, orçamento, etc.'),
    bigquery.SchemaField('enquete_interesse_governo_estadual','STRING',description='Enquete on line sobre assuntos de interesse do governo estadual'),
]

# %%
table_ref = dataset_ref.table('ESTADIC_formas_participacao_cidadao_internet')
job_config = bigquery.LoadJobConfig(schema=schema)
job = client.load_table_from_dataframe(df,table_ref, job_config=job_config)
job.result()
# Out:
# LoadJob<project=repositoriodedadosgpsp, location=US, id=ba3b319a-1a0f-4d20-8876-266bbdd88611>
