# %%
import pandas as pd
import numpy as np
import os
import pandas_gbq
from google.cloud import bigquery
import glob
import openpyxl

# %%
os.chdir('G:\\\\Drives compartilhados\\\\República.org\\\\4. Equipes\\\\Dados e Comunicação\\\\DADOS\\\\415 - Repositório de Dados\\\\Repositório Local')

# %% [markdown]
# Chamando as bases

# %%
df18 = pd.read_excel('ESTADIC//Base_ESTADIC_2018.xlsx', sheet_name='Saúde', nrows=29, usecols=['Cod Uf', 'ESAU01','ESAU03','ESAU04', 'ESAU05', 'ESAU06'])
df18
# Out:
#     Cod Uf                ESAU01     ESAU03                  ESAU04   ESAU05  \
# 0       11  Secretaria exclusiva  Masculino                      46   Branca
# 1       12  Secretaria exclusiva  Masculino                      45    Pardo
# 2       13  Secretaria exclusiva  Masculino                      55    Pardo
# 3       14  Secretaria exclusiva  Masculino                      64    Pardo
# 4       15  Secretaria exclusiva  Masculino                      59   Branca
# 5       16  Secretaria exclusiva  Masculino                      54   Branca
# 6       17  Secretaria exclusiva  Masculino                      50    Pardo
# 7       21  Secretaria exclusiva  Masculino                      36    Pardo
# 8       22  Secretaria exclusiva  Masculino                      49   Branca
# 9       23  Secretaria exclusiva  Masculino                      46    Pardo
# 10      24  Secretaria exclusiva  Masculino                      62   Branca
# 11      25  Secretaria exclusiva   Feminino                      51   Branca
# 12      26  Secretaria exclusiva  Masculino                      50   Branca
# 13      27  Secretaria exclusiva  Masculino  (*) Não soube informar   Branca
# 14      28  Secretaria exclusiva  Masculino                      56   Branca
# 15      29  Secretaria exclusiva  Masculino                      51   Branca
# 16      31  Secretaria exclusiva  Masculino                      55    Pardo
# 17      32  Secretaria exclusiva  Masculino                      62   Branca
# 18      33  Secretaria exclusiva  Masculino                      49   Branca
# 19      35  Secretaria exclusiva  Masculino                      71   Branca
# 20      41  Secretaria exclusiva  Masculino                      57   Branca
# 21      42  Secretaria exclusiva  Masculino                      56   Branca
# 22      43  Secretaria exclusiva  Masculino                      70   Branca
# 23      50  Secretaria exclusiva  Masculino                      44   Branca
# 24      51  Secretaria exclusiva   Feminino                      37   Branca
# 25      52  Secretaria exclusiva  Masculino                      54  Amarelo
# 26      53  Secretaria exclusiva  Masculino                      41   Branca
#
#                              ESAU06
# 0                          Mestrado
# 1          Ensino superior completo
# 2                    Especialização
# 3          Ensino superior completo
# 4                          Mestrado
# 5          Ensino superior completo
# 6                          Mestrado
# 7                    Especialização
# 8          Ensino superior completo
# 9          Ensino superior completo
# 10                         Mestrado
# 11                         Mestrado
# 12                         Mestrado
# 13         Ensino superior completo
# 14                   Especialização
# 15                        Doutorado
# 16  Ensino médio (2º Grau) completo
# 17         Ensino superior completo
# 18                        Doutorado
# 19                        Doutorado
# 20                        Doutorado
# 21                   Especialização
# 22                   Especialização
# 23         Ensino superior completo
# 24         Ensino superior completo
# 25         Ensino superior completo
# 26                         Mestrado

# %%
df21 = pd.read_excel('ESTADIC//Base_ESTADIC_2021.xlsx', sheet_name='Saúde', nrows=29, usecols=['Cod UF', 'ESAU01','ESAU03','ESAU04', 'ESAU05', 'ESAU06'])
df21
# Out:
#     Cod UF                ESAU01     ESAU03  ESAU04   ESAU05  \
# 0       11  Secretaria exclusiva  Masculino      42    Parda
# 1       12  Secretaria exclusiva   Feminino      46   Branca
# 2       13  Secretaria exclusiva  Masculino      57   Branca
# 3       14  Secretaria exclusiva  Masculino      67   Branca
# 4       15  Secretaria exclusiva  Masculino      43   Branca
# 5       16  Secretaria exclusiva  Masculino      31    Parda
# 6       17  Secretaria exclusiva  Masculino      58   Branca
# 7       21  Secretaria exclusiva  Masculino      39    Parda
# 8       22  Secretaria exclusiva  Masculino      52   Branca
# 9       23  Secretaria exclusiva  Masculino      56    Parda
# 10      24  Secretaria exclusiva  Masculino      66   Branca
# 11      25  Secretaria exclusiva  Masculino      68   Branca
# 12      26  Secretaria exclusiva  Masculino      50   Branca
# 13      27  Secretaria exclusiva  Masculino      39    Parda
# 14      28  Secretaria exclusiva   Feminino      52    Parda
# 15      29  Secretaria exclusiva   Feminino      56   Branca
# 16      31  Secretaria exclusiva  Masculino      37   Branca
# 17      32  Secretaria exclusiva  Masculino      39   Branca
# 18      33  Secretaria exclusiva  Masculino      47   Branca
# 19      35  Secretaria exclusiva  Masculino      53  Amarela
# 20      41  Secretaria exclusiva  Masculino      53   Branca
# 21      42  Secretaria exclusiva  Masculino      57   Branca
# 22      43  Secretaria exclusiva   Feminino      74   Branca
# 23      50  Secretaria exclusiva  Masculino      66   Branca
# 24      51  Secretaria exclusiva  Masculino      60   Branca
# 25      52  Secretaria exclusiva  Masculino      37   Branca
# 26      53  Secretaria exclusiva  Masculino      68   Branca
#
#                       ESAU06
# 0             Especialização
# 1             Especialização
# 2             Especialização
# 3   Ensino superior completo
# 4   Ensino superior completo
# 5             Especialização
# 6   Ensino superior completo
# 7             Especialização
# 8             Especialização
# 9             Especialização
# 10                 Doutorado
# 11                  Mestrado
# 12            Especialização
# 13            Especialização
# 14                  Mestrado
# 15            Especialização
# 16            Especialização
# 17            Especialização
# 18  Ensino superior completo
# 19                  Mestrado
# 20            Especialização
# 21            Especialização
# 22  Ensino superior completo
# 23            Especialização
# 24            Especialização
# 25            Especialização
# 26  Ensino superior completo

# %%
uf = pd.read_excel('ESTADIC//Base_ESTADIC_2020.xlsx', sheet_name = 'Variáveis externas', usecols=[1,2,3])

# %% [markdown]
# Renomeando as colunas

# %%
df18= df18.rename(columns={'Cod Uf':'cod_uf',
                        'ESAU01':'caracterizacao_orgao_gestor',
                        'ESAU03':'genero',
                        'ESAU04' :'idade',
                        'ESAU05':'cor_raca',
                        'ESAU06':'grau_instrucao'})

# %%
df21= df21.rename(columns={'Cod UF':'cod_uf',
                        'ESAU01':'caracterizacao_orgao_gestor',
                        'ESAU03':'genero',
                        'ESAU04' :'idade',
                        'ESAU05':'cor_raca',
                        'ESAU06':'grau_instrucao'})

# %%
##adicionando a coluna de 'ano' em cada um dos dfs
df18['ano']=2018
df21['ano']=2021

# %%
df = pd.concat([df18,df21]) #juntando os dataframes

# %%
x= uf.pivot_table(columns=('Código da Unidade da Federação', 'Sigla da Unidade da Federação', 'Nome da Unidade da Federação'), aggfunc='size')

# %%
uf = pd.DataFrame(x).reset_index()[['Código da Unidade da Federação', 'Sigla da Unidade da Federação', 'Nome da Unidade da Federação']]

# %%
df = df.merge(uf, right_on='Código da Unidade da Federação',left_on='cod_uf') #juntando os dataframes, adicionando sigla e nome das UFs

# %%
df = df.drop(['Código da Unidade da Federação'], axis=1) #eliminando coluna repetida

# %%
df = df.rename(columns={'Sigla da Unidade da Federação':'sigla_uf',
                        'Nome da Unidade da Federação':'uf'}) #padronizando as colunas

# %%
df['caracterizacao_orgao_gestor']=df['caracterizacao_orgao_gestor'].str.title()

# %%
#padronizando os dados da coluna 'cor_raca'
df['cor_raca'] = np.where(df['cor_raca']=='Pardo','Parda',df['cor_raca'])
df['cor_raca'] = np.where(df['cor_raca']=='Amarelo','Amarela',df['cor_raca'])

#padronizando os dados da coluna 'idade'

df['idade']=np.where(df['idade']=='(*) Não soube informar',np.nan,df['idade'])

# %%
limites = [0, 30, 50,65,100] #criando uma nova coluna (faixa_etaria) com base na coluna 'idade'
categorias = ['Entre 18-29', 'Entre 30-49', 'Entre 50-64', 'Acima de 65']

df['faixa_etaria'] = pd.cut(df['idade'], bins=limites, labels=categorias)

# %%
df= df[['ano', 'sigla_uf','cod_uf', 'uf', 'caracterizacao_orgao_gestor','genero', 'faixa_etaria', 'cor_raca','grau_instrucao']]

# %%
df['grau_instrucao'].unique()
# Out:
# array(['Até Pós Graduação ou Mestrado', 'Até Ensino Superior Completo',
#        'Até Doutorado', 'Até Ensino Médio'], dtype=object)

# %%
# criando dicionário
dict_esco = {'Ensino médio (2º Grau) completo':'Até Ensino Médio',
             'Ensino superior completo':'Até Ensino Superior Completo',
             'Especialização':'Até Pós Graduação ou Mestrado',
             'Mestrado':'Até Pós Graduação ou Mestrado',
             'Doutorado':'Até Doutorado'}

# %%
df = df.replace({'grau_instrucao':dict_esco})

# %% [markdown]
# Subindo para o GBQ

# %%
client = bigquery.Client()
dataset_ref = client.dataset('cargos_lideranca')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 54 entries, 0 to 53
# Data columns (total 9 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   ano                          54 non-null     int64
#  1   sigla_uf                     54 non-null     object
#  2   cod_uf                       54 non-null     int64
#  3   uf                           54 non-null     object
#  4   caracterizacao_orgao_gestor  54 non-null     object
#  5   genero                       54 non-null     object
#  6   faixa_etaria                 53 non-null     category
#  7   cor_raca                     54 non-null     object
#  8   grau_instrucao               54 non-null     object
# dtypes: category(1), int64(2), object(6)
# memory usage: 4.0+ KB

# %%
schema=[bigquery.SchemaField('ano','INTEGER',description='Ano da apuração daquele dado'),
        bigquery.SchemaField('sigla_uf','STRING',description='Sigla da UF'),
        bigquery.SchemaField('cod_uf','INTEGER',description='Código do IBGE da UF'),
        bigquery.SchemaField('uf','STRING',description='Nome da UF'), 
        bigquery.SchemaField('caracterizacao_orgao_gestor','STRING',description='Caracterização do órgão no qual o gestor está'), 
        bigquery.SchemaField('genero','STRING',description='Gênero autodeclarado ou não'),
        bigquery.SchemaField('faixa_etaria','STRING',description='faixa etária da observação'),
        bigquery.SchemaField('cor_raca','STRING',description='Raça/cor da pessoa observada'),
        bigquery.SchemaField('grau_instrucao','STRING',description='Escolaridade da pessoa ou do vínculo observado com detalhamento na pós-graduação')
        ]

# %%
table_ref = dataset_ref.table('ESTADIC_perfil_gestor_saude_tipo_orgao')
job_config = bigquery.LoadJobConfig(schema=schema)
job = client.load_table_from_dataframe(df,table_ref, job_config=job_config)
job.result()
# Out:
# LoadJob<project=repositoriodedadosgpsp, location=US, id=e127e18f-e9cd-4482-8f97-3b56023cb0c5>
