# %%
import pandas as pd
import numpy as np
import os
import pandas_gbq
from google.cloud import bigquery
import glob
import openpyxl

# %%
os.chdir('G:\\\\Drives compartilhados\\\\República.org\\\\4. Equipes\\\\Dados e Comunicação\\\\DADOS\\\\415 - Repositório de Dados\\\\Repositório Local')

# %% [markdown]
# Chamando as bases

# %%
df18 = pd.read_excel('ESTADIC//Base_ESTADIC_2018.xlsx', sheet_name='Cultura', nrows=29, usecols=['Cod Uf', 'ECUL01','ECUL03','ECUL04', 'ECUL05', 'ECUL06'])
df18
# Out:
#     Cod Uf                                             ECUL01     ECUL03  \
# 0       11                               Secretaria exclusiva  Masculino
# 1       12                    Órgão da administração indireta   Feminino
# 2       13                               Secretaria exclusiva  Masculino
# 3       14                               Secretaria exclusiva   Feminino
# 4       15                               Secretaria exclusiva  Masculino
# 5       16                               Secretaria exclusiva  Masculino
# 6       17               Setor subordinado a outra secretaria  Masculino
# 7       21                               Secretaria exclusiva  Masculino
# 8       22                               Secretaria exclusiva   Feminino
# 9       23                               Secretaria exclusiva  Masculino
# 10      24                    Órgão da administração indireta   Feminino
# 11      25                               Secretaria exclusiva  Masculino
# 12      26                               Secretaria exclusiva  Masculino
# 13      27                               Secretaria exclusiva   Feminino
# 14      28                               Secretaria exclusiva  Masculino
# 15      29                               Secretaria exclusiva   Feminino
# 16      31                               Secretaria exclusiva  Masculino
# 17      32                               Secretaria exclusiva  Masculino
# 18      33                               Secretaria exclusiva  Masculino
# 19      35                               Secretaria exclusiva  Masculino
# 20      41                               Secretaria exclusiva  Masculino
# 21      42                    Órgão da administração indireta  Masculino
# 22      43  Secretaria em conjunto com outras políticas se...  Masculino
# 23      50  Secretaria em conjunto com outras políticas se...  Masculino
# 24      51                               Secretaria exclusiva  Masculino
# 25      52  Secretaria em conjunto com outras políticas se...  Masculino
# 26      53                               Secretaria exclusiva  Masculino
#
#     ECUL04  ECUL05                           ECUL06
# 0       27   Pardo       Ensino superior incompleto
# 1       48   Pardo                   Especialização
# 2       38  Branca                   Especialização
# 3       55   Pardo         Ensino superior completo
# 4       72  Branca                   Especialização
# 5       42   Pardo         Ensino superior completo
# 6       48  Branca         Ensino superior completo
# 7       32  Branca         Ensino superior completo
# 8       40   Pardo         Ensino superior completo
# 9       50   Pardo                        Doutorado
# 10      31  Branca                         Mestrado
# 11      61  Branca  Ensino médio (2º Grau) completo
# 12      58   Pardo         Ensino superior completo
# 13      34  Branca         Ensino superior completo
# 14      70  Branca         Ensino superior completo
# 15      67   Preto                   Especialização
# 16      70  Branca                   Especialização
# 17      66   Pardo                        Doutorado
# 18      39  Branca                   Especialização
# 19      49  Branca         Ensino superior completo
# 20      54  Branca       Ensino superior incompleto
# 21      68  Branca  Ensino médio (2º Grau) completo
# 22      57  Branca         Ensino superior completo
# 23      53  Branca         Ensino superior completo
# 24      57  Branca                   Especialização
# 25      73   Pardo                         Mestrado
# 26      64  Branca  Ensino médio (2º Grau) completo

# %%
df21 = pd.read_excel('ESTADIC//Base_ESTADIC_2021.xlsx', sheet_name='Cultura', nrows=29, usecols=['Cod UF', 'ECUL01','ECUL03','ECUL04', 'ECUL05', 'ECUL06'])
df21
# Out:
#     Cod UF                                             ECUL01     ECUL03  \
# 2                      Amazonas
# 3                       Roraima
# 4                          Pará
# 5                         Amapá
# 6                     Tocantins
# 7                      Maranhão
# 8                         Piauí
# 9                         Ceará
# 10          Rio Grande do Norte
# 11                      Paraíba
# 12                   Pernambuco
# 13                      Alagoas
# 14                      Sergipe
# 15                        Bahia
# 16                 Minas Gerais
# 17               Espírito Santo
# 18               Rio de Janeiro
# 19                    São Paulo
# 20                       Paraná
# 21               Santa Catarina
# 22            Rio Grande do Sul
# 23           Mato Grosso do Sul
# 24                  Mato Grosso
# 25                        Goiás
# 26             Distrito Federal

# %% [markdown]
# Renomeando as colunas

# %%
df18= df18.rename(columns={'Cod Uf':'cod_uf',
                        'ECUL01':'caracterizacao_orgao_gestor',
                        'ECUL03':'genero',
                        'ECUL04' :'idade',
                        'ECUL05':'cor_raca',
                        'ECUL06':'grau_instrucao'})

# %%
df21= df21.rename(columns={'Cod UF':'cod_uf',
                        'ECUL01':'caracterizacao_orgao_gestor',
                        'ECUL03':'genero',
                        'ECUL04' :'idade',
                        'ECUL05':'cor_raca',
                        'ECUL06':'grau_instrucao'})

# %%
##adicionando a coluna de 'ano' em cada um dos dfs
df18['ano']=2018
df21['ano']=2021

# %%
df = pd.concat([df18,df21]) #juntando os dataframes

# %%
x= uf.pivot_table(columns=('Código da Unidade da Federação', 'Sigla da Unidade da Federação', 'Nome da Unidade da Federação'), aggfunc='size')

# %%
uf = pd.DataFrame(x).reset_index()[['Código da Unidade da Federação', 'Sigla da Unidade da Federação', 'Nome da Unidade da Federação']]

# %%
df = df.merge(uf, right_on='Código da Unidade da Federação',left_on='cod_uf') #juntando os dataframes, adicionando sigla e nome das UFs

# %%
df = df.drop(['Código da Unidade da Federação'], axis=1) #eliminando coluna repetida

# %%
df = df.rename(columns={'Sigla da Unidade da Federação':'sigla_uf',
                        'Nome da Unidade da Federação':'uf'}) #padronizando as colunas

# %%
df['caracterizacao_orgao_gestor']=df['caracterizacao_orgao_gestor'].str.title()

# %%
#padronizando os dados da coluna 'cor_raca'
df['cor_raca'] = np.where(df['cor_raca']=='Pardo','Parda',df['cor_raca'])
df['cor_raca'] = np.where(df['cor_raca']=='Preto','Preta',df['cor_raca'])

# %%
limites = [0, 30, 50,65,100] #criando uma nova coluna (faixa_etaria) com base na coluna 'idade'
categorias = ['Entre 18-29', 'Entre 30-49', 'Entre 50-64', 'Acima de 65']

df['faixa_etaria'] = pd.cut(df['idade'], bins=limites, labels=categorias)

# %%
# criando dicionário
dict_esco = {'Ensino médio (2º Grau) completo':'Até Ensino Médio',
             'Ensino superior incompleto':'Até Ensino Superior Completo',
             'Ensino superior completo':'Até Ensino Superior Completo',
             'Especialização':'Até Pós Graduação ou Mestrado',
             'Mestrado':'Até Pós Graduação ou Mestrado',
             'Doutorado':'Até Doutorado'}

# %%
df = df.replace({'grau_instrucao':dict_esco})

# %%
df.columns
# Out:
# Index(['cod_uf', 'caracterizacao_orgao_gestor', 'genero', 'idade', 'cor_raca',
#        'grau_instrucao', 'ano', 'sigla_uf', 'uf', 'faixa_etaria'],
#       dtype='object')

# %%
df= df[['ano', 'sigla_uf','cod_uf', 'uf', 'caracterizacao_orgao_gestor','genero', 'faixa_etaria', 'cor_raca','grau_instrucao']]

# 18    Parda                  Até Doutorado
# 19   Branca                  Até Doutorado
# 20   Branca  Até Pós Graduação ou Mestrado
# 21    Parda  Até Pós Graduação ou Mestrado
# 22   Branca               Até Ensino Médio
# 23   Branca  Até Pós Graduação ou Mestrado
# 24    Parda   Até Ensino Superior Completo
# 25   Branca  Até Pós Graduação ou Mestrado
# 26   Branca   Até Ensino Superior Completo
# 27   Branca  Até Pós Graduação ou Mestrado
# 28   Branca   Até Ensino Superior Completo
# 29    Preta   Até Ensino Superior Completo
# 30    Preta  Até Pós Graduação ou Mestrado
# 31    Preta  Até Pós Graduação ou Mestrado
# 32   Branca  Até Pós Graduação ou Mestrado
# 33   Branca  Até Pós Graduação ou Mestrado
# 34    Parda                  Até Doutorado
# 35   Branca   Até Ensino Superior Completo
# 36   Branca  Até Pós Graduação ou Mestrado
# 37   Branca  Até Pós Graduação ou Mestrado
# 38   Branca   Até Ensino Superior Completo
# 39   Branca   Até Ensino Superior Completo
# 40   Branca   Até Ensino Superior Completo
# 41   Branca  Até Pós Graduação ou Mestrado
# 42   Branca               Até Ensino Médio
# 43   Branca   Até Ensino Superior Completo
# 44   Branca   Até Ensino Superior Completo
# 45   Branca   Até Ensino Superior Completo
# 46   Branca   Até Ensino Superior Completo
# 47    Parda               Até Ensino Médio
# 48   Branca  Até Pós Graduação ou Mestrado
# 49   Branca   Até Ensino Superior Completo
# 50    Parda  Até Pós Graduação ou Mestrado
# 51   Branca   Até Ensino Superior Completo
# 52   Branca               Até Ensino Médio
# 53   Branca   Até Ensino Superior Completo

# %% [markdown]
# Subindo para o GBQ

# %%
client = bigquery.Client()
dataset_ref = client.dataset('cargos_lideranca')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 54 entries, 0 to 53
# Data columns (total 9 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   ano                          54 non-null     int64
#  1   sigla_uf                     54 non-null     object
#  2   cod_uf                       54 non-null     int64
#  3   uf                           54 non-null     object
#  4   caracterizacao_orgao_gestor  54 non-null     object
#  5   genero                       54 non-null     object
#  6   faixa_etaria                 54 non-null     category
#  7   cor_raca                     54 non-null     object
#  8   grau_instrucao               54 non-null     object
# dtypes: category(1), int64(2), object(6)
# memory usage: 4.0+ KB

# %%
schema=[bigquery.SchemaField('ano','INTEGER',description='Ano da apuração daquele dado'),
        bigquery.SchemaField('sigla_uf','STRING',description='Sigla da UF'),
        bigquery.SchemaField('cod_uf','INTEGER',description='Código do IBGE da UF'),
        bigquery.SchemaField('uf','STRING',description='Nome da UF'), 
        bigquery.SchemaField('caracterizacao_orgao_gestor','STRING',description='Caracterização do órgão no qual o gestor está'), 
        bigquery.SchemaField('genero','STRING',description='Gênero autodeclarado ou não'),
        bigquery.SchemaField('faixa_etaria','STRING',description='faixa etária da observação'),
        bigquery.SchemaField('cor_raca','STRING',description='Raça/cor da pessoa observada'),
        bigquery.SchemaField('grau_instrucao','STRING',description='Escolaridade da pessoa ou do vínculo observado com detalhamento na pós-graduação')
        ]

# %%
table_ref = dataset_ref.table('ESTADIC_perfil_gestor_cultura_tipo_orgao')
job_config = bigquery.LoadJobConfig(schema=schema)
job = client.load_table_from_dataframe(df,table_ref, job_config=job_config)
job.result()
# Out:
# LoadJob<project=repositoriodedadosgpsp, location=US, id=3a9c375c-c411-40f7-9e13-086ba44c86f2>
