# %%
import pandas as pd
import numpy as np
import os
import pandas_gbq
from google.cloud import bigquery
import glob
import openpyxl

# %%
os.chdir('G:\\\\Drives compartilhados\\\\República.org\\\\4. Equipes\\\\Dados e Comunicação\\\\DADOS\\\\415 - Repositório de Dados\\\\Repositório Local')

# %% [markdown]
# Chamando as bases

# %%
df = pd.read_excel('ESTADIC//Base_ESTADIC_2020.xlsx', sheet_name='Meio Ambiente', nrows=29, usecols=['Cod UF', 'Emam01','Emam03','Emam04', 'Emam05', 'Emam06'])
df
# Out:
#     Cod UF                                             Emam01     Emam03  \
# 0       11                      Secretaria estadual exclusiva  Masculino
# 1       12                      Secretaria estadual exclusiva  Masculino
# 2       13                      Secretaria estadual exclusiva  Masculino
# 3       14                    Órgão da administração indireta  Masculino
# 4       15                      Secretaria estadual exclusiva  Masculino
# 5       16                      Secretaria estadual exclusiva  Masculino
# 6       17  Secretaria estadual em conjunto com outras pol...   Feminino
# 7       21                      Secretaria estadual exclusiva  Masculino
# 8       22                      Secretaria estadual exclusiva   Feminino
# 9       23                      Secretaria estadual exclusiva  Masculino
# 10      24  Secretaria estadual em conjunto com outras pol...  Masculino
# 11      25  Secretaria estadual em conjunto com outras pol...  Masculino
# 12      26                      Secretaria estadual exclusiva  Masculino
# 13      27  Secretaria estadual em conjunto com outras pol...  Masculino
# 14      28  Secretaria estadual em conjunto com outras pol...  Masculino
# 15      29                      Secretaria estadual exclusiva  Masculino
# 16      31                      Secretaria estadual exclusiva   Feminino
# 17      32                      Secretaria estadual exclusiva  Masculino
# 18      33                      Secretaria estadual exclusiva  Masculino
# 19      35  Secretaria estadual em conjunto com outras pol...  Masculino
# 20      41  Secretaria estadual em conjunto com outras pol...  Masculino
# 21      42                      Secretaria estadual exclusiva  Masculino
# 22      43  Secretaria estadual em conjunto com outras pol...  Masculino
# 23      50                    Órgão da administração indireta  Masculino
# 24      51                      Secretaria estadual exclusiva   Feminino
# 25      52                      Secretaria estadual exclusiva   Feminino
# 26      53                      Secretaria estadual exclusiva  Masculino
#
#     Emam04   Emam05                      Emam06
# 0       48    Parda              Especialização
# 1       32   Branca    Ensino superior completo
# 2       43   Branca                    Mestrado
# 3       57    Parda              Especialização
# 4       52    Parda                    Mestrado
# 5       62   Branca                    Mestrado
# 6       63  Amarela    Ensino superior completo
# 7       37    Parda              Especialização
# 8       54   Branca                   Doutorado
# 9       61   Branca    Ensino superior completo
# 10      62    Preta              Especialização
# 11      50   Branca              Especialização
# 12      51   Branca                    Mestrado
# 13      32   Branca  Ensino superior incompleto
# 14      43    Parda              Especialização
# 15      66   Branca    Ensino superior completo
# 16      42   Branca                   Doutorado
# 17      48   Branca  Ensino superior incompleto
# 18      34   Branca    Ensino superior completo
# 19      65   Branca                   Doutorado
# 20      54   Branca    Ensino superior completo
# 21      40   Branca                   Doutorado
# 22      40   Branca    Ensino superior completo
# 23      41   Branca              Especialização
# 24      42   Branca              Especialização
# 25      49   Branca                    Mestrado
# 26      63   Branca    Ensino superior completo

# %%
uf = pd.read_excel('ESTADIC//Base_ESTADIC_2020.xlsx', sheet_name = 'Variáveis externas', usecols=[1,2,3])
uf
# Out:
#     Código da Unidade da Federação Sigla da Unidade da Federação  \
# 0                               11                            RO
# 1                               12                            AC
# 2                               13                            AM
# 3                               14                            RR
# 4                               15                            PA
# 5                               16                            AP
# 6                               17                            TO
# 7                               21                            MA
# 8                               22                            PI
# 9                               23                            CE
# 10                              24                            RN
# 11                              25                            PB
# 12                              26                            PE
# 13                              27                            AL
# 14                              28                            SE
# 15                              29                            BA
# 16                              31                            MG
# 17                              32                            ES
# 18                              33                            RJ
# 19                              35                            SP
# 20                              41                            PR
# 21                              42                            SC
# 22                              43                            RS
# 23                              50                            MS
# 24                              51                            MT
# 25                              52                            GO
# 26                              53                            DF
#
#    Nome da Unidade da Federação
# 0                      Rondônia
# 1                          Acre
# 2                      Amazonas
# 3                       Roraima
# 4                          Pará
# 5                         Amapá
# 6                     Tocantins
# 7                      Maranhão
# 8                         Piauí
# 9                         Ceará
# 10          Rio Grande do Norte
# 11                      Paraíba
# 12                   Pernambuco
# 13                      Alagoas
# 14                      Sergipe
# 15                        Bahia
# 16                 Minas Gerais
# 17               Espírito Santo
# 18               Rio de Janeiro
# 19                    São Paulo
# 20                       Paraná
# 21               Santa Catarina
# 22            Rio Grande do Sul
# 23           Mato Grosso do Sul
# 24                  Mato Grosso
# 25                        Goiás
# 26             Distrito Federal

# %% [markdown]
# Renomeando as colunas

# %%
df.columns
# Out:
# Index(['Cod UF', 'Emam01', 'Emam03', 'Emam04', 'Emam05', 'Emam06'], dtype='object')

# %%
df= df.rename(columns={ 'Cod UF':'cod_uf',
                        'Emam01':'caracterizacao_orgao_gestor',
                        'Emam03':'genero',
                        'Emam04':'idade',
                        'Emam05':'cor_raca',
                        'Emam06':'grau_instrucao'})

# %%
df['ano']=2020 #adicionando a coluna ano

# %%
x= uf.pivot_table(columns=('Código da Unidade da Federação', 'Sigla da Unidade da Federação', 'Nome da Unidade da Federação'), aggfunc='size')

# %%
uf = pd.DataFrame(x).reset_index()[['Código da Unidade da Federação', 'Sigla da Unidade da Federação', 'Nome da Unidade da Federação']]

# %%
df = df.merge(uf, right_on='Código da Unidade da Federação',left_on='cod_uf') #juntando os dataframes, adicionando sigla e nome das UFs

# %%
df = df.drop(['Código da Unidade da Federação'], axis=1) #eliminando coluna repetida

# %%
df = df.rename(columns={'Sigla da Unidade da Federação':'sigla_uf',
                        'Nome da Unidade da Federação':'uf'}) #padronizando as colunas

# %%
df['caracterizacao_orgao_gestor'] = df['caracterizacao_orgao_gestor'].str.title()

# %%
limites = [0, 30, 50,65,100] #criando uma nova coluna (faixa_etaria) com base na coluna 'idade'
categorias = ['Entre 18-29', 'Entre 30-49', 'Entre 50-64', 'Acima de 65']

df['faixa_etaria'] = pd.cut(df['idade'], bins=limites, labels=categorias)

# %%
df= df[['ano', 'sigla_uf','cod_uf', 'uf', 'caracterizacao_orgao_gestor', 'genero', 'faixa_etaria', 'cor_raca','grau_instrucao']]

# %%
# criando dicionário
dict_esco = {'Ensino superior incompleto':'Até Ensino Superior Completo',
             'Ensino superior completo':'Até Ensino Superior Completo',
             'Especialização':'Até Pós Graduação ou Mestrado',
             'Mestrado':'Até Pós Graduação ou Mestrado',
             'Doutorado':'Até Doutorado'}

# %%
df = df.replace({'grau_instrucao':dict_esco})

# %% [markdown]
# Subindo para o GBQ

# %%
client = bigquery.Client()
dataset_ref = client.dataset('cargos_lideranca')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 27 entries, 0 to 26
# Data columns (total 9 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   ano                          27 non-null     int64
#  1   sigla_uf                     27 non-null     object
#  2   cod_uf                       27 non-null     int64
#  3   uf                           27 non-null     object
#  4   caracterizacao_orgao_gestor  27 non-null     object
#  5   genero                       27 non-null     object
#  6   faixa_etaria                 27 non-null     category
#  7   cor_raca                     27 non-null     object
#  8   grau_instrucao               27 non-null     object
# dtypes: category(1), int64(2), object(6)
# memory usage: 2.1+ KB

# %%
schema=[bigquery.SchemaField('ano','INTEGER',description='Ano da apuração daquele dado'),
        bigquery.SchemaField('sigla_uf','STRING',description='Sigla da UF'),
        bigquery.SchemaField('cod_uf','INTEGER',description='Código do IBGE da UF'),
        bigquery.SchemaField('uf','STRING',description='Nome da UF'),        
        bigquery.SchemaField('caracterizacao_orgao_gestor','STRING',description='Caracterização do órgão no qual o gestor está'),
        bigquery.SchemaField('genero','STRING',description='Gênero autodeclarado ou não'),
        bigquery.SchemaField('faixa_etaria','STRING',description='faixa etária da observação'),
        bigquery.SchemaField('cor_raca','STRING',description='Raça/cor da pessoa observada'),
        bigquery.SchemaField('grau_instrucao','STRING',description='Escolaridade da pessoa ou do vínculo observado com detalhamento na pós-graduação')
        ]

# %%
table_ref = dataset_ref.table('ESTADIC_perfil_gestor_meio_ambiente_tipo_orgao')
job_config = bigquery.LoadJobConfig(schema=schema)
job = client.load_table_from_dataframe(df,table_ref, job_config=job_config)
job.result()
# Out:
# LoadJob<project=repositoriodedadosgpsp, location=US, id=f92aaf90-2c77-460e-b419-fa2d310ac0fb>
