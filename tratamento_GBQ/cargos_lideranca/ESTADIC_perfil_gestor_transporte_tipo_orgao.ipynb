# %%
# Install required Google Cloud packages (commented out as these are typically one-time setup commands)
# !pip install gcloud
# !gcloud auth application-default login

# Import necessary Python libraries
import pandas as pd                # Data manipulation and analysis
import numpy as np                 # Numerical computing
import time                        # Time-related functions
import os                          # Operating system interfaces
import pandas_gbq                  # Pandas integration with BigQuery
from google.cloud import bigquery  # BigQuery client library
import glob                        # File path pattern matching
import openpyxl                    # Excel file handling
import csv                         # CSV file handling
import re                          # Regular expressions

# Note: The actual imports remain exactly as in the original code
# Out:
# Collecting gcloud
#   Downloading gcloud-0.18.3.tar.gz (454 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 454.4/454.4 kB 2.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: httplib2>=0.9.1 in /usr/local/lib/python3.12/dist-packages (from gcloud) (0.32.0)
# Requirement already satisfied: googleapis-common-protos in /usr/local/lib/python3.12/dist-packages (from gcloud) (1.75.0)
# Requirement already satisfied: oauth2client>=2.0.1 in /usr/local/lib/python3.12/dist-packages (from gcloud) (4.1.3)
# Requirement already satisfied: protobuf!=3.0.0.b2.post1,>=3.0.0b2 in /usr/local/lib/python3.12/dist-packages (from gcloud) (5.29.6)
# Requirement already satisfied: six in /usr/local/lib/python3.12/dist-packages (from gcloud) (1.17.0)
# Requirement already satisfied: pyparsing<4,>=3.1 in /usr/local/lib/python3.12/dist-packages (from httplib2>=0.9.1->gcloud) (3.3.2)
# Requirement already satisfied: pyasn1>=0.1.7 in /usr/local/lib/python3.12/dist-packages (from oauth2client>=2.0.1->gcloud) (0.6.4)
# Requirement already satisfied: pyasn1-modules>=0.0.5 in /usr/local/lib/python3.12/dist-packages (from oauth2client>=2.0.1->gcloud) (0.4.2)
# Requirement already satisfied: rsa>=3.1.4 in /usr/local/lib/python3.12/dist-packages (from oauth2client>=2.0.1->gcloud) (4.9.1)
# Building wheels for collected packages: gcloud
#   Building wheel for gcloud (setup.py) ... done
#   Created wheel for gcloud: filename=gcloud-0.18.3-py3-none-any.whl size=602927 sha256=cfad7a6ab2bc2631a602dfa3915021c92283c4c46757cb1a6e8d4e9346fdf0fb
#   Stored in directory: /root/.cache/pip/wheels/2a/62/75/3d74209bfebb8805823ae74afa28653aa1ea76d8b5a9d741ff
# Successfully built gcloud
# Installing collected packages: gcloud
# Successfully installed gcloud-0.18.3
# Go to the following link in your browser, and complete the sign-in prompts:
#
#     https://accounts.google.com/o/oauth2/auth?response_type=code&client_id=764086051850-6qr4p6gpi6hn506pt8ejuq83di341hur.apps.googleusercontent.com&redirect_uri=https%3A%2F%2Fsdk.cloud.google.com%2Fapplicationdefaultauthcode.html&scope=openid+https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fuserinfo.email+https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fcloud-platform+https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fsqlservice.login&state=VX0BatZiSJ9PCgzQHDrHZ7v3yfMkOA&prompt=consent&token_usage=remote&access_type=offline&code_challenge=ueWFTyn0cBYt_6pt031XrBm5UFoe6JJ325cMuXwdg5E&code_challenge_method=S256
#
# Once finished, enter the verification code provided in your browser: 4/0AXEQxIBbM0xAUVjyheuXExcRRUXWgq9S2HrL73IGaNnFmAin4qZ1NrhgHBnrwlDq0az1Wg
#
# Credentials saved to file: [/content/.config/application_default_credentials.json]
#
# These credentials will be used by any library that requests Application Default Credentials (ADC).
# WARNING:
# Cannot find a quota project to add to ADC. You might receive a "quota exceeded" or "API not enabled" error. Run $ gcloud auth application-default set-quota-project to add a quota project.
#
#
# To take a quick anonymous survey, run:
#   $ gcloud survey

# %% [markdown]
# Chamando as bases

# %%
df = pd.read_excel('/content/Base_Estadic_2024.xlsx', sheet_name='Transporte', nrows=29, usecols=['Cod UF', 'Etra01','Etra03','Etra04', 'Etra05', 'Etra06'])
df
# Out:
#     Cod UF                                             Etra01        Etra03  \
# 0       11                                       Não informou  Não informou
# 1       12                    Órgão da administração indireta     Masculino
# 2       13               Setor subordinado a outra secretaria     Masculino
# 3       14                               Não possui estrutura             -
# 4       15               Setor subordinado a outra secretaria     Masculino
# 5       16                      Secretaria estadual exclusiva     Masculino
# 6       17                    Órgão da administração indireta     Masculino
# 7       21                    Órgão da administração indireta     Masculino
# 8       22                      Secretaria estadual exclusiva     Masculino
# 9       23               Setor subordinado a outra secretaria     Masculino
# 10      24               Setor subordinado a outra secretaria     Masculino
# 11      25                    Órgão da administração indireta     Masculino
# 12      26  Secretaria estadual em conjunto com outras pol...     Masculino
# 13      27  Secretaria estadual em conjunto com outras pol...     Masculino
# 14      28                    Órgão da administração indireta     Masculino
# 15      29                    Órgão da administração indireta     Masculino
# 16      31  Secretaria estadual em conjunto com outras pol...     Masculino
# 17      32                    Órgão da administração indireta     Masculino
# 18      33                      Secretaria estadual exclusiva     Masculino
# 19      35                      Secretaria estadual exclusiva     Masculino
# 20      41               Setor subordinado a outra secretaria     Masculino
# 21      42  Secretaria estadual em conjunto com outras pol...     Masculino
# 22      43                      Secretaria estadual exclusiva     Masculino
# 23      50                    Órgão da administração indireta     Masculino
# 24      51  Secretaria estadual em conjunto com outras pol...      Feminino
# 25      52  Secretaria estadual em conjunto com outras pol...     Masculino
# 26      53                      Secretaria estadual exclusiva     Masculino
#
#           Etra04        Etra05                           Etra06
# 0   Não informou  Não informou                     Não informou
# 1             52        Branca         Ensino superior completo
# 2             59        Branca         Ensino superior completo
# 3              -             -                                -
# 4             52         Parda         Ensino superior completo
# 5             64         Parda         Ensino superior completo
# 6             28         Parda                   Especialização
# 7             41         Parda         Ensino superior completo
# 8             65         Parda         Ensino superior completo
# 9             70        Branca         Ensino superior completo
# 10            61        Branca                         Mestrado
# 11            85        Branca         Ensino superior completo
# 12            46         Parda                        Doutorado
# 13            66        Branca         Ensino superior completo
# 14            41         Parda         Ensino superior completo
# 15            60        Branca         Ensino superior completo
# 16            39        Branca         Ensino superior completo
# 17            47        Branca         Ensino superior completo
# 18            57        Branca  Ensino médio (2º Grau) completo
# 19            70        Branca         Ensino superior completo
# 20            47        Branca                   Especialização
# 21            49        Branca  Ensino médio (2º Grau) completo
# 22            65        Branca       Ensino superior incompleto
# 23            65        Branca         Ensino superior completo
# 24            50         Preta                   Especialização
# 25            42        Branca                         Mestrado
# 26            56        Branca                   Especialização

# %%
uf = pd.read_excel('/content/Base_Estadic_2020.xlsx', sheet_name = 'Variáveis externas', usecols=[1,2,3])
uf
# Out:
#     Código da Unidade da Federação Sigla da Unidade da Federação  \
# 0                               11                            RO
# 1                               12                            AC
# 2                               13                            AM
# 3                               14                            RR
# 4                               15                            PA
# 5                               16                            AP
# 6                               17                            TO
# 7                               21                            MA
# 8                               22                            PI
# 9                               23                            CE
# 10                              24                            RN
# 11                              25                            PB
# 12                              26                            PE
# 13                              27                            AL
# 14                              28                            SE
# 15                              29                            BA
# 16                              31                            MG
# 17                              32                            ES
# 18                              33                            RJ
# 19                              35                            SP
# 20                              41                            PR
# 21                              42                            SC
# 22                              43                            RS
# 23                              50                            MS
# 24                              51                            MT
# 25                              52                            GO
# 26                              53                            DF
#
#    Nome da Unidade da Federação
# 0                      Rondônia
# 1                          Acre
# 2                      Amazonas
# 3                       Roraima
# 4                          Pará
# 5                         Amapá
# 6                     Tocantins
# 7                      Maranhão
# 8                         Piauí
# 9                         Ceará
# 10          Rio Grande do Norte
# 11                      Paraíba
# 12                   Pernambuco
# 13                      Alagoas
# 14                      Sergipe
# 15                        Bahia
# 16                 Minas Gerais
# 17               Espírito Santo
# 18               Rio de Janeiro
# 19                    São Paulo
# 20                       Paraná
# 21               Santa Catarina
# 22            Rio Grande do Sul
# 23           Mato Grosso do Sul
# 24                  Mato Grosso
# 25                        Goiás
# 26             Distrito Federal

# %% [markdown]
# Renomeando as colunas

# %%
df.columns
# Out:
# Index(['Cod UF', 'Etra01', 'Etra03', 'Etra04', 'Etra05', 'Etra06'], dtype='object')

# %%
df= df.rename(columns={'Cod UF':'cod_uf',
                       'Etra01':'caracterizacao_orgao_gestor',
                        'Etra03':'genero',
                        'Etra04':'idade',
                        'Etra05':'cor_raca',
                        'Etra06':'grau_instrucao'})

# %%
df['ano']=2024

# %%
x= uf.pivot_table(columns=('Código da Unidade da Federação', 'Sigla da Unidade da Federação', 'Nome da Unidade da Federação'), aggfunc='size')

# %%
uf = pd.DataFrame(x).reset_index()[['Código da Unidade da Federação', 'Sigla da Unidade da Federação', 'Nome da Unidade da Federação']]

# %%
df = df.merge(uf, right_on='Código da Unidade da Federação',left_on='cod_uf') #juntando os dataframes, adicionando sigla e nome das UFs

# %%
df = df.drop(['Código da Unidade da Federação'], axis=1) #eliminando coluna repetida

# %%
df = df.rename(columns={'Sigla da Unidade da Federação':'sigla_uf',
                        'Nome da Unidade da Federação':'uf'}) #padronizando as colunas

# %%
df['caracterizacao_orgao_gestor']=df['caracterizacao_orgao_gestor'].str.title()

# %%
limites = [0, 30, 50, 65, 100]
categorias = ['Entre 18-29', 'Entre 30-49', 'Entre 50-64', 'Acima de 65']

idade_num = pd.to_numeric(df['idade'], errors='coerce')  # "Não informou" -> NaN

df['faixa_etaria'] = pd.cut(idade_num, bins=limites, labels=categorias, right=False)
df['faixa_etaria'] = df['faixa_etaria'].cat.add_categories('Não informou').fillna('Não informou')

# %%
df['grau_instrucao'].unique()
# Out:
# array(['Não informou', 'Ensino superior completo', '-', 'Especialização',
#        'Mestrado', 'Doutorado', 'Ensino médio (2º Grau) completo',
#        'Ensino superior incompleto'], dtype=object)

# %%
df= df[['ano', 'sigla_uf','cod_uf', 'uf', 'caracterizacao_orgao_gestor','genero', 'faixa_etaria', 'cor_raca','grau_instrucao']]

# %%
# criando dicionário
dict_esco = {'Ensino médio (2º Grau) completo':'Até Ensino Médio',
             'Ensino superior completo':'Até Ensino Superior',
             'Ensino superior incompleto':'Até Ensino Superior',
             'Especialização':'Até Pós Graduação ou Mestrado',
             'Mestrado':'Até Pós Graduação ou Mestrado',
             'Doutorado':'Até Pós Graduação ou Mestrado'}

# %%
df = df.replace({'grau_instrucao':dict_esco}) #substituindo valores para padronizar

# %%
df.columns
# Out:
# Index(['ano', 'sigla_uf', 'cod_uf', 'uf', 'caracterizacao_orgao_gestor',
#        'genero', 'faixa_etaria', 'cor_raca', 'grau_instrucao'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27 entries, 0 to 26
# Data columns (total 9 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   ano                          27 non-null     int64
#  1   sigla_uf                     27 non-null     object
#  2   cod_uf                       27 non-null     int64
#  3   uf                           27 non-null     object
#  4   caracterizacao_orgao_gestor  27 non-null     object
#  5   genero                       27 non-null     object
#  6   faixa_etaria                 27 non-null     category
#  7   cor_raca                     27 non-null     object
#  8   grau_instrucao               27 non-null     object
# dtypes: category(1), int64(2), object(6)
# memory usage: 2.0+ KB

# %% [markdown]
# # Consumindo a base anterior para agregar o novo ano

# %%
query = """SELECT * FROM `repositoriodedadosgpsp.cargos_lideranca.ESTADIC_perfil_gestor_transporte_tipo_orgao`"""
# Execute the query using pandas_gbq.read_gbq and load the result into a pandas DataFrame called 'df'.
# The 'project_id' specifies the Google Cloud Project to use.
df_old = pandas_gbq.read_gbq(query, project_id='repositoriodedadosgpsp')
# Out:
# Downloading: 100%|██████████|

# %%
df_final = pd.concat([df, df_old], ignore_index=True)

# %%
df_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54 entries, 0 to 53
# Data columns (total 9 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   ano                          54 non-null     Int64
#  1   sigla_uf                     54 non-null     object
#  2   cod_uf                       54 non-null     Int64
#  3   uf                           54 non-null     object
#  4   caracterizacao_orgao_gestor  54 non-null     object
#  5   genero                       54 non-null     object
#  6   faixa_etaria                 54 non-null     object
#  7   cor_raca                     54 non-null     object
#  8   grau_instrucao               54 non-null     object
# dtypes: Int64(2), object(7)
# memory usage: 4.0+ KB

# %%
#padronizando os dados da coluna 'tipo_orgao'
df_final['caracterizacao_orgao_gestor']=np.where(df_final['caracterizacao_orgao_gestor']=='Não Informou','Sem dados',df_final['caracterizacao_orgao_gestor'])
df_final['caracterizacao_orgao_gestor']=np.where(df_final['caracterizacao_orgao_gestor']=='-','Sem dados',df_final['caracterizacao_orgao_gestor'])

#padronizando os dados da coluna 'genero'
df_final['genero']=np.where(df_final['genero']=='Não informou','Sem dados',df_final['genero'])
df_final['genero']=np.where(df_final['genero']=='-','Sem dados',df_final['genero'])

#padronizando os dados da coluna 'idade'
df_final['faixa_etaria']=np.where(df_final['faixa_etaria']=='-',np.nan,df_final['faixa_etaria'])
df_final['faixa_etaria']=np.where(df_final['faixa_etaria']=='Não informou',np.nan,df_final['faixa_etaria'])


#padronizando os dados da coluna 'cor_raca'

df_final['cor_raca']=np.where(df_final['cor_raca']=='Não informou','Sem dados',df_final['cor_raca'])
df_final['cor_raca']=np.where(df_final['cor_raca']=='-','Sem dados',df_final['cor_raca'])


#padronizando os dados da coluna 'escolaridade'
df_final['grau_instrucao']=np.where(df_final['grau_instrucao']=='-','Sem dados',df_final['grau_instrucao'])
df_final['grau_instrucao']=np.where(df_final['grau_instrucao']=='Não informou','Sem dados',df_final['grau_instrucao'])
df_final['grau_instrucao']=np.where(df_final['grau_instrucao']=='Até Ensino Superior Completo','Até Ensino Superior',df_final['grau_instrucao'])

# %%
df_final['grau_instrucao'].unique()
# Out:
# array(['Sem dados', 'Até Ensino Superior',
#        'Até Pós Graduação ou Mestrado', 'Até Ensino Médio'], dtype=object)

# %% [markdown]
# # Subindo para o GBQ

# %%
# Define the BigQuery table schema with Portuguese descriptions
schema=[bigquery.SchemaField('ano','INTEGER',description='Ano da apuração daquele dado'),
        bigquery.SchemaField('sigla_uf','STRING',description='Sigla da UF'),
        bigquery.SchemaField('cod_uf','INTEGER',description='Código do IBGE da UF'),
        bigquery.SchemaField('uf','STRING',description='Nome da UF'),
        bigquery.SchemaField('caracterizacao_orgao_gestor','STRING',description='Caracterização do órgão no qual o gestor está'),
        bigquery.SchemaField('genero','STRING',description='Gênero autodeclarado ou não'),
        bigquery.SchemaField('faixa_etaria','STRING',description='faixa etária da observação'),
        bigquery.SchemaField('cor_raca','STRING',description='Raça/cor da pessoa observada'),
        bigquery.SchemaField('grau_instrucao','STRING',description='Escolaridade da pessoa ou do vínculo observado com detalhamento na pós-graduação')
        ]

# Initialize BigQuery client connection
client = bigquery.Client(project='repositoriodedadosgpsp')

# Create reference to target dataset
dataset_ref = client.dataset('cargos_lideranca')

# Create reference to target table with standardized naming convention:
# FONTE_algo_intuitivo_dado (MUNIC_quantidade_vinculos_mapa_v1)
table_ref = dataset_ref.table('ESTADIC_perfil_gestor_transporte_tipo_orgao_v5')

# Configure the load job with our schema definition
job_config = bigquery.LoadJobConfig(
    schema=schema,
    # Optional parameters (commented out):
    # write_disposition="WRITE_TRUNCATE",  # Overwrites table if exists
    # create_disposition="CREATE_IF_NEEDED"  # Default behavior
)

# Execute the load job to upload DataFrame to BigQuery
job = client.load_table_from_dataframe(
    dataframe=df_final,
    destination=table_ref,
    job_config=job_config
)

# Wait for the job to complete
job.result()
# Out:
# /usr/local/lib/python3.12/dist-packages/google/auth/_default.py:114: UserWarning: Your application has authenticated using end user credentials from Google Cloud SDK without a quota project. You might receive a "quota exceeded" or "API not enabled" error. See the following page for troubleshooting: https://cloud.google.com/docs/authentication/adc-troubleshooting/user-creds.
#   warnings.warn(_CLOUD_SDK_CREDENTIALS_WARNING)
# LoadJob<project=repositoriodedadosgpsp, location=US, id=c8745be6-8f58-4278-8875-792d1e98b364>
