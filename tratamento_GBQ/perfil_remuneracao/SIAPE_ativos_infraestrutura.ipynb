# %%
import pandas as pd
import time
import os
import pandas_gbq
from google.cloud import bigquery
import numpy as np
import re

# %%
os.chdir('G:\\Drives compartilhados\\República.org\\4. Equipes\\Dados e Comunicação\\DADOS\\415 - Repositório de Dados\\Dados para subir\\Tabelas finais')

# %%
df = pd.read_csv('SIAPE_ativos_infraestrutura.csv')
df
# Out:
#       ano                                        ministerios  \
# 0    1999  ministerio da industria, comercio exterior e s...
# 1    1999                  ministerio da integracao nacional
# 2    1999                        ministerio das comunicacoes
# 3    1999                      ministerio de minas e energia
# 4    1999                        ministerio do meio ambiente
# ..    ...                                                ...
# 129  2018                  ministerio da integracao nacional
# 130  2018                             ministerio das cidades
# 131  2018                      ministerio de minas e energia
# 132  2018                        ministerio do meio ambiente
# 133  2018  ministerio dos transportes, portos e aviacao c...
#
#      servidores_ativos_ministerios  total_servidores_ativos  perc_servidores
# 0                             2511                   482854             0.52
# 1                             3025                   482854             0.63
# 2                             1094                   482854             0.23
# 3                             2218                   482854             0.46
# 4                             5957                   482854             1.23
# ..                             ...                      ...              ...
# 129                           2380                   611916             0.39
# 130                            405                   611916             0.07
# 131                           4097                   611916             0.67
# 132                           8771                   611916             1.43
# 133                           6365                   611916             1.04
#
# [134 rows x 5 columns]

# %%
df['ministerios'] = df['ministerios'].str.title() #padronizando

# %%
def transformar(nome):
    nome = re.sub(r"\bMinisterio\b", "Ministério",nome)
    nome = re.sub(r"\bIndustria\b", "Indústria",nome)
    nome = re.sub(r"\bComercio\b", "Comércio",nome)
    nome = re.sub(r"\bServicos\b", "Serviços",nome)
    nome = re.sub(r"\bIntegracao\b", "Integração",nome)
    nome = re.sub(r"\bComunicacoes\b", "Comunicações",nome)
    nome = re.sub(r"\bAviacao\b", "Aviação",nome)
    return nome

# %%
df['ministerios'] = df['ministerios'].apply(transformar)

# %%
df
# Out:
#       ano                                        ministerios  \
# 0    1999  Ministério Da Indústria, Comércio Exterior E S...
# 1    1999                  Ministério Da Integração Nacional
# 2    1999                        Ministério Das Comunicações
# 3    1999                      Ministério De Minas E Energia
# 4    1999                        Ministério Do Meio Ambiente
# ..    ...                                                ...
# 129  2018                  Ministério Da Integração Nacional
# 130  2018                             Ministério Das Cidades
# 131  2018                      Ministério De Minas E Energia
# 132  2018                        Ministério Do Meio Ambiente
# 133  2018  Ministério Dos Transportes, Portos E Aviação C...
#
#      servidores_ativos_ministerios  total_servidores_ativos  perc_servidores
# 0                             2511                   482854             0.52
# 1                             3025                   482854             0.63
# 2                             1094                   482854             0.23
# 3                             2218                   482854             0.46
# 4                             5957                   482854             1.23
# ..                             ...                      ...              ...
# 129                           2380                   611916             0.39
# 130                            405                   611916             0.07
# 131                           4097                   611916             0.67
# 132                           8771                   611916             1.43
# 133                           6365                   611916             1.04
#
# [134 rows x 5 columns]

# %%
df['ministerios'].unique()
# Out:
# array(['Ministério Da Indústria, Comércio Exterior E Serviços',
#        'Ministério Da Integração Nacional', 'Ministério Das Comunicações',
#        'Ministério De Minas E Energia', 'Ministério Do Meio Ambiente',
#        'Ministério Dos Transportes, Portos E Aviação Civil',
#        'Ministério Das Cidades'], dtype=object)

# %%
df = df.drop(['total_servidores_ativos'], axis=1)

# %%
df.rename(columns={'perc_servidores': 'per_servidores'}, inplace=True)
df
# Out:
#       ano                                        ministerios  \
# 0    1999  Ministério Da Indústria, Comércio Exterior E S...
# 1    1999                  Ministério Da Integração Nacional
# 2    1999                        Ministério Das Comunicações
# 3    1999                      Ministério De Minas E Energia
# 4    1999                        Ministério Do Meio Ambiente
# ..    ...                                                ...
# 129  2018                  Ministério Da Integração Nacional
# 130  2018                             Ministério Das Cidades
# 131  2018                      Ministério De Minas E Energia
# 132  2018                        Ministério Do Meio Ambiente
# 133  2018  Ministério Dos Transportes, Portos E Aviação C...
#
#      servidores_ativos_ministerios  per_servidores
# 0                             2511            0.52
# 1                             3025            0.63
# 2                             1094            0.23
# 3                             2218            0.46
# 4                             5957            1.23
# ..                             ...             ...
# 129                           2380            0.39
# 130                            405            0.07
# 131                           4097            0.67
# 132                           8771            1.43
# 133                           6365            1.04
#
# [134 rows x 4 columns]

# %%
df['per_servidores'] = df['per_servidores']/100

# %%
df
# Out:
#       ano                                        ministerios  \
# 0    1999  Ministério Da Indústria, Comércio Exterior E S...
# 1    1999                  Ministério Da Integração Nacional
# 2    1999                        Ministério Das Comunicações
# 3    1999                      Ministério De Minas E Energia
# 4    1999                        Ministério Do Meio Ambiente
# ..    ...                                                ...
# 129  2018                  Ministério Da Integração Nacional
# 130  2018                             Ministério Das Cidades
# 131  2018                      Ministério De Minas E Energia
# 132  2018                        Ministério Do Meio Ambiente
# 133  2018  Ministério Dos Transportes, Portos E Aviação C...
#
#      servidores_ativos_ministerios  per_servidores
# 0                             2511          0.0052
# 1                             3025          0.0063
# 2                             1094          0.0023
# 3                             2218          0.0046
# 4                             5957          0.0123
# ..                             ...             ...
# 129                           2380          0.0039
# 130                            405          0.0007
# 131                           4097          0.0067
# 132                           8771          0.0143
# 133                           6365          0.0104
#
# [134 rows x 4 columns]

# %% [markdown]
# Subindo para o GBQ

# %%
client = bigquery.Client()
dataset_ref = client.dataset('perfil_remuneracao')
# Out:
# c:\Users\ana.sales_republica\Anaconda\lib\site-packages\google\auth\_default.py:78: UserWarning: Your application has authenticated using end user credentials from Google Cloud SDK without a quota project. You might receive a "quota exceeded" or "API not enabled" error. See the following page for troubleshooting: https://cloud.google.com/docs/authentication/adc-troubleshooting/user-creds.
#   warnings.warn(_CLOUD_SDK_CREDENTIALS_WARNING)

# %%
schema= [bigquery.SchemaField('ano','INTEGER',description='Ano de referência da observação'),
          bigquery.SchemaField('ministerios','STRING',description='Ministérios observados'),
          bigquery.SchemaField('servidores_ativos_ministerios', 'INTEGER',description='Número de servidores ativos por ministério'),
          bigquery.SchemaField('per_servidores','FLOAT', description='Percentual de servidores ativos por ministério ')]

# %%
table_ref = dataset_ref.table('SIAPE_ativos_infraestrutura') 
job_config = bigquery.LoadJobConfig(schema=schema)
job = client.load_table_from_dataframe(df, table_ref, job_config=job_config)
job.result()
# Out:
# LoadJob<project=repositoriodedadosgpsp, location=US, id=b6553bbc-5cf2-4c3b-a719-9119bea3d5be>
