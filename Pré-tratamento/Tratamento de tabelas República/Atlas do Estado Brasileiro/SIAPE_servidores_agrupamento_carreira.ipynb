# %%
import pandas as pd
import numpy as np
import os

# %%
os.chdir('G:\\Drives compartilhados\\República.org\\4. Equipes\\Dados e Comunicação\\DADOS\\415 - Repositório de Dados\\Dados para subir\\Tabelas finais')

# %%
df_wide = pd.read_csv("SIAPE_servidores_agrupamento_carreira.csv", sep = ";")
df_wide
# Out:
#      ano  social  economia_financas_gestao  \
# 0   2004  167438                      3214
# 1   2005  167511                      3350
# 2   2006  178166                      3693
# 3   2007  178301                      3807
# 4   2008  182809                      3760
# 5   2009  216913                      4247
# 6   2010  233343                      4278
# 7   2011  236857                      4435
# 8   2012  240316                      4613
# 9   2013  247323                      4514
# 10  2014  255686                      4432
# 11  2015  262486                      2867
# 12  2016  266676                      7490
# 13  2017  265859                      7378
#
#     infraestrutura_desenvolvimento_pesquisa  juridico_policial  \
# 0                                     23301              22196
# 1                                     24072              24291
# 2                                     27913              26821
# ...

# %%
df= df_wide.melt(id_vars =['ano'], 
        value_vars = ['social', 'economia_financas_gestao', 'infraestrutura_desenvolvimento_pesquisa','juridico_policial', 'apoio_tecnico_administrativo','regulacao_auditoria_fiscalizacao', 'nao_classificado'], 
        var_name ='carreiras', 
        value_name ='total')
df
# Out:
# C:\Users\ana.sales_republica\AppData\Local\Temp\ipykernel_11484\2749766528.py:1: FutureWarning: This dataframe has a column name that matches the 'value_name' column name of the resulting Dataframe. In the future this will raise an error, please set the 'value_name' parameter of DataFrame.melt to a unique name.
#   df= df_wide.melt(id_vars =['ano'],
#      ano         carreiras   total
# 0   2004            social  167438
# 1   2005            social  167511
# 2   2006            social  178166
# 3   2007            social  178301
# 4   2008            social  182809
# ..   ...               ...     ...
# 93  2013  nao_classificado   42339
# 94  2014  nao_classificado   42277
# 95  2015  nao_classificado   41415
# 96  2016  nao_classificado   37701
# 97  2017  nao_classificado   38419
#
# [98 rows x 3 columns]

# %%
df= df.to_csv('SIAPE_servidores_agrupamento_carreira.csv', index = False)
