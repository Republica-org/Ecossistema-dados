# %%
import numpy as np
import pandas as pd
import os

# %%
os.chdir('G:\\Drives compartilhados\\República.org\\4. Equipes\\Dados e Comunicação\\DADOS\\415 - Repositório de Dados\\Dados para subir\\Tabelas finais')

# %%
## Baixei direto do Atlas pois o encoding não estava funcionando. 

#os.chdir("C:\\Users\\paula.frias_republic\\Downloads")

# %%
df = pd.read_csv('2407-racanatjur.csv',sep=";", encoding='UTF8')
df
# Out:
#       ano mes_base                    nat_jur          raça2  vinculos   total
# 0    1999      Fev          Autarquia Federal         Branca    100527  188092
# 1    1999      Fev          Autarquia Federal  Não informada     32263  188092
# 2    1999      Fev          Autarquia Federal          Negra     48488  188092
# 3    1999      Fev          Autarquia Federal         Outros      6814  188092
# 4    1999      Fev  Emp Pub  S A  Cap Fechado         Branca         9      18
# ..    ...      ...                        ...            ...       ...     ...
# 340  2020      Fev           Fundacao Federal         Outros      1993   73138
# 341  2020      Fev    Poder Executivo Federal         Branca     91144  173994
# 342  2020      Fev    Poder Executivo Federal  Não informada     11517  173994
# 343  2020      Fev    Poder Executivo Federal          Negra     65508  173994
# 344  2020      Fev    Poder Executivo Federal         Outros      5825  173994
#
# [345 rows x 6 columns]

# %%
df = pd.read_csv('SIAPE_ativos_federal_raca_orgao_juridico.csv', encoding='UTF8')
df
# Out:
#       ano mes_base                    nat_jur            raca  vinculos  \
# 0    1999      Fev          Autarquia Federal          Branca    100527
# 1    1999      Fev          Autarquia Federal  NÃ£o informada     32263
# 2    1999      Fev          Autarquia Federal           Negra     48488
# 3    1999      Fev          Autarquia Federal          Outros      6814
# 4    1999      Fev  Emp Pub  S A  Cap Fechado          Branca         9
# ..    ...      ...                        ...             ...       ...
# 340  2020      Fev           Fundacao Federal          Outros      1993
# 341  2020      Fev    Poder Executivo Federal          Branca     91144
# 342  2020      Fev    Poder Executivo Federal  NÃ£o informada     11517
# 343  2020      Fev    Poder Executivo Federal           Negra     65508
# 344  2020      Fev    Poder Executivo Federal          Outros      5825
#
#       total
# 0    188092
# 1    188092
# 2    188092
# 3    188092
# 4        18
# ..      ...
# ...

# %% [markdown]
# Renomeação de coluna

# %%
df.rename(columns={"raça2":"raca"}, inplace=True)
df
# Out:
#       ano mes_base                    nat_jur           raca  vinculos   total
# 0    1999      Fev          Autarquia Federal         Branca    100527  188092
# 1    1999      Fev          Autarquia Federal  Não informada     32263  188092
# 2    1999      Fev          Autarquia Federal          Negra     48488  188092
# 3    1999      Fev          Autarquia Federal         Outros      6814  188092
# 4    1999      Fev  Emp Pub  S A  Cap Fechado         Branca         9      18
# ..    ...      ...                        ...            ...       ...     ...
# 340  2020      Fev           Fundacao Federal         Outros      1993   73138
# 341  2020      Fev    Poder Executivo Federal         Branca     91144  173994
# 342  2020      Fev    Poder Executivo Federal  Não informada     11517  173994
# 343  2020      Fev    Poder Executivo Federal          Negra     65508  173994
# 344  2020      Fev    Poder Executivo Federal         Outros      5825  173994
#
# [345 rows x 6 columns]

# %% [markdown]
# Eliminação de valores nulos

# %%
df.dropna()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 df.dropna()
#
# AttributeError: 'NoneType' object has no attribute 'dropna'

# %%
df = df.to_csv('SIAPE_ativos_federal_raca_orgao_juridico.csv', index = False)
