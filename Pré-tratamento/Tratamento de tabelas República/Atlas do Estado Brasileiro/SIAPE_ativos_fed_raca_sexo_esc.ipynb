# %%
import numpy as np
import pandas as pd
import os

# %%
os.chdir('G:\\Drives compartilhados\\República.org\\4. Equipes\\Dados e Comunicação\\DADOS\\415 - Repositório de Dados\\Dados para subir\\Dados Brutos\\Atlas do Estado')

# %%
df = pd.read_csv("SIAPE_ativos_federal_raca_sexo_escolaridade.csv", sep=";")
df
# Out:
#        ano mes_base esc_cargo sexo          raça2           raça  \
# 0     1999      Fev       NaN  Fem         Branca         BRANCA
# 1     1999      Fev       NaN  Fem  Não informada  NAO INFORMADO
# 2     1999      Fev       NaN  Fem          Negra          NEGRA
# 3     1999      Fev       NaN  Fem          Negra          PARDA
# 4     1999      Fev       NaN  Fem          Negra          PRETA
# ...    ...      ...       ...  ...            ...            ...
# 1491  2020      Fev   S/cargo  Mas  Não informada  NAO INFORMADO
# 1492  2020      Fev   S/cargo  Mas          Negra          PARDA
# 1493  2020      Fev   S/cargo  Mas          Negra          PRETA
# 1494  2020      Fev   S/cargo  Mas         Outros        AMARELA
# 1495  2020      Fev   S/cargo  Mas         Outros       INDIGENA
#
#       qtde_vinc_serv
# 0               3535
# 1               2665
# 2                 65
# 3               3653
# 4                857
# ...              ...
# 1491             204
# ...

# %% [markdown]
# Renomeação da coluna

# %%
df.rename(columns={"raça":"raca"}, inplace=True) 
df
# Out:
#        ano mes_base esc_cargo sexo          raça2           raca  \
# 0     1999      Fev       NaN  Fem         Branca         BRANCA
# 1     1999      Fev       NaN  Fem  Não informada  NAO INFORMADO
# 2     1999      Fev       NaN  Fem          Negra          NEGRA
# 3     1999      Fev       NaN  Fem          Negra          PARDA
# 4     1999      Fev       NaN  Fem          Negra          PRETA
# ...    ...      ...       ...  ...            ...            ...
# 1491  2020      Fev   S/cargo  Mas  Não informada  NAO INFORMADO
# 1492  2020      Fev   S/cargo  Mas          Negra          PARDA
# 1493  2020      Fev   S/cargo  Mas          Negra          PRETA
# 1494  2020      Fev   S/cargo  Mas         Outros        AMARELA
# 1495  2020      Fev   S/cargo  Mas         Outros       INDIGENA
#
#       qtde_vinc_serv
# 0               3535
# 1               2665
# 2                 65
# 3               3653
# 4                857
# ...              ...
# 1491             204
# ...

# %% [markdown]
# Eliminação de coluna

# %%
df = df.drop("raça2", axis=1) 
df
# Out:
#        ano mes_base esc_cargo sexo           raca  qtde_vinc_serv
# 0     1999      Fev       NaN  Fem         BRANCA            3535
# 1     1999      Fev       NaN  Fem  NAO INFORMADO            2665
# 2     1999      Fev       NaN  Fem          NEGRA              65
# 3     1999      Fev       NaN  Fem          PARDA            3653
# 4     1999      Fev       NaN  Fem          PRETA             857
# ...    ...      ...       ...  ...            ...             ...
# 1491  2020      Fev   S/cargo  Mas  NAO INFORMADO             204
# 1492  2020      Fev   S/cargo  Mas          PARDA            1725
# 1493  2020      Fev   S/cargo  Mas          PRETA             234
# 1494  2020      Fev   S/cargo  Mas        AMARELA             147
# 1495  2020      Fev   S/cargo  Mas       INDIGENA              14
#
# [1496 rows x 6 columns]

# %%
df = df.to_csv("SIAPE_ativos_federal_raca_sexo_escolaridade.csv", index = False)
