# %%
import numpy as np
import pandas as pd
import os

# %%
import numpy as np
import pandas as pd
df_wide = pd.read_csv('SIAPE_civis_ativos_ministerio.csv', sep=';', encoding='latin-1')
df_wide
# Out:
#                                           ministerios  perc_servidores_2018  \
# 0                              ministerio da educacao                 49.25
# 1                               ministerio da justica                  5.17
# 2                       ministerio de minas e energia                  0.67
# 3                         ministerio do meio ambiente                  1.43
# 4   ministerio dos transportes, portos e aviacao c...                  1.04
# 5   ministerio da industria, comercio exterior e s...                  0.55
# 6                               ministerio do turismo                  0.07
# 7                               ministerio do esporte                  0.05
# 8                               ministerio da cultura                  0.57
# 9                  ministerio das relacoes exteriores                  0.55
# 10                  ministerio da integracao nacional                  0.39
# ...

# %%
df_long = df_wide.melt('ministerios', var_name= 'Servidores por ano', value_name = 'valor em %')
df_long
# Out:
#                                           ministerios    Servidores por ano  \
# 0                              ministerio da educacao  perc_servidores_2018
# 1                               ministerio da justica  perc_servidores_2018
# 2                       ministerio de minas e energia  perc_servidores_2018
# 3                         ministerio do meio ambiente  perc_servidores_2018
# 4   ministerio dos transportes, portos e aviacao c...  perc_servidores_2018
# 5   ministerio da industria, comercio exterior e s...  perc_servidores_2018
# 6                               ministerio do turismo  perc_servidores_2018
# 7                               ministerio do esporte  perc_servidores_2018
# 8                               ministerio da cultura  perc_servidores_2018
# 9                  ministerio das relacoes exteriores  perc_servidores_2018
# 10                  ministerio da integracao nacional  perc_servidores_2018
# ...

# %%
df_long.to_csv('SIAPE_civis_ativos_ministerio.csv')

# %% [markdown]
# Renomeação de coluna

# %%
os.chdir('G:\\Drives compartilhados\\República.org\\4. Equipes\\Dados e Comunicação\\DADOS\\415 - Repositório de Dados\\Dados para subir\\Tabelas finais')

# %%
df = pd.read_csv("SIAPE_civis_ativos_ministerio.csv")
df
# Out:
#     Unnamed: 0                                        ministerios  \
# 0            0                             ministerio da educacao
# 1            1                              ministerio da justica
# 2            2                      ministerio de minas e energia
# 3            3                        ministerio do meio ambiente
# 4            4  ministerio dos transportes, portos e aviacao c...
# 5            5  ministerio da industria, comercio exterior e s...
# 6            6                              ministerio do turismo
# 7            7                              ministerio do esporte
# 8            8                              ministerio da cultura
# 9            9                 ministerio das relacoes exteriores
# 10          10                  ministerio da integracao nacional
# 11          11  ministerio da ciencia, tecnologia, inovacao e ...
# 12          12                   ministerio do trabalho e emprego
# ...

# %%
df.rename(columns={"Servidores por ano": "servidores_ano", "valor em %": "valor_percent"}, inplace= True)
df
# Out:
#                                           ministerios        servidores_ano  \
# 0                              ministerio da educacao  perc_servidores_2018
# 1                               ministerio da justica  perc_servidores_2018
# 2                       ministerio de minas e energia  perc_servidores_2018
# 3                         ministerio do meio ambiente  perc_servidores_2018
# 4   ministerio dos transportes, portos e aviacao c...  perc_servidores_2018
# 5   ministerio da industria, comercio exterior e s...  perc_servidores_2018
# 6                               ministerio do turismo  perc_servidores_2018
# 7                               ministerio do esporte  perc_servidores_2018
# 8                               ministerio da cultura  perc_servidores_2018
# 9                  ministerio das relacoes exteriores  perc_servidores_2018
# 10                  ministerio da integracao nacional  perc_servidores_2018
# ...

# %%
df = df.drop(['Unnamed: 0'], axis=1)
df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 df = df.drop(['Unnamed: 0'], axis=1)
#
# File c:\Users\ana.sales_republica\Anaconda\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File c:\Users\ana.sales_republica\Anaconda\lib\site-packages\pandas\core\frame.py:5399, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5251 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    5252 def drop(  # type: ignore[override]
# ...

# %%
df = df.to_csv('SIAPE_civis_ativos_ministerio.csv', index = False)
