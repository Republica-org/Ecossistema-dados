# %%
import pandas as pd
import os
import numpy as np

# %%
os.chdir("G:\\Drives compartilhados\\República.org\\4. Equipes\\Dados e Comunicação\\DADOS\\415 - Repositório de Dados\\Dados para subir")

# %%
 df_wide =pd.read_csv("4424-grafico4.csv", sep=";")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 df_wide =pd.read_csv("4424-grafico4.csv", sep=";")
#
# File c:\Users\ana.sales_republica\Anaconda\lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File c:\Users\ana.sales_republica\Anaconda\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# ...

# %%
df_wide
# Out:
#      Ano         RPPS    Salarios
# 0   2002        0,021        0,038
# 1   2003         0,02        0,037
# 2   2004        0,019        0,035
# 3   2005        0,019        0,037
# 4   2006        0,019        0,038
# 5   2007        0,018        0,037
# 6   2008        0,018        0,037
# 7   2009        0,018        0,038
# 8   2010   0,01779811  0,036644524
# 9   2011  0,018001917  0,036436966
# 10  2012  0,018872775  0,037085908
# 11  2013  0,019215919   0,03802809
# 12  2014  0,019971718  0,038093445
# 13  2015  0,021659254   0,04009657
# 14  2016  0,022768754  0,039721414
# 15  2017  0,023936768  0,039554596
# 16  2018  0,024396163  0,038453163
# 17  2019  0,025093086  0,037699075
# 18  2020  0,027552446  0,037280386

# %%
df_long = df_wide.melt('Ano', var_name='Tipo de despesa', value_name='% PIB')

# %%
df_long
# Out:
#      Ano Tipo de despesa        % PIB
# 0   2002            RPPS        0,021
# 1   2003            RPPS         0,02
# 2   2004            RPPS        0,019
# 3   2005            RPPS        0,019
# 4   2006            RPPS        0,019
# 5   2007            RPPS        0,018
# 6   2008            RPPS        0,018
# 7   2009            RPPS        0,018
# 8   2010            RPPS   0,01779811
# 9   2011            RPPS  0,018001917
# 10  2012            RPPS  0,018872775
# 11  2013            RPPS  0,019215919
# 12  2014            RPPS  0,019971718
# 13  2015            RPPS  0,021659254
# 14  2016            RPPS  0,022768754
# 15  2017            RPPS  0,023936768
# 16  2018            RPPS  0,024396163
# 17  2019            RPPS  0,025093086
# 18  2020            RPPS  0,027552446
# 19  2002       Salarios         0,038
# 20  2003       Salarios         0,037
# 21  2004       Salarios         0,035
# 22  2005       Salarios         0,037
# 23  2006       Salarios         0,038
# ...

# %%
df_long.to_csv("Tabelas Finais\\IPEA_despesa_PIB_salarios_RPPS.csv")

# %%
os.chdir('G:\\Drives compartilhados\\República.org\\4. Equipes\\Dados e Comunicação\\DADOS\\415 - Repositório de Dados\\Dados para subir\\Tabelas finais\\Tratar primeira coluna e nomes ')

# %%
df = pd.read_csv("IPEA_despesa_PIB_salarios_RPPS.csv")
df
# Out:
#     Unnamed: 0   Ano Tipo de despesa        % PIB
# 0            0  2002            RPPS        0,021
# 1            1  2003            RPPS         0,02
# 2            2  2004            RPPS        0,019
# 3            3  2005            RPPS        0,019
# 4            4  2006            RPPS        0,019
# 5            5  2007            RPPS        0,018
# 6            6  2008            RPPS        0,018
# 7            7  2009            RPPS        0,018
# 8            8  2010            RPPS   0,01779811
# 9            9  2011            RPPS  0,018001917
# 10          10  2012            RPPS  0,018872775
# 11          11  2013            RPPS  0,019215919
# 12          12  2014            RPPS  0,019971718
# 13          13  2015            RPPS  0,021659254
# 14          14  2016            RPPS  0,022768754
# 15          15  2017            RPPS  0,023936768
# 16          16  2018            RPPS  0,024396163
# 17          17  2019            RPPS  0,025093086
# ...

# %% [markdown]
# Renomeação de colunas

# %%
df.rename(columns={"Ano": "ano", "Tipo de despesa": "tipo_despesa", "% PIB" : "PIB_percent"}, inplace=True)
df
# Out:
#      ano tipo_despesa  PIB_percent
# 0   2002         RPPS        0,021
# 1   2003         RPPS         0,02
# 2   2004         RPPS        0,019
# 3   2005         RPPS        0,019
# 4   2006         RPPS        0,019
# 5   2007         RPPS        0,018
# 6   2008         RPPS        0,018
# 7   2009         RPPS        0,018
# 8   2010         RPPS   0,01779811
# 9   2011         RPPS  0,018001917
# 10  2012         RPPS  0,018872775
# 11  2013         RPPS  0,019215919
# 12  2014         RPPS  0,019971718
# 13  2015         RPPS  0,021659254
# 14  2016         RPPS  0,022768754
# 15  2017         RPPS  0,023936768
# 16  2018         RPPS  0,024396163
# 17  2019         RPPS  0,025093086
# 18  2020         RPPS  0,027552446
# 19  2002    Salarios         0,038
# 20  2003    Salarios         0,037
# 21  2004    Salarios         0,035
# 22  2005    Salarios         0,037
# 23  2006    Salarios         0,038
# 24  2007    Salarios         0,037
# 25  2008    Salarios         0,037
# ...

# %% [markdown]
# Eliminação de coluna

# %%
df = df.drop('Unnamed: 0', axis=1)
df
# Out:
#      ano tipo_despesa  PIB_percent
# 0   2002         RPPS        0,021
# 1   2003         RPPS         0,02
# 2   2004         RPPS        0,019
# 3   2005         RPPS        0,019
# 4   2006         RPPS        0,019
# 5   2007         RPPS        0,018
# 6   2008         RPPS        0,018
# 7   2009         RPPS        0,018
# 8   2010         RPPS   0,01779811
# 9   2011         RPPS  0,018001917
# 10  2012         RPPS  0,018872775
# 11  2013         RPPS  0,019215919
# 12  2014         RPPS  0,019971718
# 13  2015         RPPS  0,021659254
# 14  2016         RPPS  0,022768754
# 15  2017         RPPS  0,023936768
# 16  2018         RPPS  0,024396163
# 17  2019         RPPS  0,025093086
# 18  2020         RPPS  0,027552446
# 19  2002    Salarios         0,038
# 20  2003    Salarios         0,037
# 21  2004    Salarios         0,035
# 22  2005    Salarios         0,037
# 23  2006    Salarios         0,038
# 24  2007    Salarios         0,037
# 25  2008    Salarios         0,037
# ...

# %%
df = df.to_csv('IPEA_despesa_PIB_salarios_RPPS.csv', index = False)
