# %%
import pandas as pd
import time
import os
import pandas_gbq
from google.cloud import bigquery
import glob
import openpyxl

# %%
os.chdir('G:\\Drives compartilhados\\República.org\\4. Equipes\\Dados e Comunicação\\DADOS\\415 - Repositório de Dados\\Dados para subir\\Dados Brutos\\INEP\\Adequação Formação Docente')

# %%
anos = list(range(2013,2023))

# %%
anos
# Out:
# [2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022]

# %%
df1 = pd.read_excel("AFD_ESCOLAS_2013.xlsx",index_col=0)
df1
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 df1 = pd.read_excel("AFD_ESCOLAS_2013.xlsx",index_col=0)
#       2 df1
#
# File c:\Users\ana.sales_republica\Anaconda\lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File c:\Users\ana.sales_republica\Anaconda\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# ...

# %%
df1.dropna()
# Out:
#             Região  UF  Código do Município      Nome do Município  \
# Ano
# 2013         Norte  RO              1100015  ALTA FLORESTA D OESTE
# 2013         Norte  RO              1100015  ALTA FLORESTA D OESTE
# 2013         Norte  RO              1100015  ALTA FLORESTA D OESTE
# 2013         Norte  RO              1100015  ALTA FLORESTA D OESTE
# 2013         Norte  RO              1100015  ALTA FLORESTA D OESTE
# ...            ...  ..                  ...                    ...
# 2013  Centro_Oeste  DF              5300108               BRASILIA
# 2013  Centro_Oeste  DF              5300108               BRASILIA
# 2013  Centro_Oeste  DF              5300108               BRASILIA
# 2013  Centro_Oeste  DF              5300108               BRASILIA
# 2013  Centro_Oeste  DF              5300108               BRASILIA
#
#       Código da Escola                           Nome da Escola Localização  \
# Ano
# ...

# %%
df2 = pd.read_excel("AFD_ESCOLAS_2014.xlsx",index_col=0)
df2
# Out:
#             Região  UF  Código do Município      Nome do Município  \
# Ano
# 2014         Norte  RO              1100015  ALTA FLORESTA D OESTE
# 2014         Norte  RO              1100015  ALTA FLORESTA D OESTE
# 2014         Norte  RO              1100015  ALTA FLORESTA D OESTE
# 2014         Norte  RO              1100015  ALTA FLORESTA D OESTE
# 2014         Norte  RO              1100015  ALTA FLORESTA D OESTE
# ...            ...  ..                  ...                    ...
# 2014  Centro_Oeste  DF              5300108               BRASILIA
# 2014  Centro_Oeste  DF              5300108               BRASILIA
# 2014  Centro_Oeste  DF              5300108               BRASILIA
# 2014  Centro_Oeste  DF              5300108               BRASILIA
# 2014  Centro_Oeste  DF              5300108               BRASILIA
#
#       Código da Escola                           Nome da Escola Localização  \
# Ano
# ...

# %%
tabelas = pd.concat([df1, df2])
tabelas
# Out:
#             Região  UF  Código do Município      Nome do Município  \
# Ano
# 2013         Norte  RO              1100015  ALTA FLORESTA D OESTE
# 2013         Norte  RO              1100015  ALTA FLORESTA D OESTE
# 2013         Norte  RO              1100015  ALTA FLORESTA D OESTE
# 2013         Norte  RO              1100015  ALTA FLORESTA D OESTE
# 2013         Norte  RO              1100015  ALTA FLORESTA D OESTE
# ...            ...  ..                  ...                    ...
# 2014  Centro_Oeste  DF              5300108               BRASILIA
# 2014  Centro_Oeste  DF              5300108               BRASILIA
# 2014  Centro_Oeste  DF              5300108               BRASILIA
# 2014  Centro_Oeste  DF              5300108               BRASILIA
# 2014  Centro_Oeste  DF              5300108               BRASILIA
#
#       Código da Escola                           Nome da Escola Localização  \
# Ano
# ...

# %%
df3 = pd.read_excel("AFD_ESCOLAS_2016.xlsx",index_col=0)
display(df3)
# Out:
#             Região  UF  Código do Município      Nome do Município  \
# Ano
# 2016         Norte  RO              1100015  Alta Floresta D'Oeste
# 2016         Norte  RO              1100015  Alta Floresta D'Oeste
# 2016         Norte  RO              1100015  Alta Floresta D'Oeste
# 2016         Norte  RO              1100015  Alta Floresta D'Oeste
# 2016         Norte  RO              1100015  Alta Floresta D'Oeste
# ...            ...  ..                  ...                    ...
# 2016  Centro-Oeste  DF              5300108               Brasília
# 2016  Centro-Oeste  DF              5300108               Brasília
# 2016  Centro-Oeste  DF              5300108               Brasília
# 2016  Centro-Oeste  DF              5300108               Brasília
# 2016  Centro-Oeste  DF              5300108               Brasília
#
#       Código da Escola            Nome da Escola Localização  \
# Ano
# 2016          11022558     EIEEF HAP BITT TUPARI       Rural
# ...

# %% [markdown]
# tabela = pd.concat([df1, df2, df3, df4, df5, df6, df7, df8, df9])
# tabela

# %%
x=2013

# %%
df1=pd.DataFrame()

for i in anos: 
    path="AFD_ESCOLAS_{}.xlsx".format(i)
    df = pd.read_excel(path,index_col=0)
    df=df.reset_index()
    df.drop(['Ano'], axis=1,inplace=True)
    df.dropna()
    df.insert(0, 'Ano', i)
    df1 = pd.concat([df,df])

# %%
df1=pd.DataFrame()
df1
# Out:
# Empty DataFrame
# Columns: []
# Index: []
